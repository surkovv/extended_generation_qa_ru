# %%
import deeppavlov
import udapi
import json
from tqdm.notebook import tqdm
from src.record import Record
from src.generate import LongAnswerGenerator
from tests.tester import Tester
from udapi.block.read.conllu import Conllu
from udapi.core.document import Document
from udapi.block.write.textmodetrees import TextModeTrees

from io import StringIO

# %%
SQ_PATH = '/home/admin/.deeppavlov/sberQ/'

# %%
with open(SQ_PATH + 'dev-v1.1.json') as f:
    dataset = json.load(f)['data'][0]['paragraphs']

# %%
dataset
# Out:
# [{'context': 'В Миссолонги Байрон заболел лихорадкой, продолжая отдавать все свои силы на борьбу за свободу страны. 19 января 1824 года он писал Хэнкопу: Мы готовимся к экспедиции , а 22 января, в день своего рождения, он вошёл в комнату полковника Стенхопа, где было несколько человек гостей, и весело сказал: Вы упрекаете меня, что я не пишу стихов, а вот я только что написал стихотворение . И Байрон прочёл: Сегодня мне исполнилось 36 лет . Постоянно хворавшего Байрона очень тревожила болезнь его дочери Ады. Получив письмо с хорошей вестью о её выздоровлении, он захотел выехать прогуляться с графом Гамба. Во время прогулки пошёл страшный дождь, и Байрон окончательно захворал. Последними словами поэта были отрывочные фразы: Сестра моя! дитя моё!.. бедная Греция!.. я отдал ей время, состояние, здоровье!.. теперь отдаю ей и жизнь! .',
#   'id': '2153',
#   'qas': [{'id': '12786',
#     'question': 'Чем заболел Байрон в Миссолонги?',
#     'answers': [{'answer_start': 28, 'text': 'лихорадкой'}]}]},
#  {'context': 'От излишней потери тепла млекопитающих предохраняет шёрстный покров, а у водных форм — подкожный слой жира. Излишки тепла отводятся потоотделением. Значительную роль в терморегуляции играет развитая система кожных кровеносных сосудов, диаметр просветов которых регулируется нервно-рефлекторным путём. Механизм теплообразования за счёт активации клеточного метаболизма называется несократительным термогенезом. К таким механизм относят, в частности, липолиз, особенно бурой жировой ткани. Кроме жира, в качестве внутренних энергетических запасов организма могут выступать и углеводы. Если же тепло образуется в процессе сокращения скелетных мышц, то говорят о сократительном термогенезе.',
#   'id': '11126',
#   'qas': [{'id': '39919',
#     'question': 'Как отводятся излишки тепла у млекопитающих?',
#     'answers': [{'answer_start': 132, 'text': 'потоотделением'}]}]},
#  {'context': 'Хромосомные перестройки (хромосомные аберрации) — это мутации, нарушающие структуру хромосом. Они могут возникнуть в соматических и зародышевых клетках спонтанно или в результате внешних воздействий (ионизирующее излучение, химические мутагены, вирусная инфекция и др.). В результате хромосомной перестройки может быть утрачен или, наоборот, удвоен фрагмент хромосомы (делеция и дупликация, соответственно); участок хромосомы может быть перенесён на другую хромосому (транслокация) или он может изменить свою ориентацию в составе хромосомы на 180° (инверсия). Существуют и другие хромосомные перестройки.',
#   'id': '13814',
#   'qas': [{'id': '4762',
#     'question': 'Что нарушают хромосомные аберрации?',
#     'answers': [{'answer_start': 74, 'text': 'Структуру хромосом.'}]}]},
#  {'context': 'Первый в мире городской автобус с двигателем внутреннего сгорания вышел на маршрут 12 апреля 1903 года в Лондоне. В России автобус в качестве городского общественного транспорта впервые стал использоваться с июня 1907 года в Архангельске. В город был привезён автобус германской марки НАГ (NAG). Эта машина была рассчитана на 25 пассажиров и весила 6 тонн. Мощность двигателя 26 л. с. А 11 ноября 1907 года первый пассажирский автобусный маршрут был открыт в Санкт-Петербурге. По этому поводу в Петербургском листке было помещено сообщение: К двенадцати часам дня к Александровскому саду, против Вознесенского проспекта, приехал автомобиль-омнибус или, как их теперь называют, автобус . В Москве автобусное движение впервые было открыто 13 августа 1908 года, а постоянное автобусное движение лишь с 8 августа 1924 года, когда на первый регулярный маршрут между Каланчевской площадью и Тверской Заставой вышли 8 автобусов марки Leyland .',
#   'id': '9418',
#   'qas': [{'id': '74796',
#     'question': 'В каком городе первый в мире городской автобус с двигателем внутреннего сгорания вышел на маршрут?',
#     'answers': [{'answer_start': 103, 'text': 'в Лондоне'}]}]},
#  {'context': 'Фродом являются также и операции с поддельными картами. Подделываются кредитные карты так — берётся гибридная карточка (т.е. на карте представлены чип и магнитная полоса), копируются записи её магнитной полосы и переносятся на другую карточку только с магнитной полосой или на гибридную карточку с кривым чипом (например, сожжённым или неперсонализированным). Операции могут успешно выполняться: в режиме онлайн (в устройствах читающих магнитную полосу), в режиме офлайн (подлимитные операции) или в режиме fallback (при невозможности читать чип устройство проводит операцию по магнитной полосе). Ответственность за такой фрод ложится на эмитента карточки или на эквайрера, если по правилам конкретной платежной системы возможен перенос ответственности.',
#   'id': '8604',
#   'qas': [{'id': '56710',
#     'question': 'В каком режиме проходят подлимитные операции?',
#     'answers': [{'answer_start': 455, 'text': 'в режиме офлайн'}]}]},
#  {'context': 'Слоговое письмо представляет собой набор письменных знаков, которые представляют (или аппроксимируют) слоги. Знак в слоговом письме обычно отображает сочетание гласный-согласный, или просто один гласный звук. Но в некоторых случаях знаки отображают более сложные слоги (например, согласный-гласный-согласный или согласный-согласный-гласный). Фонетическая связь слогов не находит отражения в алфавите. Например, слог ка будет выглядеть совсем непохожим на слог ки , и в алфавите не будет схожих слогов с такими же гласными.',
#   'id': '3235',
#   'qas': [{'id': '3308',
#     'question': 'Находит ли отражение в алфавите фонетическая связь слогов?',
#     'answers': [{'answer_start': 368, 'text': 'не находит'}]}]},
#  {'context': 'Весной 1890 года художник перебрался в Овер-сюр-Уаз, местечко под Парижем, где впервые за два года увиделся с братом и его семьёй. Он по-прежнему продолжал писать, но стиль его последних работ изменился окончательно, став ещё более нервным и гнетущим. Главное место в творчестве занял прихотливо искривлённый контур, словно зажимающий собой тот или иной предмет ( Сельская дорога с кипарисами , 1890, Музей Крёллер-Мюллер, Оттерло; Улица и лестница в Овере , 1890, Городской художественный музей, Сент-Луис; Пейзаж в Овере после дождя , 1890, Государственный музей изобразительных искусств им. А. С. Пушкина, Москва). Последним светлым событием в личной жизни Винсента стало знакомство с художником-любителем доктором Полем Гаше.',
#   'id': '13133',
#   'qas': [{'id': '70696',
#     'question': 'Каким стал стиль последних работ художника?',
#     'answers': [{'answer_start': 232, 'text': 'нервным и гнетущим'}]}]},
#  {'context': 'В 2008 году родилось 1147 человек у граждан Швейцарии, а 893 у иностранных, в то же время, умерло 1114 граждан Швейцарии и 274 иностранных. Без учёта иммиграции и эмиграции, население граждан Швейцарии в Женеве увеличилось на 33 человека, в то время, как иностранных на 619. 465 швейцарских мужчин и 498 швейцарских женщин эмигрировали из страны, тогда, как 2 933 нешвейцарских мужчин и 2 662 нешвейцарских женщин иммигрировали в Швейцарию из других стран. Общая численность швейцарского населения в 2008 году увеличилось на 135 человек, а иностранных граждан на 3 181. Прирост населения составил 1,8 %.',
#   'id': '9141',
#   'qas': [{'id': '76925',
#     'question': 'Сколько человек родилось в 2008 году у граждан Швейцарии?',
#     'answers': [{'answer_start': 21, 'text': '1147 человек'}]}]},
#  {'context': 'Иногда говорят о возможности провести GNU GPL как договор присоединения, согласно статьям (428, 435 ГК РФ). Но единственный такой способ для лицензионных договоров описан в п. 3 ст. 1286 ГК РФ ( Заключение лицензионных договоров о предоставлении права использования программы для ЭВМ или базы данных допускается путём заключения каждым пользователем с соответствующим правообладателем договора присоединения, условия которого изложены на приобретаемом экземпляре таких программы или базы данных либо на упаковке этого экземпляра, а также в электронном виде (пункт 2 статьи 434). ). Эта статья даёт возможность для легализации ПО, скачанного из Интернет и предоставляемого по лицензии GNU GPL (Лицензионный договор, заключаемый в упрощённом порядке, является безвозмездным, если договором не предусмотрено иное.).',
#   'id': '13772',
#   'qas': [{'id': '60110',
#     'question': 'Какая статья и пункт дает возможность статья для легализации ПО, скачанного из Интернет и предоставляемого по лицензии GNU GPL?',
#     'answers': [{'answer_start': 558, 'text': 'пункт 2 статьи 434'}]}]},
#  {'context': 'Первым пособием по товароведению в России обычно назвают вышедшую в 1575 году Торговую книгу (другие названия Память товарам , Память как продавать товар русской в немцех ). Составленная на основе богатейшего внешнеторгового опыта, накопленного купцами-новгородцами, книга поучала, како торг вести и знати всему цену , как приготовлять товары для продажи западноевропейцам. Особое внимание в ней уделялось русско-нидерландской торговле. Торговая книга советовала русским купцам заключать торговые договоры о продаже технического сырья, пищевых продуктов, изделий ремесла, лесных промыслов; приводились цены на пушнину и кожи. Сообщалось и о том, что привозили на Кольское побережье нидерландские купцы: сахар, изюм, пряности, нашатырь, камфору, металлы (олово, ртуть) и металлоизделия (медную и железную проволоку для русских ремесленников).',
#   'id': '10328',
#   'qas': [{'id': '37134',
#     'question': 'Какими русскими купцами был накоплен значимый торговый опыт?',
#     'answers': [{'answer_start': 245, 'text': 'купцами-новгородцами'}]}]},
#  {'context': 'Конкурентная разведка в её сегодняшнем виде получила сильный импульс развития в середине 1980-х годов. Родоначальником конкурентной разведки современного периода считается компания Ксерокс (Xerox), столкнувшаяся с конкуренцией со стороны японских производителей. Это была война насмерть, поскольку японцы вышли на американский рынок с розничными ценами ниже себестоимости Ксерокса. Но Ксерокс, благодаря своему японскому филиалу, создал систему работы, которую сегодня называют бенчмаркингом, а затем адаптировал и применил к миру бизнеса разведывательные технологии в максимально возможном объёме. Его примеру последовали другие крупные американские компании. Через несколько лет конкурентная разведка стала применяться в Европе, а затем и во всем мире. Этот период можно считать окончательным выделением конкурентной разведки в отдельное направление деятельности.',
#   'id': '10868',
#   'qas': [{'id': '14753',
#     'question': 'Где была применена конкурентная разведка через несколько лет?',
#     'answers': [{'answer_start': 721,
#       'text': 'в Европе, а затем и во всем мире'}]}]},
#  {'context': 'Операционные системы, следующие стандарту POSIX или опирающиеся на него, называют POSIX-совместимыми (чаще встречается словоупотребление UNIX-подобные или семейство UNIX , но оно противоречит статусу торгового знака UNIX , принадлежащего консорциуму The Open Group и зарезервированному для обозначения только операционных систем, строго следующих стандарту). Сертификация на совместимость со стандартом платная, из-за чего некоторые системы не проходили этот процесс, однако считаются POSIX-совместимыми по существу.',
#   'id': '9592',
#   'qas': [{'id': '15495',
#     'question': 'Совместимы ли операционные системы POSIX?',
#     'answers': [{'answer_start': 475,
#       'text': 'Считаются POSIX-совместимыми по существу'}]}]},
#  {'context': 'Братья Дохерти, уроженцы Уимблдона и воспитанники Кембриджа, впервые серьёзно заявили о себе на чемпионате 1896 года. Старший из них, Реджинальд, дошёл до раунда вызова в парном разряде; младший, Лоуренс, выбыл из борьбы в одиночном разряде достаточно рано, чтобы принять участие в первом в истории Уимблдона утешительном турнире — All-England Plate, где дошёл до финала, проиграв там другому будущему герою Уимблдонского турнира Артуру Гору. Уже со следующего года начался длинный период практически безраздельного господства Дохерти в британском лаун-теннисе. С 1897 по 1900 год Реджинальд становился чемпионом Уимблдонского турнира четыре раза подряд, в том числе один раз обыграв в раунде вызова собственного брата. В 1901 году он уступил чемпионский титул Гору, после этого сосредоточившись из-за ухудшающегося здоровья только на игре в парах, но уже со следующего года на Уимблдоне доминировал Лоуренс, ставший чемпионом пять раз подряд и ушедший непобеждённым. За это же десятилетие, с 1897 по 1906 год, Реджинальд и Лоуренс вместе семь раз выиграли чемпионат мужских пар[16].',
#   'id': '1855',
#   'qas': [{'id': '16195',
#     'question': 'Сколько раз Реджинальд Дохерти стал чемпионом с 1897 по 1900 год?',
#     'answers': [{'answer_start': 635, 'text': 'четыре раза подряд'}]}]},
#  {'context': 'Есть попытки видеть начало публицистики в далёком прошлом литературы; Эрнест Ренан даже называл библейских пророков публицистами древности. Игорь Дедков поддерживает эту мысль, добавляя, что русская публицистическая литература восходит к „Слову о Законе и Благодати“ Илариона и обличительным произведениям Максима Грека . Несомненно, однако, что публицистика в современной её форме есть создание новой истории, всё течение которой — начиная с предвестников реформации — ознаменовано мощным развитием публицистики, которой принадлежало видное участие в возбуждении и организации самых важных общественных движений. Это значение публицистики ещё усилилось с появлением периодической прессы. Роль публицистики в современной жизни громадна. Даже в тех случаях, когда она идёт за общественным мнением, она влияет на него, давая ему определённое выражение и модифицируя его в ту или иную сторону. Большинство выдающихся политических деятелей Западной Европы начинало и начинает свою деятельность с публицистики, прибегая к её помощи и впоследствии. Особенное значение имеет публицистика в России, где она является почти единственным и во всяком случае главным проявлением частной общественно-политической инициативы, и где так важна руководящая роль литературы; авторитетное положение русской литературной критики объясняется тем, что она — в лице наиболее популярных своих представителей — занималась по преимуществу публицистикой. Отсутствием иных органов для выражения общественной мысли объясняется также господство в нашей литературе социального романа с определённой, подчас партийной окраской, а равно и то явление, что у нас отдавали свои силы публицистике такие яркие художественные таланты, как Салтыков-Щедрин и Глеб Успенский, представители особого литературного жанра — соединения художественных образов с публицистикой. Румынский публицист и писатель Горсен Крекош успешно сочетал свою публицистику с поэтическими элементами.',
#   'id': '4685',
#   'qas': [{'id': '31921',
#     'question': 'Кто считал что русская публицистическая литература восходит к „Слову о Законе и Благодати“ Илариона?',
#     'answers': [{'answer_start': 140, 'text': 'Игорь Дедков.'}]}]},
#  {'context': 'Почвы Нигера довольно бедны. На севере Нигера, на каменистых плато и в песчаных пустынях почвенный покров практически отсутствует. Только на участках, где появляется вода, колючие кустарники и засухоустойчивые злаки формируют примитивные песчаные почвы. На юге Нигера, в Сахели, распространение почв зависит от количества влаги. В основном это краснозёмы и песчаные почвы различной мощности. В песчаных почвах Сахели мало перегноя, что делает их уязвимыми для ветровой эрозии. На востоке страны, в котловине озера Чад распространены солончаки. В долинах рек, вади, и впадинах, где собирается вода, встречаются обогащённые аллювием глинистые почвы, благоприятные для сельского хозяйства. Для Нигера характерен процесс деградации и эрозии почв, приводящий к опустыниванию земель, поэтому борьба за восстановление и сохранение почв является важнейшей задачей страны[13].',
#   'id': '3113',
#   'qas': [{'id': '960',
#     'question': 'Где колючие кустарники и засухоустойчивые злаки формируют земную кору?',
#     'answers': [{'answer_start': 131,
#       'text': 'Только на участках, где появляется вода'}]}]},
#  {'context': 'В 14 лет на Мадонну как поп-лирика оказывает влияние дружба с будущим признанным поэтом Уином Купером (англ.)русск., который учится с ней в одной школе на класс старше. По воспоминанием Купера, девушка Чикконе кажется застенчивой и немного отстранённой, она избегает общества, скромно одевается и особо любит книги Олдоса Хаксли и роман Любовник леди Чаттерлей [42]. Ключевым событием детства Мадонны считают выступление на вечере талантов школы West в 14 лет. На нём покрытая зелёной и розовой краской артистка в топе и шортах шокирует публику исполнением танца под известную песню Baba O Riley (Teenage Wasteland) (англ.)русск. группы The Who. Этим она мгновенно убивает репутацию примерной девочки-отличницы, в городе долго обсуждают выступление, а отец сажает дочь под домашний арест. Героиню дня , братьев и сестёр начинают поддразнивать: Мадонна — шлюха , хотя к сексу это не имеет никакого отношения[43][44]. О том моменте Мадонна вспоминала:',
#   'id': '3383',
#   'qas': [{'id': '28307',
#     'question': 'Какое важное событие произошло с Мадонной в 14 лет?',
#     'answers': [{'answer_start': 409,
#       'text': 'выступление на вечере талантов школы West'}]}]},
#  {'context': 'Основные и хорошо изученные аллотропные модификации углерода — алмаз и графит. Термодинамический расчет линии равновесия гафит-алмаз на фазовой р,Т-диаграмме был выполнен в 1939 г. О.И.Лейпунским. При нормальных условиях термодинамически устойчив только графит, а алмаз и другие формы метастабильны. При атмосферном давлении и температуре выше 1200 K алмаз начинает переходить в графит, выше 2100 K превращение совершается взрывообразно за секунды. ΔН0 перехода — 1,898 кДж/моль. Прямой переход графита в алмаз происходит при 3000 K и давлении 11—12 ГПа. При нормальном давлении углерод сублимируется при 3 780 K.',
#   'id': '3532',
#   'qas': [{'id': '5726',
#     'question': 'Когда происходит прямой переход графита в алмаз?',
#     'answers': [{'answer_start': 522,
#       'text': 'при 3000 K и давлении 11—12 ГПа'}]}]},
#  {'context': 'Перед отъездом за границу Байрон продал своё имение Ньюстед, и это дало ему возможность не тяготиться постоянным безденежьем. Теперь он мог предаться уединению, которого так жаждал. За границей он поселился в вилле Диодати на Женевской ривьере. Лето Байрон провел на вилле, совершив две небольшие экскурсии по Швейцарии: одну с Гобгаузом, другую с поэтом Шелли. В третьей песне Чайльд-Гарольда (май—июнь 1816) он описывает свою поездку на поля Ватерлоо. Мысль написать Манфреда посетила его, когда он на обратном пути в Женеву увидал Юнгфрау.',
#   'id': '1535',
#   'qas': [{'id': '83100',
#     'question': 'О чем написано в песне Чайльд-Гарольда ?',
#     'answers': [{'answer_start': 428, 'text': 'Поездку на поля Ватерлоо'}]}]},
#  {'context': 'Развитие и усложнение симфонической музыки, постепенное расширение состава оркестра уже в конце XVIII века требовали освобождения дирижёра от участия в ансамбле; дирижирующий концертмейстер вновь уступал своё место человеку, стоящему перед оркестром. При этом в качестве баттуты могла использоваться трубка из кожи, набитая шерстью, или рулон нот. В начале XIX века в руке дирижёра появилась небольшая деревянная палочка. В Вене дирижёрскую палочку первым использовал Игнац фон Мозель в 1812 году; в 1817 году с помощью палочки управляли оркестром К. М. Вебер в Дрездене и Л. Шпор во Франкфурте-на-Майне.',
#   'id': '13289',
#   'qas': [{'id': '65358',
#     'question': 'Что изначально использовалось в качестве баттуты?',
#     'answers': [{'answer_start': 300,
#       'text': 'трубка из кожи, набитая шерстью, или рулон нот.'}]}]},
#  {'context': 'Названия судный приказ, судная изба, суд встречаются при Иоанне IV, Московский же судный приказ известен в разрядных книгах с 1598 г. В нём сидели боярин, стольник да 1 или 2 дьяка. Ведомству его были подчинены исковые дела жителей Москвы, Московского уезда и, может быть, некоторых других городов, за исключением дел об убийстве, разбое и воровстве с поличным. В 1681 г. он был соединён в один приказ с челобитным, холопьим и владимирским судным, но затем опять стал существовать отдельно, наряду с владимирским судным, а когда последний в 1699 г. был уничтожен, то предметы ведомства его перешли к московскому судному приказу. В 1714 г. приказ этот был переведён из Петербурга в Москву и с тех пор в актах не встречается.',
#   'id': '9840',
#   'qas': [{'id': '15850',
#     'question': 'Какие дела не вел Московский судный приказ?',
#     'answers': [{'answer_start': 318,
#       'text': 'об убийстве, разбое и воровстве с поличным'}]}]},
#  {'context': 'Начиная с 1970-х годов концепции стоимости и балансовой стоимости претерпели значительные изменения. Понятие балансовая стоимость наиболее полезно в отраслях с преобладанием материальных активов. Нематериальные активы, такие как патенты, торговые марки или деловая репутация, сложно оценить количественно и, кроме того, их стоимость может значительно снизиться при разделении компании на части. Кроме того, стоимость активов может быстро меняться в отраслях, подверженных быстрым технологическим переменам. В этом случае, стоимость материальных активов может резко снижаться в результате радикальных инноваций. Для оценки реальной стоимости активов в таких случаях был предложен расчёт дисконтированного денежного потока, генерируемого тем или иным активом.',
#   'id': '1191',
#   'qas': [{'id': '30750',
#     'question': 'Что может произойти со стоимостью нематериальных активов при разделении компании на части?',
#     'answers': [{'answer_start': 333,
#       'text': 'Может значительно снизиться'}]}]},
#  {'context': 'В 1973 году назначен Ричардом Никсоном на пост вице-президента США после отставки Спиро Агню; утверждён 27 ноября Сенатом и 6 декабря Палатой представителей, после чего вступил в должность. Менее чем через год, 9 августа 1974 года, Джеральд Форд вступил на пост президента США, когда в отставку подал уже сам Никсон в связи с расследованием по делу Уотергейта. Форд при этом заявил: Наш долгий национальный кошмар окончился . Таким образом, он стал единственным президентом США, который никогда не был всенародно избран ни на пост президента, ни на пост вице-президента.',
#   'id': '7545',
#   'qas': [{'id': '56044',
#     'question': 'Как прокомментировал Форд отставку Никсона',
#     'answers': [{'answer_start': 383,
#       'text': 'Наш долгий национальный кошмар окончился'}]}]},
#  {'context': 'При спешивании влахов (переходе к оседлому существованию) они смешались и с пришлыми на север от Дуная с начала VI века н. э. славянами, и с другим населением и стали прихожанами христианских храмов восточной , византийской веры, церковным и государственным языком их княжеств стал под мощным непосредственным влиянием Болгарского Царства церковнославянский. Однако, как считают другие исследователи, валахи появились позже славян на территории будущего Валашского княжества. Например, по мнению профессора Бернштейна С. М. Носители романской языковой традиции появляются в Валахии значительно позже славян. Современная наука ничего не знает о существовании романского населения в Валахии между III и XII вв. н. э. .',
#   'id': '14074',
#   'qas': [{'id': '41220',
#     'question': 'Какой язык стал церковным и государственным языком княжеств, в которые входили ставшие оседлыми влахи?',
#     'answers': [{'answer_start': 339, 'text': 'церковнославянский'}]}]},
#  {'context': 'Ряд философов и писателей, обращаясь к теме внутренних ценностей человека, постулировали отсутствие каких-либо оснований для следования существующим моральным и культурным нормам, что получило название нигилизм . Например, основываясь на своём понимании буддизма, нигилистическую картину мира нарисовал Шопенгауэр. Шпенглер и Ницше видели распространение нигилизма в окружающей их европейской культуре. Ницше считал нигилизм естественной логикой развития всей европейской культуры, корни которой он видел, в частности, в христианском постулировании априорной греховности человека. Хотя Шпенглер и Ницше скорее концептуализировали нигилизм и его причины, их самих часто причисляют к нигилистам. Сам термин нигилизм , вероятно, впервые возник в России, где многие писатели, например Тургенев, неоднократно выводили образы нигилистов в художественной литературе.',
#   'id': '2611',
#   'qas': [{'id': '33517',
#     'question': 'Какое название получило в философии отсутствие каких-либо оснований для следования существующим моральным и культурным нормам?',
#     'answers': [{'answer_start': 201, 'text': ' нигилизм .'}]}]},
#  {'context': 'Технические индикаторы — дополнительные графики, формируемые на основе пересчёта значений, содержащихся в базовом графике цены. Обычно это различные виды усреднений (очередная точка графика рассчитывается как усреднённое значение некоторого количества предыдущих значений цены, например, скользящая средняя) или отношений (очередная точка является результатом сопоставления некоторого числа предыдущих цен — их разность, производная от изменения за период и т. п., например, индекс относительной силы). Индикаторы наглядно показывают некоторую неочевидную информацию, содержащуюся в статистике изменения цены. Индикаторы имеют минимум один изменяемый параметр, от значения которого могут существенно изменяться внешний вид результата. Индикаторы могут использоваться как отдельно так и в комплексе.',
#   'id': '3517',
#   'qas': [{'id': '36699',
#     'question': 'Какие индикаторы - дополнительные графики, формируемые на основе пересчёта значений, содержащихся в базовом графике цены?',
#     'answers': [{'answer_start': 0, 'text': 'технические'}]}]},
#  {'context': 'Термин кратер принят в планетной номенклатуре — единой системе, однозначно идентифицирующей детали рельефа на поверхности Луны, что позволяет легко опознать и описать эти структуры. Присвоением официального названия, с момента своего основания в 1919 году, занимается Международный астрономический союз (МАС). Несмотря на то что за 360 лет истории лунной номенклатуры были присвоены имена не укладывающиеся в принятую схему, Международным астрономическим союзом приняты следующие правила. Кратеры на Луне, как правило, получают своё название в честь умерших выдающихся учёных, инженеров и исследователей, внёсших значительный, фундаментальный вклад в своей области. Кроме того, кратеры вокруг Моря Москвы названы в честь погибших советских космонавтов, а кратеры вокруг кратера Аполлон названы в честь погибших американских астронавтов. Это правило может быть распространено и для других космических держав, которые потеряют своих космонавтов. Для маленьких кратеров используются только имена, без фамилий (например кратер Борис). Как правило, официальные названия не присваиваются кратерам размером менее 100 метров, кроме случаев, когда такие кратеры представляют исключительный научный интерес. Более подробно — см. статью Планетная номенклатура .',
#   'id': '7013',
#   'qas': [{'id': '4874',
#     'question': 'Когда был основан Международный астрономический союз?',
#     'answers': [{'answer_start': 244, 'text': 'в 1919 году'}]}]},
#  {'context': 'Одним из непищевых применений аскорбиновой кислоты является её использование в качестве проявляющего вещества в фотографии, как в промышленных, так и в самодельных проявителях. В настоящее время большинство производителей фотохимии имеют в своих линейках продукции проявители для фотоплёнок и фотобумаг, в состав которых входят аскорбиновая кислота или аскорбат натрия[10]. Основное достоинство таких проявителей — отсутствие каких-либо вредных воздействий на здоровье человека при контакте с раствором, поскольку многие синтетические проявляющие вещества в той или иной степени токсичны.',
#   'id': '1024',
#   'qas': [{'id': '64257',
#     'question': 'Многие ли вещества входящие в растворители токсичны?',
#     'answers': [{'answer_start': 514,
#       'text': 'Многие синтетические проявляющие вещества.'}]}]},
#  {'context': 'В последнюю пору самостоятельного существования греческого народа, с эпохи Александра Великого и до покорения Греции римлянами, наметился упадок творчества скульпторов. Они не утрачивают ни познаний, ни технического мастерства, унаследованных от прежних ваятелей, даже доводят это мастерство до большей тонкости, но вносят в искусство существенно новых элементов, не открывают для него новых направлений, а только повторяют, комбинируют и видоизменяют старое, заботясь только о воспроизведении впечатления на зрителя колоссальностью размера своих произведений и живописностью сложной группировки фигур, причём произведениям часто свойственны преувеличенный пафос и театральность.',
#   'id': '731',
#   'qas': [{'id': '59439',
#     'question': 'В чем суть упадка творчества скульпторов?',
#     'answers': [{'answer_start': 414,
#       'text': 'Повторяют, комбинируют и видоизменяют старое'}]}]},
#  {'context': 'Альбом 1997 года Earthling получил самые строгие оценки критиков со времён Let’s Dance (1983)[105], звук пластинки представлял собой эксперименты с британским джанглом и драм-н-бэйсом. Синглами с альбома стали композиции Little Wonder и Dead Man Walking ; песня Telling Lies была выпущена в интернете в цифровом варианте. Боуи организован мировой тур в поддержку альбома. Композиция I’m Afraid of Americans вошла в саундтрек к фильму Пола Верховена Шоугёлз , ремикс на эту песню был сделан Трентом Резнором и выпущен в качестве сингла. Постоянная ротация клипа (в котором снялся и Резнор) на музыкальных каналах способствовала 16-недельному пребыванию этой композиции в американском Billboard Hot 100[105]. Альбом был номинирован на премию Грэмми в категории Лучшее альтернативное музыкальное исполнение .',
#   'id': '3470',
#   'qas': [{'id': '57840',
#     'question': 'В какой номинации был представлен альбом Earthling на премию Грэмми?',
#     'answers': [{'answer_start': 758,
#       'text': ' Лучшее альтернативное музыкальное исполнение '}]}]},
#  {'context': 'Существуют также бактерии с весьма специфическим энергетическим метаболизмом. Так, в октябре 2008 года в журнале Science появилось сообщение об обнаружении экосистемы, состоящей из представителей одного единственного ранее неизвестного вида бактерии — Desulforudis audaxviator, которые получают энергию для своей жизнедеятельности из химических реакций с участием водорода, образующегося в результате распада молекул воды под воздействием радиации залегающих вблизи нахождения колонии бактерий урановых руд. Некоторые колонии бактерий, обитающие на дне океана, используют для передачи энергии своим собратьям электрический ток.',
#   'id': '14621',
#   'qas': [{'id': '82204',
#     'question': 'Откуда эти бактерии получают энергию для своей жизнедеятельности?',
#     'answers': [{'answer_start': 331,
#       'text': 'из химических реакций с участием водорода'}]}]},
#  {'context': 'Работы по созданию специальной электрической батареи и электродвигателя, предназначенных для торпед калибра 533 мм, начали в 1932 г. и в Советском Союзе. В течение 1937—1938 гг. было изготовлено две опытовые электрические торпеды ЭТ-45 с электродвигателем мощностью 45 кВт. Она показала неудовлетворительные результаты, поэтому в 1938 г. разрабатывается принципиально новый электродвигатель с вращающимися в разные стороны якорем и магнитной системой, с высоким КПД и удовлетворительной мощностью (80 кВт). Первые образцы новой электрической торпеды изготовили в 1940 г. И хотя германская электрическая торпеда G7e попала в руки и советских инженеров, но те не стали её копировать, а в 1942 г., после проведения государственных испытаний, была принята на вооружение отечественная торпеда ЭТ-80. Пять первых боевых торпед ЭТ-80 поступили на Северный флот в начале 1943 г. Всего во время войны советские подводники израсходовали 16 электрических торпед.',
#   'id': '9909',
#   'qas': [{'id': '72734',
#     'question': 'Какие две торпеды были изготовлены в течение 1937—1938 гг. с электродвигателем мощностью 45 кВт?',
#     'answers': [{'answer_start': 230, 'text': 'ЭТ-45'}]}]},
#  {'context': 'Первые 50 современных школ были созданы на острове в 1903—1904 годах, причем их особенностью было то, что учителя ходили по домам учеников для их консультирования. В 1910 году было введено обязательное обучение детей от 10 до 14 лет. В дальнейшем срок обязательного обучения постепенно увеличивался: 7 лет в 1936 году, 8 лет в 1946 году, 9 лет в 1984 году, 10 лет в 1990 году. На начало 2010-х годов в стране было 213 школ, из которых только 6 были частными. С 1995 года обязательное обучение с 6 до 16 лет. Ныне в школах обязательны для изучения два иностранных языка: датский с 6 класса и английский с 7 класса.',
#   'id': '483',
#   'qas': [{'id': '7656',
#     'question': 'Когда в Исландии появились современные учебные заведения?',
#     'answers': [{'answer_start': 51, 'text': 'в 1903—1904 годах'}]}]},
#  {'context': 'Энергосберегающие режимы работы материнской платы компьютера позволяют переводить его в режим сна, что значительно сокращает уровень потребления компьютером электроэнергии. В режиме гибернации питание ОЗУ отключается. В этом случае для сохранения содержимого ОЗУ операционная система (ОС) перед отключением питания записывает содержимое ОЗУ на устройство постоянного хранения данных (как правило, жёсткий диск). Например, в ОС Windows XP содержимое памяти сохраняется в файл hiberfil.sys, в ОС семейства Unix — на специальный swap-раздел жёсткого диска.',
#   'id': '8020',
#   'qas': [{'id': '17201',
#     'question': 'что в режиме гибернации отключается?',
#     'answers': [{'answer_start': 193, 'text': 'питание ОЗУ'}]}]},
#  {'context': 'Некоторые мембранные белки участвуют в транспорте малых молекул через мембрану клетки, изменяя её проницаемость. Липидный компонент мембраны водонепроницаем (гидрофобен), что предотвращает диффузию полярных или заряженных (ионы) молекул. Мембранные транспортные белки принято подразделять на белки-каналы и белки-переносчики. Белки-каналы содержат внутренние заполненные водой поры, которые позволяют ионам (через ионные каналы) или молекулам воды (через белки-аквапорины) перемещаться через мембрану. Многие ионные каналы специализируются на транспорте только одного иона; так, калиевые и натриевые каналы часто различают эти сходные ионы и пропускают только один из них. Белки-переносчики связывают, подобно ферментам, каждую переносимую молекулу или ион и, в отличие от каналов, могут осуществлять активный транспорт с использованием энергии АТФ. Электростанция клетки — АТФ-синтаза, которая осуществляет синтез АТФ за счёт протонного градиента, также может быть отнесена к мембранным транспортным белкам.',
#   'id': '50',
#   'qas': [{'id': '62421',
#     'question': 'Что содержат белки-каналы?',
#     'answers': [{'answer_start': 348,
#       'text': 'Внутренние заполненные водой поры'}]}]},
#  {'context': 'В Рязани действуют 32 муниципальных учреждения здравоохранения. Один из крупнейших в России медицинских вузов — Рязанский государственный университет имени академика Павлова имеет кафедры и представительства во всех узкоспециализированных медицинских больницах и диспансерах города. Благодаря этому студенты университета получают возможность пройти предварительную квалификационную подготовку на практике, а пациенты медицинских учреждений — получают современное врачебное обслуживание благодаря научным достижениям университета.',
#   'id': '6775',
#   'qas': [{'id': '65677',
#     'question': 'Какой ВУЗ является одним из крупнейших в России медицинских вузов',
#     'answers': [{'answer_start': 112,
#       'text': 'Рязанский государственный университет имени академика Павлова'}]}]},
#  {'context': 'В результате сотрудничества компаний Nikon и Kodak в августе 1994 года была создана гибридная цифровая камера Kodak DCS 410 на основе фотоаппарата Nikon F90, съёмная задняя крышка которого заменялась цифровой приставкой с ПЗС-матрицей разрешением 1,5 мегапикселя. Данные записывались на карту PCMCIA, встроенную в задник. В марте 1998 года на рынке появился первый цифровой зеркальный фотоаппарат Canon EOS D2000 неразъёмной конструкции. Все эти образцы предназначались для фотослужб новостных информационных агентств и стоили от 15 до 30 тысяч долларов. Цена самых дешёвых камер, таких как Canon EOS D30, выпущенного в 2000 году, превышала 2500 долларов, оставаясь неприемлемой для большинства фотографов.',
#   'id': '6925',
#   'qas': [{'id': '64081',
#     'question': 'Какова была цена камеры Canon EOS D30,выпущенной в 2000 году',
#     'answers': [{'answer_start': 631, 'text': 'превышала 2500 долларов'}]}]},
#  {'context': 'Торвальдс начал разработку ядра Linux на MINIX, и перенёс на него ряд приложений. Позже, когда Linux достиг определённой зрелости, появилась возможность продолжать разработку уже на базе самого Linux. Приложения GNU вскоре заменили приложения MINIX, так как код GNU, находящийся в свободном доступе, был более удобен для применения в молодой операционной системе (исходный код под лицензией GNU GPL может быть использован в других проектах, если они также выпускаются под той же или совместимой лицензией, для того чтобы сделать Linux доступным для коммерческого использования, Торвальдс начал переходить от своей первоначальной лицензии на GNU GPL). Разработчики работали над полной интеграцией компонентов GNU с Linux с целью создания полнофункциональной и свободной операционной системы (Linux).',
#   'id': '9774',
#   'qas': [{'id': '4469',
#     'question': 'Торвальдс начал разработку чего',
#     'answers': [{'answer_start': 27, 'text': 'ядра Linux на MINIX'}]}]},
#  {'context': 'В соли, поступающей в продажу, содержание NaCl составляет от 97 % (второй сорт) до 99,7 % (экстра), остальная доля приходится на различные примеси (сульфат натрия, хлорид калия и др.), а также зачастую добавки. Чаще всего добавляют йодиды и карбонаты, а в последние годы фториды. Добавка фторидов используется для профилактики зубных заболеваний. С 1950-х годов добавлять фторид в соль стали в Швейцарии, и благодаря положительным результатам в борьбе с кариесом в 1980-х годах фторид стали добавлять в соль во Франции и в Германии. До 60 % продаваемой соли в Германии и до 80 % в Швейцарии содержит фториды.',
#   'id': '12719',
#   'qas': [{'id': '8694',
#     'question': 'Для чего используется добавка фторидов в соль?',
#     'answers': [{'answer_start': 310,
#       'text': 'для профилактики зубных заболеваний'}]}]},
#  {'context': 'Тривиальная номенклатура. В популярной и научной литературе можно нередко встретить исторические, или тривиальные, названия спиртов, которые вследствие сложившейся традиции используются вместо систематических названий. Тривиальные названия обычно происходят от названия природного источника получения того или иного спирта. Так, например, метанол называют древесным спиртом, этанол — винным спиртом, гераниол содержится в гераниевом масле, а цетиловый спирт ранее получали из жира кашалотов (лат. cetus — кит). Некоторые спирты получили тривиальные названия из-за своих физических свойств (глицерин от др.-греч. glykeros, сладкий). Спирты, производные от природных углеводов, сохраняют корень тривиального названия соответствующих углеводов (маннит, ксилит, сорбит).',
#   'id': '12927',
#   'qas': [{'id': '2432',
#     'question': 'Какие названия можно использовать для спиртов?',
#     'answers': [{'answer_start': 84,
#       'text': 'исторические, или тривиальные'}]}]},
#  {'context': 'Известным современным музыкантом и композитором шотландского происхождения является уроженец Глазго основатель и лидер рок-группы Dire Straits Марк Нопфлер, ныне занимающийся сольными проектами. Группы Nazareth, Alestorm, Mogwai, The FRATELLIS, Simple Minds, Franz Ferdinand тоже родом из Шотландии. Известная панк-группа The Exploited родом из Шотландии. Самой известной шотландской альтернативной группой является Primal Scream. Музыканты легендарной австралийской группы AC/DC Ангус и Малколм Янги, а также ныне покойный Бон Скотт — шотландцы по национальности и уроженцы Шотландии.',
#   'id': '1402',
#   'qas': [{'id': '7004',
#     'question': 'Какие группы тоже родом из Шотландии?',
#     'answers': [{'answer_start': 195,
#       'text': 'Группы Nazareth, Alestorm, Mogwai, The FRATELLIS, Simple Minds, Franz Ferdinand'}]}]},
#  {'context': 'Чтобы облегчить и автоматизировать процесс внесения исправлений, Ларри Уолл в 1984 году разработал утилиту patch ( заплатка ), которая в формализованном (но хорошо понятном человеку) виде описывает операции редактирования, которые нужно произвести, чтобы получить новую версию текста. С появлением этой утилиты пользователь, обнаруживший и исправивший ошибку в программе, мог прислать автору небольшую заплатку, по которой автор мог понять, какие изменения предлагаются, и автоматически приложить их к своему исходному тексту. С появлением утилиты patch гораздо больше пользователей стало включаться в разработку программ с доступным исходным текстом, немалую роль и здесь сыграла сеть Usenet. В конце концов, данный способ исправления стал общеупотребительным и применяющимся не только к исходному коду программы, но и непосредственно к скомпилированному исполнимому коду в случае закрытого ПО, а слово патч стало нарицательным. Патчи (файлы-заплатки с исправлениями) — обязательный атрибут сегодняшней разработки любых программ любой сложности.',
#   'id': '8557',
#   'qas': [{'id': '26429',
#     'question': 'Кто разработал утилиту patch ( заплатка )?',
#     'answers': [{'answer_start': 65, 'text': 'Ларри Уолл'}]}]},
#  {'context': '15-го июля во время разведки к востоку or Золотой Липы лётчики 2-го Сибирского Корпусного Авиаотряда поручик Покровский и корнет Плонский заметили неприятельский аэроплан. Из оружия у них были только пистолеты Маузер. Несмотря на это, они атаковали противника и после непродолжительной перестрелки вынудили его опуститься. Австрийский аэроплан Авиатик (бортовой номер 31-13) достался призом в совершенно неповреждённом состоянии вместе с двумя лётчиками из 7-й авиароты. Оба русских героя были награждены орденами Св. Георгия 4-й степени.',
#   'id': '3819',
#   'qas': [{'id': '31929',
#     'question': 'Кто увидел вражеский аэроплан во время розведки?',
#     'answers': [{'answer_start': 55, 'text': 'лётчики'}]}]},
#  {'context': 'Центральное понятие концепции естественного отбора — приспособленность организмов. Приспособленность определяется как способность организма к выживанию и размножению, которая определяет размер его генетического вклада в следующее поколение. Однако главным в определении приспособленности является не общее число потомков, а число потомков с данным генотипом (относительная приспособленность). Например, если потомки успешного и быстро размножающегося организма слабые и плохо размножаются, то генетический вклад и, соответственно, приспособленность этого организма будут низкими.',
#   'id': '11017',
#   'qas': [{'id': '54643',
#     'question': 'Каким уровнем генетического вклада можно оценить организм, потомство которого слабо и плохо размножаеться?',
#     'answers': [{'answer_start': 571, 'text': 'низкими'}]}]},
#  {'context': 'Вирусный геном может быть кольцевым, как у полиомавирусов, или линейным, как у аденовирусов. Форма генома не зависит от типа нуклеиновой кислоты. У многих РНК-содержащих вирусов и некоторых ДНК-содержащих вирусов геном часто представлен несколькими молекулами (частями), в связи с чем он называется сегментированным. У РНК-содержащих вирусов каждый сегмент часто кодирует только один белок, и обычно эти сегменты упаковываются в один капсид. Однако присутствие всех сегментов не всегда обязательно для инфекционности вируса, как это демонстрируют вирус мозаики костра и некоторые другие вирусы растений.',
#   'id': '14427',
#   'qas': [{'id': '1313',
#     'question': 'Зависит ли форма генома от типа нуклеиновой кислоты?',
#     'answers': [{'answer_start': 106, 'text': 'не зависит'}]}]},
#  {'context': 'Первоначально создание программного обеспечения для компьютеров было в первую очередь академическим занятием. Для специалистов в области компьютерной науки каждая программа представляла собой результат научного исследования, в некотором смысле аналогичный публикации статьи. Это означает, что исходный текст программы был обязательно доступен всему научному сообществу, поскольку любой научный результат должен быть верифицируем, то есть подтверждаться другими исследователями и быть открытым для критики. Таким образом, процесс разработки программного обеспечения более принципиально схож с научным процессом: учёный брал существующие программы, исправлял их в соответствии со своими идеями и публиковал исправленные программы — новый результат.',
#   'id': '10475',
#   'qas': [{'id': '17257',
#     'question': 'Каким должен быть научный результат?',
#     'answers': [{'answer_start': 484, 'text': 'открытым для критики'}]}]},
#  {'context': 'Чешуекрылые являются весьма разнообразными, а большинство их видов плохо изученными. Некоторые из описанных видов известны по находкам из одной-единственной местности либо даже по единственному экземпляру. Истинная оценка общего количества существующих видов никогда не будет известна, потому что многие виды вымерли ещё до их обнаружения. Систематика бабочек, представленная в различных работах, отражает различные взгляды их авторов и является, вне всякого сомнения, дискуссионной. Имеются споры, посвященные систематическому положению или необходимости сохранения статуса некоторых подвидов или видов. Исследования ДНК свидетельствуют, что некоторые из известных в настоящее время видов должны быть разделены. Хорошо известным примером является случай, когда на первый взгляд идентичные Colias alfacariensis и Colias hyale, ранее считавшиеся одним видом, были разделены на два, после того как были обнаружены существенные различия в строении их гусениц и куколок.',
#   'id': '10636',
#   'qas': [{'id': '66927',
#     'question': 'Когда будет известна истинная оценка общего количества существующих видов чешуекрылых?',
#     'answers': [{'answer_start': 259, 'text': 'никогда'}]}]},
#  {'context': 'Железнодорожный путь направляет гребень железнодорожного колеса, сохраняя направление движения вагона без дополнительного трения, позволяя, таким образом, делать более длинные поезда, чем возможно на автомобильных дорогах. Рельсы и шпалы обычно кладут на балластную призму, которая распределяет вес со шпал на грунт для избежания сгибания пути при просадке земли от веса проходящих поездов. Вышеперечисленное относится к верхнему строению пути, которое обычно укладывается на земляное полотно, относящееся к нижнему строению пути и расположенное в границах полосы отвода железных дорог.',
#   'id': '7078',
#   'qas': [{'id': '67957',
#     'question': 'На что укладывается верхнее строение пути?',
#     'answers': [{'answer_start': 476, 'text': 'земляное полотно'}]}]},
#  {'context': 'Помимо всего прочего, Кёльн является ещё и крупнейшим музейно-выставочным центром. По числу картинных галерей он занимает второе место в мире, после Нью-Йорка. В Музее Вальрафа-Рихарца хранится великолепное собрание картин от Средневековья до начала XX века, в том числе таких мастеров, как Лохнер, Рембрандт, Рубенс, ван Гог, Ренуар. Другие известные музеи Кёльна — Римско-германский музей, Городской музей, Музей Шнютген (церковное искусство), Музей восточно-азиатского искусства, Музей Людвига (одно из самых значительных собраний современного искусства в мире) и Музей духо́в в Доме Фарина, где 300 лет назад была создана знаменитая Кёльнская вода — одеколон. В церкви Святой Цецилии располагается музей средневекового искусства (de: Museum Schnütgen), носящий имя члена соборного капитула Кёльнского архиепископства Александра Шнютгена (de: Alexander Schnütgen), подарившего Кёльну в 1906 году свою коллекцию, которая и стала основой музейной экспозиции. Имеются также музеи шоколада, спорта, пива и этнографический музей. Кроме того, в городе существуют зоопарк, террариум и парк-оранжерея экзотических растений ( Флора ).',
#   'id': '82',
#   'qas': [{'id': '38053',
#     'question': 'Чем, помимо всего прочего, является Кёльн?',
#     'answers': [{'answer_start': 43,
#       'text': 'Крупнейшим музейно-выставочным центром.'}]}]},
# ...
#  {'context': 'В XX веке библиотекари столкнулись с проблемой отслеживания того множества книг, которое каждый год выпускалось по всему миру. В связи с этим Международная федерация библиотечных ассоциаций и учреждений разработала несколько инструментов для решения данной проблемы, и в том числе — международное стандартное библиографическое описание (ISBD). В соответствии с ним, каждому изданию присваивается международный стандартный книжный номер — ISBN. ISBN, соответственно, является уникальным идентификатором для каждого издания книги, произведённого в любой стране мира, если издатель принимает этот стандарт. Поддержкой системы занимается специальное сообщество ISBN. Идентификатор состоит из четырёх частей[K 7]:',
#   'id': '13222',
#   'qas': [{'id': '53743',
#     'question': 'Чем является ISBN. для каждого издания книги в любой стране, при условии принятия издателем этого стандарта?',
#     'answers': [{'answer_start': 475,
#       'text': 'Уникальным идентификатором.'}]}]},
#  {'context': '* Советские пять фильмов о Шерлоке Холмсе (1979—1986), главные роли в которых исполнили Василий Ливанов и Виталий Соломин, признаются одной из лучших постановок в кино даже англичанами, а актёрскую пару Ливанов-Соломин английские критики называли лучшей континентальной парой актёров, когда-либо игравших Холмса и Ватсона .[источник?] С 23 февраля 2006 года можно говорить и о государственном уровне этого признания — Василий Ливанов награждён орденом Британской империи[19]. На основе фильма в 2000 году был снят телесериал Воспоминания о Шерлоке Холмсе с обрамляющим сюжетом о Конан Дойле, но популярности он не завоевал, а запомнился судебными разбирательствами за право показа[20].',
#   'id': '3571',
#   'qas': [{'id': '63993',
#     'question': 'Какое название носит телесериал, снятый по мотивам фильма о Шерлоке Холмсе?',
#     'answers': [{'answer_start': 524,
#       'text': ' Воспоминания о Шерлоке Холмсе '}]}]},
#  {'context': 'Владение было расположено на Малых Антильских островах. В состав Нидерландских Антильских островов входили острова из архипелага Подветренных островов: Кюрасао, Бонайре — южная группа — и северная группа из Наветренных: Саба, Синт-Эстатиус и южная часть острова Святого Мартина (северная часть острова контролируется Францией). Общая площадь 800 км². Остров Аруба, также входивший в южную группу, в 1986 году вышел из федерации Антильских островов и получил статус территории Королевства Нидерландов с внутренним самоуправлением.',
#   'id': '13176',
#   'qas': [{'id': '9113',
#     'question': 'В каком году остров Аруба вышел из федерации Антильских островов и получил статус территории Королевства Нидерландов',
#     'answers': [{'answer_start': 397, 'text': 'в 1986 году'}]}]},
#  {'context': 'С середины XVI века также европейские учёные начали проявлять интерес к армянскому языку, однако изучение армянского языка в Европе берёт начало с первой половины XVII века. Именно с этого столетия история армянского языкознания вступает в новый исторический период, называемый латинизированный армянский из-за искусственно введённых грамматиками латинских форм выражения. Но, несмотря на это, этот период стал важным шагом в истории армянской лингвистической мысли. Учёные описывали почти весь строй армянского языка; ещё глубже вникали в его особенности.',
#   'id': '3430',
#   'qas': [{'id': '509',
#     'question': 'Что описывали учёные латинизированный армянский период?',
#     'answers': [{'answer_start': 484,
#       'text': 'Почти весь строй армянского языка'}]}]},
#  {'context': 'По мере накопления опыта поддержки ликвидности банковского сектора взгляды экономистов на функцию кредитора последней инстанции претерпевали изменения. Эволюция взглядов находилась под влиянием потребностей центрального банка. Во-первых, совмещение политики управления денежным предложением и процентными ставками с функцией кредитора последней инстанции, что вело к слиянию обоих видов деятельности. Во-вторых, оказание индивидуальной финансовой поддержки крупнейшим банкам в условиях отсутствия общего кризиса ликвидности или банковской паники. Сохранение на плаву крупнейших банков было обусловлено негативными сетевыми эффектами, который возникли бы в отсутствие поддержки кредитора последней инстанции. Как следствие, возникло отклонение от первоначальной классической концепции, предполагавшей, что последняя инстанция кредитует неплатежеспособные, однако кредитоспособные банки. Эволюция взглядов на кредитора последней инстанции привела к формированию двух подходов: выполнение функции по отношению к рынку в целом (мезокредитор последней инстанции) и на индивидуальной основе (микрокредитор последней инстанции).',
#   'id': '3632',
#   'qas': [{'id': '25336',
#     'question': 'Пол влиянием чего находилась эволюция взглядов?',
#     'answers': [{'answer_start': 194,
#       'text': 'потребностей центрального банка'}]}]},
#  {'context': 'После этого Хендрикс играл с несколькими местными сиэтлскими группами. Первой его группой была The Velvetones. Вскоре он был приговорён к 2 годам заключения за угон машины. Но его адвокат смог изменить приговор на 2 года службы в армии, в 101-й воздушно-десантной дивизии. Меньше чем через год Хендрикс был демобилизован из-за травмы, полученной при прыжке с парашютом. В армии Хендрикса характеризовали как очень плохого солдата: он постоянно спал на посту, ему нельзя было поручить ни одного дела. По словам одного из офицеров, у него не было ни одного положительного качества .',
#   'id': '12290',
#   'qas': [{'id': '30013',
#     'question': 'За что Хендрикс был приговорен к 2 годам заключения',
#     'answers': [{'answer_start': 157, 'text': 'за угон машины'}]}]},
#  {'context': 'В 1512—1797 годах под контролем Граубюндена находилась Вальтеллина — плодородная и стратегически важная область на севере Италии. Во время Тридцатилетней войны (1618—1648) Граубюнден вёл продолжительную борьбу за Вальтеллину с Испанией и Габсбургами. Французская революция снова застала борьбу партий. В 1797 году по преимуществу итальянское население этой области при содействии войск революционной Франции (в ходе первого итальянского похода Наполеона Бонапарта) восстало, после чего Вальтеллина была присоединена к созданной французами Цизальпинской республике.',
#   'id': '11116',
#   'qas': [{'id': '82536',
#     'question': 'под чьим контролем была Вальтеллину в 1512-1797 годах?',
#     'answers': [{'answer_start': 18, 'text': 'под контролем Граубюндена'}]}]},
#  {'context': 'Члены Федерального совета и канцлер избираются на совместном заседании обеих палат парламента на срок его полномочий, то есть 4 года. Каждый год парламент назначает президента конфедерации и вице-президента из числа членов Совета, без права переназначения на следующий год. На практике федеральные советники практически всегда переизбираются, так что состав Совета может оставаться неизменным в течение нескольких сроков полномочий парламента, и по обычаю пост президента занимают поочередно все члены Совета.',
#   'id': '6923',
#   'qas': [{'id': '28016',
#     'question': 'Кто по обычаю занимает пост президента?',
#     'answers': [{'answer_start': 481,
#       'text': 'поочередно все члены Совета'}]}]},
#  {'context': 'Во время Средневековья в Европе появляются и первые учебники по борьбе. Так, в 1443 году вышла Фехтовальная книга Ганса Талхоффера, содержащая в том числе и разделы, посвященные борьбе, которые содержали отсылки на более ранние издания, не сохранившиеся до наших дней: 1388 года Карла Лихтенауэра и книги 13 века некоего мастера Отто — первого известного пособия исключительно по борьбе. В 1511 году вышла книга Борьба Ганса Вурма. В 1512 году вышла Книга фехтования Альбрехта Дюрера, с его же рисунками, содержащая 120 борцовских приёмов, впрочем не отличавшихся от ранее известных. В 1539 году вышла книга Искусство борьбы. 85 приёмов Ф. Ауэрсвальда.[19].[20] Естественно, что книги были доступны лишь высоким слоям общества; низкие слои продолжали культивировать свои национальные виды.',
#   'id': '6568',
#   'qas': [{'id': '4308',
#     'question': 'В каком году вышла Фехтовальная книга Ганса Талхоффера, в которой были разделы о борьбе?',
#     'answers': [{'answer_start': 77, 'text': 'в 1443 году'}]}]},
#  {'context': 'Первая из его опубликованных работ — повесть Детство , 1852 год. Первая прижизненная изданная книга писателя — Военные рассказы графа Л. Н. Толстого 1856 год, Санкт-Петербург; в том же году вышла и его вторая книга Детство и отрочество . Последнее художественное произведение, напечатанное при жизни Толстого — художественный очерк Благодарная почва , посвящённый встрече Толстого с молодым крестьянином в Мещерском 21 июня 1910 года; очерк впервые был опубликован в 1910 году в газете Речь . За месяц до своей смерти Лев Толстой работал над третьим вариантом повести Нет в мире виноватых .',
#   'id': '7304',
#   'qas': [{'id': '59180',
#     'question': 'Над каким произведением Лев Толстой работал за месяц до своей смерти ?',
#     'answers': [{'answer_start': 538,
#       'text': 'над третьим вариантом повести Нет в мире виноватых '}]}]},
#  {'context': 'Запасы, управляемые поставщиком (ЗУП) (англ. Vendor-managed inventory, VMI) — это ряд бизнес-подходов и моделей, при которых покупатель (клиент) предоставляет определённую информацию поставщику товара или ряда товаров, а поставщик принимает на себя полную ответственность за поддержание уровня запасов этих товаров на складе или в торговой точке клиента. Стороны предварительно согласовывают уровень сервиса и размеры запасов. Как правило, в соглашение о введении системы ЗУП (VMI) входит также перенос от покупателя к поставщику ответственности за представленность и мерчендайзинг товара в торговых точках. К двустороннему соглашению между поставщиком и покупателем часто привлекаются третьи стороны — компании, которые занимаются контрактной логистикой по требованию и за счет одной из сторон.',
#   'id': '1811',
#   'qas': [{'id': '77329',
#     'question': 'Как расшифровыется аббревиатура ЗУП?',
#     'answers': [{'answer_start': 0,
#       'text': 'Запасы, управляемые поставщиком'}]}]},
#  {'context': 'Также нужно учитывать передачу тепла из-за конвекции молекул и излучения. Например, при полной нетеплопроводности вакуума, тепловая энергия передаётся излучением (Солнце, инфракрасные теплогенераторы). В газах и жидкостях происходит перемешивание разнотемпературных слоёв естественным путём или искусственно (примеры принудительного перемешивания — фены, электрочайники). Также в конденсированных средах возможно перепрыгивание фононов из одного твердого тела в другое через субмикронные зазоры, что способствует распространению звуковых волн и тепловой энергии, даже если зазоры представляют собой идеальный вакуум.',
#   'id': '11244',
#   'qas': [{'id': '49108',
#     'question': 'В каких средах происходит естественное перемешивание слоев?',
#     'answers': [{'answer_start': 202, 'text': 'В газах и жидкостях.'}]}]},
#  {'context': 'Человеческий мозг воспринимает внешний мир через чувства, а на каждого отдельного человека сильно влияет его или её собственный опыт, что ведёт к субъективному взгляду на существование и на течение времени. Обычно говорят, что люди обладают сознанием, самосознанием, умом — всё это так или иначе соответствует процессам мышления. Также говорят о таких качествах как самоосознанность, чувствительность, мудрость и о способностях воспринимать отношение с самим собой и с окружающей средой. Насколько мысленные конструкции человека или его опыт соответствуют объективности внешнего физического мира — вопрос дебатов, а также того, что именно подразумевать под вышеперечисленными терминами, и насколько корректно в принципе их использование.',
#   'id': '10310',
#   'qas': [{'id': '3349',
#     'question': 'Какие способности есть у людей?',
#     'answers': [{'answer_start': 428,
#       'text': 'Воспринимать отношение с самим собой и с окружающей средой'}]}]},
#  {'context': 'Возрастает также информационная роль блогов как своеобразной альтернативы официальным СМИ[16]. Так, во время войны в Ираке появились блоги американских солдат[17][18][19], сообщавших о том, что в действительности происходило на театре военных действий, а также их знакомых и родных, которые стали размещать солдатские письма с описанием происходящего. Эти блоги нанесли мощный удар по пропаганде администрации США. Самым известным блогером, писавшим о войне в Ираке, стал пехотинец Колби Баззел. Его блог Колби Баззел посылает войну на… [20] приобрёл огромную популярность. Когда Баззел вернулся домой, его пригласили на работу в журнал Esquire, а в 2007 году он получил престижную премию Lulu Blooker Prize за свою книгу Моя война: убивая время в Ираке .',
#   'id': '651',
#   'qas': [{'id': '74079',
#     'question': 'Как назывался блог Колби Баззела?',
#     'answers': [{'answer_start': 504,
#       'text': ' Колби Баззел посылает войну на… '}]}]},
#  {'context': 'Качественное изменение преподавания политики произошло во второй половине XIX века во многом благодаря развитию социологии и методологии позитивизма. В европейских и северо-американских университетах появились кафедры и даже факультеты политических наук. Первой в 1857 году была открыта кафедра истории и политической науки в Колумбийском университете (США, 1857). Также были открыты Академия нравственных и политических наук в Мадриде (Испания, 1861), Свободная школа политических наук в Париже (Франция, 1871), Школа политической науки в Колумбии (США, 1880), Общество государствоведения в Берлине (Германия, 1883), Лондонская школа экономических и политических наук (Великобритания, 1895).',
#   'id': '1728',
#   'qas': [{'id': '78086',
#     'question': 'Где появились кафедры и даже факультеты политических наук?',
#     'answers': [{'answer_start': 150,
#       'text': 'В европейских и северо-американских университетах.'}]}]},
#  {'context': 'Высшим воплощением абсурда, по Камю, являются разнообразные попытки насильственного улучшения общества — фашизм, сталинизм и т. п. Будучи гуманистом и антиавторитарным социалистом, он полагал, что борьба с насилием и несправедливостью их же методами могут породить только ещё большие насилие и несправедливость, но, отвергая понимание бунта, не признающего за ним положительных аспектов, в эссе Бунтующий человек рассматривает бунт как способ солидарности с другими людьми и философию меры, определяющую и согласие, и несогласие с существующими реалиями; перефразируя картезианскую максиму в я бунтую, следовательно мы существуем [16]. Камю выделяет две формы проявления бунтарства: первая выражена в революционной деятельности, вторая, которой он отдаёт предпочтение, в творчестве[4]. Вместе с тем, он оставался в пессимистической уверенности, что несмотря на положительную роль бунта в истории, окончательно победить зло невозможно[4].',
#   'id': '12004',
#   'qas': [{'id': '45690',
#     'question': 'Что по мнению Камю борьба с насилием и несправедливостью их же методами могут породить?',
#     'answers': [{'answer_start': 272,
#       'text': 'ещё большие насилие и несправедливость'}]}]},
#  {'context': 'Нижний (кембрийско-вендский) и верхний (кембрийско-ордовикский) ярусы подземных вод прибалтийского артезианского бассейна разделены мощной толщей кембрийских глин. По размерам бассейн относится к числу крупнейших в Европе. На питание пресных подземных вод здесь расходуется в среднем от 5 до 30 % атмосферных осадков; их естественный годовой ресурс оценивается в 16,8 км³. Среднемноголетний подземный сток колеблется, расчёте на 1 км², от 1,5—1,7 л/сек в сильно трещиноватых и закарстованных известняках силура и ордовика до 0,5 л/сек в палеогеновых и кембрийско-ордовикских водоносных комплексах со слабой водопроводимостью и затруднённым инфильтрационным питанием. С учётом этих различий подземный сток в процентах к речному колеблется между 15—20 % и 50—60 %, достигая 70 % на силурийском и ордовикском плато в бассейне реки Мяркис.',
#   'id': '12945',
#   'qas': [{'id': '78282',
#     'question': 'Как иначе называется нижний ярус подземных вод прибалтийского артезианского бассейна?',
#     'answers': [{'answer_start': 8, 'text': 'кембрийско-вендский'}]}]},
#  ...]

# %%
records = []
for r in tqdm(dataset):
    for q in r['qas']:
        question = q['question']
        for a in q['answers']:
            answer = a['text']
            records.append(Record(r['context'], question, answer))
# Out:
#   0%|          | 0/5036 [00:00<?, ?it/s]

# %%
records[7].micro
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14298/269963382.py in <module>
# ----> 1 records[7].micro
#
# NameError: name 'records' is not defined

# %%
parser = deeppavlov.build_model("ru_syntagrus_joint_parsing", download=False)
# Out:
# 2022-09-29 00:20:21.160 INFO in 'deeppavlov.core.common.file'['file'] at line 32: Interpreting 'ru_syntagrus_joint_parsing' as '/data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/configs/syntax/ru_syntagrus_joint_parsing.json'
# [nltk_data] Downloading package punkt to /home/admin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/admin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     /home/admin/nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /home/admin/nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/bert_dp/tokenization.py:125: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
# 2022-09-29 00:20:23.572 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /data/home/admin/.deeppavlov/models/morpho_ru_syntagrus/tag.dict]
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:37: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:222: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:222: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:193: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:236: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# 2022-09-29 00:20:23.594606: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-09-29 00:20:23.599703: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2195105000 Hz
# 2022-09-29 00:20:23.599852: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x597b2a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-09-29 00:20:23.599870: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-09-29 00:20:23.602032: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:314: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/bert_dp/modeling.py:178: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/bert_dp/modeling.py:418: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/bert_dp/modeling.py:499: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# 2022-09-29 00:20:23.852776: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-29 00:20:23.853052: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5a936a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-09-29 00:20:23.853068: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2022-09-29 00:20:23.853217: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-29 00:20:23.853354: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:01:00.0
# 2022-09-29 00:20:23.853609: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-09-29 00:20:23.854792: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-09-29 00:20:23.855829: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-09-29 00:20:23.856097: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-09-29 00:20:23.857444: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-09-29 00:20:23.858571: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-09-29 00:20:23.862519: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-09-29 00:20:23.862640: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-29 00:20:23.862844: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-29 00:20:23.862964: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2022-09-29 00:20:23.863013: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-09-29 00:20:23.863303: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-09-29 00:20:23.863326: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2022-09-29 00:20:23.863333: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2022-09-29 00:20:23.863441: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-29 00:20:23.863601: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-29 00:20:23.863745: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10487 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/bert_dp/modeling.py:366: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/bert_dp/modeling.py:680: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/bert_dp/modeling.py:283: The name tf.erf is deprecated. Please use tf.math.erf instead.
#
# WARNING:tensorflow:Variable *= will be deprecated. Use `var.assign(var * other)` if you want assignment to the variable value or `x = x * y` if you want a new python Tensor object.
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:75: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:571: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:131: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:131: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:244: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:249: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2022-09-29 00:20:39.704 INFO in 'deeppavlov.core.models.tf_model'['tf_model'] at line 51: [loading model from /data/home/admin/.deeppavlov/models/morpho_ru_syntagrus/model]
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:54: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# INFO:tensorflow:Restoring parameters from /data/home/admin/.deeppavlov/models/morpho_ru_syntagrus/model
# 2022-09-29 00:20:41.129 WARNING in 'deeppavlov.core.models.serializable'['serializable'] at line 52: No load path is set for UDPymorphyLemmatizer!
# 2022-09-29 00:20:41.482 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /data/home/admin/.deeppavlov/models/syntax_ru_syntagrus/deps.dict]
# 2022-09-29 00:20:41.498643: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-29 00:20:41.498839: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:01:00.0
# 2022-09-29 00:20:41.498891: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-09-29 00:20:41.498910: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-09-29 00:20:41.498926: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-09-29 00:20:41.498942: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-09-29 00:20:41.498958: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-09-29 00:20:41.498989: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-09-29 00:20:41.499007: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-09-29 00:20:41.499067: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-29 00:20:41.499237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-29 00:20:41.499339: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2022-09-29 00:20:41.499366: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-09-29 00:20:41.499372: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2022-09-29 00:20:41.499377: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2022-09-29 00:20:41.499474: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-29 00:20:41.499625: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-29 00:20:41.499772: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10487 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/core/layers/tf_layers.py:161: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/core/layers/tf_layers.py:181: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/tensorflow_core/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /data/home/admin/bachelor/env/lib/python3.7/site-packages/deeppavlov/core/layers/tf_layers.py:185: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
# 2022-09-29 00:20:59.39 INFO in 'deeppavlov.core.models.tf_model'['tf_model'] at line 51: [loading model from /data/home/admin/.deeppavlov/models/syntax_ru_syntagrus/model_joint]
# INFO:tensorflow:Restoring parameters from /data/home/admin/.deeppavlov/models/syntax_ru_syntagrus/model_joint

# %%
res = parser([records[i].question for i in range(1, 10)])

# %%
def get_tree(conllu_output):
    tree = Conllu(filehandle=StringIO(conllu_output)).read_tree()
    return tree

def get_trees(conllu_output):
    tree = Conllu(filehandle=StringIO('\n\n'.join(conllu_output))).read_trees()
    return tree

def write_tree(conllu_output):
    tree = get_tree(conllu_output)
    writer = TextModeTrees(attributes="ord,form,lemma,upos,deprel,parent,feats")
    writer.process_tree(tree)

# %% [markdown]
# ### Интересные вопросы

# %%
write_tree(*parser(['Каким уровнем генетического вклада можно оценить организм, потомство которого слабо и плохо размножаеться?']))
# Out:
# # sent_id = ?
# # text = Каким уровнем генетического вклада можно оценить организм , потомство которого слабо и плохо размножаеться ?
# ─┮
#  │                                                   ╭─╼ 1 Каким какой DET det <?#2, уровнем> Case=Ins|Gender=Masc|Number=Sing
#  │                                                 ╭─┾ 2 уровнем уровень NOUN obl <?#6, оценить> Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing
#  │                                                 │ │ ╭─╼ 3 генетического генетический ADJ amod <?#4, вклада> Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
#  │                                                 │ ╰─┶ 4 вклада вклад NOUN nmod <?#2, уровнем> Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#  ╰─┮ 5 можно можно ADV root <?, <ROOT>> Degree=Pos │
#    ┡───────────────────────────────────────────────┾ 6 оценить оценить VERB csubj <?#5, можно> Aspect=Perf|VerbForm=Inf|Voice=Act
#    │                                               ╰─┮ 7 организм организм NOUN obj <?#6, оценить> Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
#    │                                                 │ ╭─╼ 8 , , PUNCT punct <?#14, размножаеться> _
#    │                                                 │ ┢─┮ 9 потомство потомство NOUN nsubj <?#14, размножаеться> Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing
#    │                                                 │ │ ╰─╼ 10 которого который PRON nmod <?#9, потомство> Case=Gen
#    │                                                 │ ┢─┮ 11 слабо слабый ADJ advmod <?#14, размножаеться> Degree=Pos|Gender=Neut|Number=Sing|Variant=Short
#    │                                                 │ │ │ ╭─╼ 12 и и CCONJ cc <?#13, плохо> _
#    │                                                 │ │ ╰─┶ 13 плохо плохо ADV conj <?#11, слабо> Degree=Pos
#    │                                                 ╰─┶ 14 размножаеться размножаеться VERB acl:relcl <?#7, организм> Aspect=Perf|VerbForm=Inf|Voice=Mid
#    ╰─╼ 15 ? ? PUNCT punct <?#5, можно> _

# %%
write_tree(*parser(['Какова была цена камеры Canon EOS D30,выпущенной в 2000 году?']))
# Out:
# # sent_id = ?
# # text = Какова была цена камеры Canon EOS D30 , выпущенной в 2000 году ?
# ─┮
#  ╰─┮ 1 Какова каков ADJ root <?, <ROOT>>
#    ┡─╼ 2 была быть AUX cop <?#1, Какова>
#    ┡─┮ 3 цена цена NOUN nsubj <?#1, Какова>
#    │ ╰─┮ 4 камеры камера NOUN nmod <?#3, цена>
#    │   ┡─╼ 5 Canon canon PROPN flat:foreign <?#4, камеры>
#    │   ┡─╼ 6 EOS eos PROPN flat:foreign <?#4, камеры>
#    │   ┡─╼ 7 D30 d30 PROPN flat:foreign <?#4, камеры>
#    │   │ ╭─╼ 8 , , PUNCT punct <?#9, выпущенной>
#    │   ╰─┾ 9 выпущенной выпустить VERB acl <?#4, камеры>
#    │     │ ╭─╼ 10 в в ADP case <?#12, году>
#    │     │ ┢─╼ 11 2000 2000 NUM nummod <?#12, году>
#    │     ╰─┶ 12 году год NOUN obl <?#9, выпущенной>
#    ╰─╼ 13 ? ? PUNCT punct <?#1, Какова>

# %% [markdown]
# Еще интересен ответ `никогда`
#
# `Question: На что укладывается верхнее строение пути?
# Answer: земляное полотно`

# %%
write_tree(*parser(['Чем, помимо всего прочего, является Кёльн?']))
# Out:
# # sent_id = ?
# # text = Чем , помимо всего прочего , является Кёльн ?
# ─┮
#  │ ╭─┮ 1 Чем чем PRON obl <?#7, является>
#  │ │ ╰─╼ 2 , , PUNCT punct <?#1, Чем>
#  │ │                                         ╭─╼ 3 помимо помимо ADP case <?#5, прочего>
#  │ ┢─╼ 4 всего весь PRON obl <?#7, является> │
#  │ ┢─────────────────────────────────────────┾ 5 прочего прочее ADJ parataxis <?#7, является>
#  │ │                                         ╰─╼ 6 , , PUNCT punct <?#5, прочего>
#  ╰─┾ 7 является являться VERB root <?, <ROOT>>
#    ┡─╼ 8 Кёльн кёльна PROPN nsubj <?#7, является>
#    ╰─╼ 9 ? ? PUNCT punct <?#7, является>

# %%
write_tree(*parser(['Каким должен быть научный результат?']))
# Out:
# # sent_id = ?
# # text = Каким должен быть научный результат ?
# ─┮
#  │ ╭───────────────────────────────────────┮ 1 Каким какой DET det <?#2, должен>
#  ╰─┾ 2 должен должный ADJ root <?, <ROOT>> │
#    │                                       ╰─╼ 3 быть быть AUX cop <?#1, Каким>
#    │ ╭─╼ 4 научный научный ADJ amod <?#5, результат>
#    ┡─┶ 5 результат результат NOUN nsubj <?#2, должен>
#    ╰─╼ 6 ? ? PUNCT punct <?#2, должен>

# %%
write_tree(*parser(['Что сообщал Моцарт о Констанции в письме 15 декабря 1781 года ее отцу?']))
# Out:
# # sent_id = ?
# # text = Что сообщал Моцарт о Констанции в письме 15 декабря 1781 года ее отцу ?
# ─┮
#  │ ╭─╼ 1 Что что PRON obj <?#2, сообщал> Case=Acc
#  ╰─┾ 2 сообщал сообщать VERB root <?, <ROOT>> Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
#    ┡─╼ 3 Моцарт моцарт PROPN nsubj <?#2, сообщал> Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
#    │ ╭─╼ 4 о о ADP case <?#5, Констанции> _
#    ┡─┶ 5 Констанции констанция PROPN obl <?#2, сообщал> Animacy=Anim|Case=Loc|Gender=Fem|Number=Sing
#    │ ╭─╼ 6 в в ADP case <?#7, письме> _
#    ┡─┾ 7 письме письмо NOUN obl <?#2, сообщал> Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing
#    │ ┡─┮ 8 15 15 NUM nummod <?#7, письме> _
#    │ │ ┡─╼ 9 декабря декабрь NOUN flat <?#8, 15> Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#    │ │ │ ╭─╼ 10 1781 1781 NUM nummod <?#11, года> _
#    │ │ ╰─┶ 11 года год NOUN nmod <?#8, 15> Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#    │ │ ╭─╼ 12 ее она PRON nmod <?#13, отцу> Case=Gen|Gender=Fem|Number=Sing|Person=3
#    │ ╰─┶ 13 отцу отец NOUN iobj <?#7, письме> Animacy=Anim|Case=Dat|Gender=Masc|Number=Sing
#    ╰─╼ 14 ? ? PUNCT punct <?#2, сообщал> _

# %% [markdown]
# Question: Что такое параматма?
#
# // Хочу отвечать Параматма - это душа
#
# Question: Как переводится название города Джукетау?
# Answer: Липовая гора

# %% [markdown]
# С вопросами `какой, какая, какие` отдельная история...

# %% [markdown]
# ## Разбиение на группы

# %%
from collections import namedtuple

# %%
Instance = namedtuple('Instance', ['question', 'question_tree', 'answer', 'answer_tree'])

def getInstances(records, chunk_size=50):
    instances = []
    for chunk_start in tqdm(range(0, len(records), chunk_size)):
        chunk_end = min(chunk_start + chunk_size, len(records))
        chunk = records[chunk_start:chunk_end]
        
        questions = [record.question for record in chunk]
        question_trees = get_trees(parser(questions))
        
        answers = [record.answer for record in chunk]
        answer_trees = get_trees(parser(answers))
        
        instances.extend([Instance(*x) for x in zip(questions,
                                                   question_trees,
                                                   answers,
                                                   answer_trees)])
    return instances

# %%
instances = getInstances(records)
# Out:
#   0%|          | 0/101 [00:00<?, ?it/s]

# %%
import pickle
with open('inst.a', 'wb') as f:
    pickle.dump(instances, f)

# %%
instances
# Out:
# [Instance(question='Чем заболел Байрон в Миссолонги?', question_tree=Node<?, <ROOT>>, answer='лихорадкой', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как отводятся излишки тепла у млекопитающих?', question_tree=Node<?, <ROOT>>, answer='потоотделением', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что нарушают хромосомные аберрации?', question_tree=Node<?, <ROOT>>, answer='Структуру хромосом.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком городе первый в мире городской автобус с двигателем внутреннего сгорания вышел на маршрут?', question_tree=Node<?, <ROOT>>, answer='в Лондоне', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком режиме проходят подлимитные операции?', question_tree=Node<?, <ROOT>>, answer='в режиме офлайн', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Находит ли отражение в алфавите фонетическая связь слогов?', question_tree=Node<?, <ROOT>>, answer='не находит', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Каким стал стиль последних работ художника?', question_tree=Node<?, <ROOT>>, answer='нервным и гнетущим', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Сколько человек родилось в 2008 году у граждан Швейцарии?', question_tree=Node<?, <ROOT>>, answer='1147 человек', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какая статья и пункт дает возможность статья для легализации ПО, скачанного из Интернет и предоставляемого по лицензии GNU GPL?', question_tree=Node<?, <ROOT>>, answer='пункт 2 статьи 434', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какими русскими купцами был накоплен значимый торговый опыт?', question_tree=Node<?, <ROOT>>, answer='купцами-новгородцами', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Где была применена конкурентная разведка через несколько лет?', question_tree=Node<?, <ROOT>>, answer='в Европе, а затем и во всем мире', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Совместимы ли операционные системы POSIX?', question_tree=Node<?, <ROOT>>, answer='Считаются POSIX-совместимыми по существу', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Сколько раз Реджинальд Дохерти стал чемпионом с 1897 по 1900 год?', question_tree=Node<?, <ROOT>>, answer='четыре раза подряд', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто считал что русская публицистическая литература восходит к „Слову о Законе и Благодати“ Илариона?', question_tree=Node<?, <ROOT>>, answer='Игорь Дедков.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Где колючие кустарники и засухоустойчивые злаки формируют земную кору?', question_tree=Node<?, <ROOT>>, answer='Только на участках, где появляется вода', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какое важное событие произошло с Мадонной в 14 лет?', question_tree=Node<?, <ROOT>>, answer='выступление на вечере талантов школы West', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда происходит прямой переход графита в алмаз?', question_tree=Node<?, <ROOT>>, answer='при 3000 K и давлении 11—12 ГПа', answer_tree=Node<?, <ROOT>>),
#  Instance(question='О чем написано в песне Чайльд-Гарольда ?', question_tree=Node<?, <ROOT>>, answer='Поездку на поля Ватерлоо', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что изначально использовалось в качестве баттуты?', question_tree=Node<?, <ROOT>>, answer='трубка из кожи, набитая шерстью, или рулон нот.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие дела не вел Московский судный приказ?', question_tree=Node<?, <ROOT>>, answer='об убийстве, разбое и воровстве с поличным', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что может произойти со стоимостью нематериальных активов при разделении компании на части?', question_tree=Node<?, <ROOT>>, answer='Может значительно снизиться', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как прокомментировал Форд отставку Никсона', question_tree=Node<?, <ROOT>>, answer='Наш долгий национальный кошмар окончился', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какой язык стал церковным и государственным языком княжеств, в которые входили ставшие оседлыми влахи?', question_tree=Node<?, <ROOT>>, answer='церковнославянский', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какое название получило в философии отсутствие каких-либо оснований для следования существующим моральным и культурным нормам?', question_tree=Node<?, <ROOT>>, answer=' нигилизм .', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие индикаторы - дополнительные графики, формируемые на основе пересчёта значений, содержащихся в базовом графике цены?', question_tree=Node<?, <ROOT>>, answer='технические', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда был основан Международный астрономический союз?', question_tree=Node<?, <ROOT>>, answer='в 1919 году', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Многие ли вещества входящие в растворители токсичны?', question_tree=Node<?, <ROOT>>, answer='Многие синтетические проявляющие вещества.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В чем суть упадка творчества скульпторов?', question_tree=Node<?, <ROOT>>, answer='Повторяют, комбинируют и видоизменяют старое', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В какой номинации был представлен альбом Earthling на премию Грэмми?', question_tree=Node<?, <ROOT>>, answer=' Лучшее альтернативное музыкальное исполнение ', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Откуда эти бактерии получают энергию для своей жизнедеятельности?', question_tree=Node<?, <ROOT>>, answer='из химических реакций с участием водорода', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие две торпеды были изготовлены в течение 1937—1938 гг. с электродвигателем мощностью 45 кВт?', question_tree=Node<?, <ROOT>>, answer='ЭТ-45', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда в Исландии появились современные учебные заведения?', question_tree=Node<?, <ROOT>>, answer='в 1903—1904 годах', answer_tree=Node<?, <ROOT>>),
#  Instance(question='что в режиме гибернации отключается?', question_tree=Node<?, <ROOT>>, answer='питание ОЗУ', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что содержат белки-каналы?', question_tree=Node<?, <ROOT>>, answer='Внутренние заполненные водой поры', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какой ВУЗ является одним из крупнейших в России медицинских вузов', question_tree=Node<?, <ROOT>>, answer='Рязанский государственный университет имени академика Павлова', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какова была цена камеры Canon EOS D30,выпущенной в 2000 году', question_tree=Node<?, <ROOT>>, answer='превышала 2500 долларов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Торвальдс начал разработку чего', question_tree=Node<?, <ROOT>>, answer='ядра Linux на MINIX', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Для чего используется добавка фторидов в соль?', question_tree=Node<?, <ROOT>>, answer='для профилактики зубных заболеваний', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие названия можно использовать для спиртов?', question_tree=Node<?, <ROOT>>, answer='исторические, или тривиальные', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие группы тоже родом из Шотландии?', question_tree=Node<?, <ROOT>>, answer='Группы Nazareth, Alestorm, Mogwai, The FRATELLIS, Simple Minds, Franz Ferdinand', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто разработал утилиту patch ( заплатка )?', question_tree=Node<?, <ROOT>>, answer='Ларри Уолл', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто увидел вражеский аэроплан во время розведки?', question_tree=Node<?, <ROOT>>, answer='лётчики', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Каким уровнем генетического вклада можно оценить организм, потомство которого слабо и плохо размножаеться?', question_tree=Node<?, <ROOT>>, answer='низкими', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Зависит ли форма генома от типа нуклеиновой кислоты?', question_tree=Node<?, <ROOT>>, answer='не зависит', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Каким должен быть научный результат?', question_tree=Node<?, <ROOT>>, answer='открытым для критики', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда будет известна истинная оценка общего количества существующих видов чешуекрылых?', question_tree=Node<?, <ROOT>>, answer='никогда', answer_tree=Node<?, <ROOT>>),
#  Instance(question='На что укладывается верхнее строение пути?', question_tree=Node<?, <ROOT>>, answer='земляное полотно', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Чем, помимо всего прочего, является Кёльн?', question_tree=Node<?, <ROOT>>, answer='Крупнейшим музейно-выставочным центром.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='О чем говорилось в шестой части книги?', question_tree=Node<?, <ROOT>>, answer='о причинах изменения широт планет', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда произошёл переход от присваивающего хозяйства к производящему?', question_tree=Node<?, <ROOT>>, answer='Примерно в 9-7 тысячелетии', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что обосновывается тем фактом, что Попов 25 марта 1896 г. провёл опыты с радиотелеграфией, послав на расстояние 250 м радиограмму?', question_tree=Node<?, <ROOT>>, answer='Приоритет Попова', answer_tree=Node<?, <ROOT>>),
#  Instance(question='в каких годах началось массированное проникновение маржиналистских идей в экономическую литературу?', question_tree=Node<?, <ROOT>>, answer='в середине 1880-х годов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='До какого года продолжали выпускаться серии серебряных сертификатов?', question_tree=Node<?, <ROOT>>, answer='до 1965 года', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что такое инкубационный период?', question_tree=Node<?, <ROOT>>, answer='в течение которого не проявляется никаких симптомов инфекции', answer_tree=Node<?, <ROOT>>),
#  Instance(question='На какой срок грозит лишение свободы в Австралии за поимку парусника Улисс (Papilio ulysses) без соответствующего разрешения?', question_tree=Node<?, <ROOT>>, answer='На срок от 6 месяцев до 2 лет', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какой процент горожан имеют собственный дом?', question_tree=Node<?, <ROOT>>, answer='3,6 %', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что сообщал Моцарт о Констанции в письме 15 декабря 1781 года ее отцу?', question_tree=Node<?, <ROOT>>, answer='Что собирается жениться на ней.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какая методика дает реальную картину строения вещества?', question_tree=Node<?, <ROOT>>, answer='методику рентгенографического анализа', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что такое параматма?', question_tree=Node<?, <ROOT>>, answer='сверхдуша', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что признали религиозные конфессии', question_tree=Node<?, <ROOT>>, answer='возможность сочетания религиозных верований', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какой фактор обуславливает участие определённых социальных слоёв в разделении культуры?', question_tree=Node<?, <ROOT>>, answer='доступ к полноценному образованию', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как переводится название города Джукетау?', question_tree=Node<?, <ROOT>>, answer='Липовая гора', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие вершины имеют кристаллы различной формы?', question_tree=Node<?, <ROOT>>, answer='острые', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Где расположен главный автовокзал, принимающий около 100 автобусов в сутки?', question_tree=Node<?, <ROOT>>, answer='в Кызылае к западу от Анкары', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие названия у истоков реки Везер?', question_tree=Node<?, <ROOT>>, answer='Верра и Фульда', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Сколько цифровых фотоаппаратов было продано японскими компаниями в 2005 году?', question_tree=Node<?, <ROOT>>, answer='64 770 000', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какую температуру пламени может достигать ацетилен при сгорании в кислороде?', question_tree=Node<?, <ROOT>>, answer='3150 °C', answer_tree=Node<?, <ROOT>>),
#  Instance(question='С какой целью проводится бизнес-рейтинг?', question_tree=Node<?, <ROOT>>, answer='с целью оптимизации бизнес-процессов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='На чем основывались первые представления о строении атомов и природе химической валентности?', question_tree=Node<?, <ROOT>>, answer='на закономерностях свойств элементов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какой уникальный музей расположен в Клайпеде?', question_tree=Node<?, <ROOT>>, answer='Морской музей', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Каково общее направление течения Дона в этой местности?', question_tree=Node<?, <ROOT>>, answer='на восток', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие три ключевые области ведения бизнеса охватывает книга Бизнес со скоростью мысли?', question_tree=Node<?, <ROOT>>, answer='торговлю, производство и управление знаниями', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие существуют придания о Посейдоне', question_tree=Node<?, <ROOT>>, answer='преданий о споре Посейдона за города с другими богами', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда Джона Леннона взяла на воспитание тетя', question_tree=Node<?, <ROOT>>, answer='Когда Джулия Леннон нашла себе другого мужчину', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какая бабочка самая известная мигрирующая?', question_tree=Node<?, <ROOT>>, answer='Данаида монарх (Danaus plexippus)', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие банки предоставляют беспроцентные дневные кредиты под соответствующее обеспечение?', question_tree=Node<?, <ROOT>>, answer='Центральные банки', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Во сколько раз увеличилось население Рязани при мэре Надежде Николаевне Чумаковой?', question_tree=Node<?, <ROOT>>, answer='более чем в семь раз', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какова общая длина общая длина дорожной сети,которую построили инки в Америке?', question_tree=Node<?, <ROOT>>, answer='16 тыс. км', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Сколько генерируется улучшенных малых азимутальных меток для новых система один оборот антенны РЛС?', question_tree=Node<?, <ROOT>>, answer='16384', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какую сумму удалось собрать при проведении Победного кредита ?', question_tree=Node<?, <ROOT>>, answer='более 65 миллионов канадских долларов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие примеры для воспитания и обучения, применяемые в узкопрофессиональных целях, можно назвать', question_tree=Node<?, <ROOT>>, answer='воинская подготовка, обучение ремеслу', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком замке был заключен Дидро?', question_tree=Node<?, <ROOT>>, answer='Венсенском', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что используют в качестве генератора импульсные РЛС метрового диапазона?', question_tree=Node<?, <ROOT>>, answer='триодную лампу', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Где дуют самые сильные постоянные ветры?', question_tree=Node<?, <ROOT>>, answer='на земле Адели, Антарктида', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие языки образовались на базе восточной подгруппы?', question_tree=Node<?, <ROOT>>, answer='шведский, датский и старогутнийский языки', answer_tree=Node<?, <ROOT>>),
#  Instance(question='С чем связывается образ крысы?', question_tree=Node<?, <ROOT>>, answer='с порчей, разрушением, смертью', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком году Армстронг запатентовал супергетеродинный радиоприемник?', question_tree=Node<?, <ROOT>>, answer='В 1918', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какое качество газообмена у более дешевых двигателей?', question_tree=Node<?, <ROOT>>, answer='относительно невысокое', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что является главными преимуществами асинхронного ТЭД?', question_tree=Node<?, <ROOT>>, answer='простота конструкции и малые габариты', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие произведения Тургенева не ценил Дмитрий Мережковский?', question_tree=Node<?, <ROOT>>, answer='Романы', answer_tree=Node<?, <ROOT>>),
#  Instance(question='На протяжении какого времени карты Carte Blanche считались более престижными?', question_tree=Node<?, <ROOT>>, answer='большей части 1960-х и 1970-х годов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Фамилия какого португальского мореплавателя известна открытием мыса Доброй Надежды?', question_tree=Node<?, <ROOT>>, answer='Диаш', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как осуществляется дыхание у большинства представителей ракообразных?', question_tree=Node<?, <ROOT>>, answer='При помощи жабр.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком году Лавуазье получил имение?', question_tree=Node<?, <ROOT>>, answer='1778', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком году группа Машина времени приняла участие в Международном фестивале Музыканты мира детям Чернобыля в Минске?', question_tree=Node<?, <ROOT>>, answer='23 апреля 1991 года', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Сколько методов оценки модуля тригонометрических сумм предложил Виноградов?', question_tree=Node<?, <ROOT>>, answer='два', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что перенес Шостакович через несколько месяцев после смерти отца?', question_tree=Node<?, <ROOT>>, answer='Тяжёлую операцию', answer_tree=Node<?, <ROOT>>),
#  Instance(question='К чему в последующие этапы своего развития неоднократно возвращалась философия?', question_tree=Node<?, <ROOT>>, answer='к релятивизму', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто автор статьи Творчество Прокофьева в советском теоретическом музыкознании ?', question_tree=Node<?, <ROOT>>, answer='Ю. Н. Холопов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какой характер имел результат народных состязаний по борьбе?', question_tree=Node<?, <ROOT>>, answer='символический', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что было принципиальным недостатком 4- и 8-дорожечных картриджей?', question_tree=Node<?, <ROOT>>, answer='способ переключения дорожек', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Сколько взрывчатки было поставлено в СССР по ленд-лизу?', question_tree=Node<?, <ROOT>>, answer='345 735 тонн', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что позволяет шея жирафу?', question_tree=Node<?, <ROOT>>, answer='срывать листья и молодые побеги с крон деревьев', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что в вызывает мёд, собранный с рододендрона, в организме человека?', question_tree=Node<?, <ROOT>>, answer='головную боль, рвоту, потемнение в глазах, а иногда и обморочное состояние', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какое влияние оказывает Центральный банк Мальты на кредитный рынок?', question_tree=Node<?, <ROOT>>, answer='может регулировать уровень цен', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какой вид может иметь форма губок?', question_tree=Node<?, <ROOT>>, answer='корковых, подушковидных, плёнковидных', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Наряду с какими языками галльский являлся одним из трёх языков, распространенных в Галлии?', question_tree=Node<?, <ROOT>>, answer='с аквитанским и белгским', answer_tree=Node<?, <ROOT>>),
#  Instance(question='С какого года устройство доступно в лизинг за доллар в неделю?', question_tree=Node<?, <ROOT>>, answer='С 31 мая 2016', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каких странах провинция выступает административным подразделением региона?', question_tree=Node<?, <ROOT>>, answer='в Италии и Чили', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что произошло после после пика популярности?', question_tree=Node<?, <ROOT>>, answer='интерес инвесторов к чистым технологиям снизился', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда Украина столкнулась с высокой инфляцией (10200 % в год)?', question_tree=Node<?, <ROOT>>, answer='В начале 90-х годов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как платило дань сельцо?', question_tree=Node<?, <ROOT>>, answer='наравне с сёлами', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда родился Ван Гог?', question_tree=Node<?, <ROOT>>, answer='30 марта 1853 года', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каких звездолетах могут использоваться фотонные установки в качестве маршевых двигателей?', question_tree=Node<?, <ROOT>>, answer='Досветовые', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В соответствии с каким научным учением, революция в крестьянских странах, таких как Россия, готовит почву в конечном счете для развития капитализма', question_tree=Node<?, <ROOT>>, answer='Классическим марксизмом', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Каковы крылья пестрокрыльницы изменчивой в летний период?', question_tree=Node<?, <ROOT>>, answer='окраска крыльев чёрная с белыми пятнами', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В чьих работах было положено начало современным представлениям о биологическом виде и системе животного мира?', question_tree=Node<?, <ROOT>>, answer='Дж. Рэя и К. Линнея', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда Гундобад вторгся в Бургундию?', question_tree=Node<?, <ROOT>>, answer='501 году', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кому передали Озерки родители Бунина?', question_tree=Node<?, <ROOT>>, answer='сыну Евгению', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Через сколько лет риливное ускорение отдалит Луну от Земли настолько, что полное солнечное затмение станет невозможно', question_tree=Node<?, <ROOT>>, answer='Через 600 миллионов лет', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что вызвало всплеск общественного интереса к этому направлению?', question_tree=Node<?, <ROOT>>, answer='Публикация ряда результатов в открытой печати', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда прошли первые многопартийные президентские выборы в Мавритании?', question_tree=Node<?, <ROOT>>, answer='в январе 1992', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда Ягайло передал Спитко западную часть Подолья?', question_tree=Node<?, <ROOT>>, answer='В июне 1395', answer_tree=Node<?, <ROOT>>),
#  Instance(question='К чему привели ошибочные данные разветки Британии?', question_tree=Node<?, <ROOT>>, answer='британская авиация нанесла бомбовые удары', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Где принимал участие отец Бунина в составе Елецкой дружины ополчения?', question_tree=Node<?, <ROOT>>, answer='в Крымской кампании', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какое слово позже добавилось для отличия от метра?', question_tree=Node<?, <ROOT>>, answer='мэтр', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Из чего была голова у огромного истукана во сне Навуходоносора?', question_tree=Node<?, <ROOT>>, answer='из золота', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Сколько часов отвели на изучение башкирского языка в башкирских и русских школах?', question_tree=Node<?, <ROOT>>, answer='от 1 до 8 часов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Сколько составляет суммарная биомасса клеток прокариот?', question_tree=Node<?, <ROOT>>, answer='350—550 млрд т', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком году архиепископ Боготы Луис Сапата де Карденас объвил защитницей города Святую Исабеллу?', question_tree=Node<?, <ROOT>>, answer='В 1573 году', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда Брюллов покинул Россию по настоянию врачей?', question_tree=Node<?, <ROOT>>, answer='27 апреля 1849 года', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кого несомненно возбудит занятие Порт-Артура или Да-лянь-вана?', question_tree=Node<?, <ROOT>>, answer='Китай', answer_tree=Node<?, <ROOT>>),
#  Instance(question='У кого ареалы часто сопряжены с распространением кормовых растений гусениц?', question_tree=Node<?, <ROOT>>, answer='У монофагов и узких олигофагов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Был ли в атмосфере свободный кислород до появления первых фотосинтезирующих архей?', question_tree=Node<?, <ROOT>>, answer='В атмосфере его практически не было.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком году в СССР проводилась кампания против самодеятельных музыкальных коллективов?', question_tree=Node<?, <ROOT>>, answer='В 1982—1984', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда группа Машина времени в новом составе дебютировала на фестивале Весенние ритмы. Тбилиси-80 ?', question_tree=Node<?, <ROOT>>, answer='8 марта 1980 года', answer_tree=Node<?, <ROOT>>),
#  Instance(question='С чьей концепцией схожа концепция наполнения баз добровольцами?', question_tree=Node<?, <ROOT>>, answer='С концепцией вики.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Полуоси ведущего моста имеют разную или одинаковую длину?', question_tree=Node<?, <ROOT>>, answer='Разную.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кому предаются полномочия в отсутствии управляющего в случае, когда число заместителей более одного?', question_tree=Node<?, <ROOT>>, answer='Самому старшему по возрасту заместителю', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Перевод onnellinen talon omistaja с финского языка?', question_tree=Node<?, <ROOT>>, answer='onnellinen talon omistaja букв. счастливый дома владелец ', answer_tree=Node<?, <ROOT>>),
#  Instance(question='За каким анализом следует анализ качества кредитного портфеля?', question_tree=Node<?, <ROOT>>, answer='За количественным', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком языке различают наречия места, времени, образа действия, меры, а также причины?', question_tree=Node<?, <ROOT>>, answer='В чешском языке.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Формирование чего не происходит у губок в ходе эмбриогенеза?', question_tree=Node<?, <ROOT>>, answer='зародышевых листков', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какое самое известное произведение Твардовского?', question_tree=Node<?, <ROOT>>, answer=' Книга про бойца без начала и конца .', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что стало новым?', question_tree=Node<?, <ROOT>>, answer='пчёлы полностью специализировались на опылении', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Многие ли верят в одновременное существование материального тела и нематериального сознания?', question_tree=Node<?, <ROOT>>, answer='Большинство людей на Земле', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Где горожане стали получать медицинские услуги после практик отдельных докторов царского периода?', question_tree=Node<?, <ROOT>>, answer='В заводских и районных поликлиниках и больницах.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что будет за изучение или попытки исправления ошибок программ путём дизассемблирования ?', question_tree=Node<?, <ROOT>>, answer='могут преследоваться уголовным правом.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто описал понятия рас, как исторически слагающиеся категории ?', question_tree=Node<?, <ROOT>>, answer='Г. И. Петров', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что утверждают некоторые критики относительно использования таксонов высшего по виду ранга в систематике?', question_tree=Node<?, <ROOT>>, answer='эти таксоны не должны использоваться в систематике вообще', answer_tree=Node<?, <ROOT>>),
#  Instance(question='как расценивалась Скифская сюита ?', question_tree=Node<?, <ROOT>>, answer='как самое крупное и значительное из написанных им до сих пор оркестровых произведений ', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каких международных организациях может открыть счет Банк Канады?', question_tree=Node<?, <ROOT>>, answer='Международный валютный фонд', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что должен делать Банк Канады?', question_tree=Node<?, <ROOT>>, answer='способствовать экономическому благосостоянию канадских граждан', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком случае работнику обязаны выплатить тарифную ставку?', question_tree=Node<?, <ROOT>>, answer='при условии выполнения должностных обязанностей', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Сколько Интеза Холдинг Интернешнл СА заплатила на 75% акций КМБ Банка?', question_tree=Node<?, <ROOT>>, answer='$90 млн', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Речной окунь - это рыба какого рода?', question_tree=Node<?, <ROOT>>, answer='пресноводных окуней', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда Аксель Вебер заявил о намерении UBS сократить численность сотрудников в Лондоне?', question_tree=Node<?, <ROOT>>, answer='В начале 2017 года', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какая черта характерна для феноменологии естествознания', question_tree=Node<?, <ROOT>>, answer=' Синхронность открытий ', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Через какую территорию Андре де Лонжюмо попал в Китай?', question_tree=Node<?, <ROOT>>, answer='Центральную Азию', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Из скольки судов состоял флот под командованием Васко да Гамы?', question_tree=Node<?, <ROOT>>, answer='из четырёх судов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что было запатентовано и поступило в свободную продажу в 1907 году?', question_tree=Node<?, <ROOT>>, answer='Фотопластинки Автохром братьев Люмьер', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В какую категорию современная экономика относит информацию и время?', question_tree=Node<?, <ROOT>>, answer='в категорию труд ', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие страны являются производителями оливкового масла за пределами Европы?', question_tree=Node<?, <ROOT>>, answer='Сирия и Марокко', answer_tree=Node<?, <ROOT>>),
#  Instance(question='На что расчленено тело у большинства млекопитающих?', question_tree=Node<?, <ROOT>>, answer='на голову, шею, туловище, две пары конечностей и хвост', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Относительно чего законодательство Российской Федерации предъявляет меньшие процедурные требования к деятельности общества с ограниченной ответственностью?', question_tree=Node<?, <ROOT>>, answer='чем к деятельности акционерного общества', answer_tree=Node<?, <ROOT>>),
#  Instance(question='На основании какого закона поделены все местные налоги между местными уровнями?', question_tree=Node<?, <ROOT>>, answer='Бюджетного кодекса РФ', answer_tree=Node<?, <ROOT>>),
#  Instance(question='С чем была связана первоначальная неприятность дисков DVD-RW?', question_tree=Node<?, <ROOT>>, answer='с несовместимостью старых приводов с этими новыми дисками', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В какие годы начал набирать популярность поджанр антиутопий - киберпанк?', question_tree=Node<?, <ROOT>>, answer='В 1980-е годы', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что отметили литературоведы глядя на произведения, созданных в эмигрантский период?', question_tree=Node<?, <ROOT>>, answer='напрочь ушёл присущий Бунину прежде социальный посыл', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Где наименьшая концентрация языков SVO ?', question_tree=Node<?, <ROOT>>, answer='Северной Америке и северной части Азии', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Где некоторые типы распадов могут изменять свою вероятность?', question_tree=Node<?, <ROOT>>, answer='в ядрах звёзд', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Представителями какого музыкального жанра 70-х являются следующие группы: Devo, Suicide, Television, Talking Heads?', question_tree=Node<?, <ROOT>>, answer='постпанка', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кем публикуется Красный список угрожаемых видов', question_tree=Node<?, <ROOT>>, answer='Международным союзом охраны природы и природных ресурсов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какой немецкий спутник должен был полететь на той же ракете что и российские спутники Канопус-В и МКА-ПН1?', question_tree=Node<?, <ROOT>>, answer='TET-1', answer_tree=Node<?, <ROOT>>),
#  Instance(question='что завоевали хозяева турнира', question_tree=Node<?, <ROOT>>, answer='остались без наград.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='За что тренера раскритиковали ?', question_tree=Node<?, <ROOT>>, answer='за неудачные перестановки', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какой вид рыбы относится в Америке к Perca fluviatilis?', question_tree=Node<?, <ROOT>>, answer='аборигенный жёлтый окунь', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В чём выражается это влияние?', question_tree=Node<?, <ROOT>>, answer='в принятии физическими лицами, предприятиями и органами государственной власти экономических решений', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какой город выдержал осаду весной 1149 года?', question_tree=Node<?, <ROOT>>, answer='Луцк', answer_tree=Node<?, <ROOT>>),
#  Instance(question='как называли некоторых из шведских учеников Линнея, которые начали участвовать в различных экспедициях?', question_tree=Node<?, <ROOT>>, answer=' апостолами Линнея .', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какое изобретение, наряду с мостом, является одним из древнейших?', question_tree=Node<?, <ROOT>>, answer='Тоннель', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто построил первый каменный мост через Дунай?', question_tree=Node<?, <ROOT>>, answer='Римский император Траян.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие учреждения развивались наравне с государственными банками?', question_tree=Node<?, <ROOT>>, answer='негосударственные кредитные учреждения', answer_tree=Node<?, <ROOT>>),
#  Instance(question='где римляне добывали золото для монет позднее эпохи культуры Hallstatt?', question_tree=Node<?, <ROOT>>, answer='в Бад Гаштайнской области', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Раковины каких морских существ выставлялись на показ в интерьерах XIX века?', question_tree=Node<?, <ROOT>>, answer='моллюсков', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какой гонорар получил Моцарт за оперу Così fan tutte ?', question_tree=Node<?, <ROOT>>, answer='200 дукатов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как называются сильные ветры средней продолжительности (примерно 1 минута) ?', question_tree=Node<?, <ROOT>>, answer='называются шквалами', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Чем представлена у рыб система кровообращения?', question_tree=Node<?, <ROOT>>, answer='только одним замкнутым контуром', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие стили носят название местных императорских династий?', question_tree=Node<?, <ROOT>>, answer='Японские', answer_tree=Node<?, <ROOT>>),
#  Instance(question='С какой целью ревизионная комиссия производит проверку финансово-хозяйственной деятельности хозяйственного общества?', question_tree=Node<?, <ROOT>>, answer='подтверждает достоверность данных, содержащихся в отчётности', answer_tree=Node<?, <ROOT>>),
#  Instance(question='К чему привела тяжёлая жизнь при полуголодном существовании?', question_tree=Node<?, <ROOT>>, answer='К сильному истощению', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда была запущена первая в мире атомная электростанция?', question_tree=Node<?, <ROOT>>, answer='27 июня 1954 года', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как описывает изменение курса математики в реформе 1871 А. А. Корнилов?', question_tree=Node<?, <ROOT>>, answer='был сильно увеличен гимназический курс математики', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кому помог завоевать Англию в 1688 году другой шторм Протестантский ветер ?', question_tree=Node<?, <ROOT>>, answer='Вильгельму Оранскому', answer_tree=Node<?, <ROOT>>),
#  Instance(question='С помощью чего можно восстановить данные при подмене одного из секторов жесткого диска резервным?', question_tree=Node<?, <ROOT>>, answer='При помощи ECC.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком году был изобретен желатиносеребряный процесс?', question_tree=Node<?, <ROOT>>, answer='в 1887 году', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что вызывает изменения частот аллелей генов?', question_tree=Node<?, <ROOT>>, answer='мутации, поток генов, естественный отбор и дрейф генов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какая структура настаивала на создании поселений в регионе для увеличения числа рабочей силы?', question_tree=Node<?, <ROOT>>, answer='лесной департамент', answer_tree=Node<?, <ROOT>>),
#  Instance(question='С каким разрешением были получены фото Марса?', question_tree=Node<?, <ROOT>>, answer='С самым высоким разрешением', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кем писаны многие произведения средневековых поэтов?', question_tree=Node<?, <ROOT>>, answer='Писаны под их диктовку женщинами.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что описывает Манну в романе', question_tree=Node<?, <ROOT>>, answer='Манн описывает историю упадка и вырождения купеческой династии из Любека', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком году отец Оригена был убит?', question_tree=Node<?, <ROOT>>, answer='В 202 году', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что является один из этих негативных факторов,облегчающих распространение эпидемий?', question_tree=Node<?, <ROOT>>, answer='Скученность городского населения', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что используется в аксиоме Архимеда вместо тройки вещественных чисел?', question_tree=Node<?, <ROOT>>, answer='тройка комплексных чисел', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как называется круг кровообращения, функционирующий через легкие?', question_tree=Node<?, <ROOT>>, answer='малый', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какой вид паровых машин стал практически единственным типом, используемым на пароходах после 1880-х годов?', question_tree=Node<?, <ROOT>>, answer='компаундные', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каких аспектах стран мира Швеция наиболее однородна?', question_tree=Node<?, <ROOT>>, answer='В этническом, религиозном и языковом', answer_tree=Node<?, <ROOT>>),
#  Instance(question='К возникновению каких поджанров привело введение в киберпанк тем нанотехнологий и биоинженерии?', question_tree=Node<?, <ROOT>>, answer='нанопанк и биопанк', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Чем являются водородные соединения других элементов?', question_tree=Node<?, <ROOT>>, answer='газами', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто вывел сорт розы Champneys Pink Cluster ?', question_tree=Node<?, <ROOT>>, answer='Джон Чемпнис Чарльстон', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто развил философию в направлении абсолютного идеализма?', question_tree=Node<?, <ROOT>>, answer='Фихте, Шеллинг и Гегель', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что закрывается при сокращении камер сердца?', question_tree=Node<?, <ROOT>>, answer='Клапаны остий.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие клетки не способны образовывать цисты?', question_tree=Node<?, <ROOT>>, answer='единичные', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие товары не используется в технологических процессах?', question_tree=Node<?, <ROOT>>, answer='ценные бумаги, деньги', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто отклонил проект идеального города Леонардо да Винчи?', question_tree=Node<?, <ROOT>>, answer='Миланский герцог Лодовико Сфорца.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как расценивал Мендрелеев капитал?', question_tree=Node<?, <ROOT>>, answer='временную форму', answer_tree=Node<?, <ROOT>>),
#  Instance(question='При каком виде фотосъемки шерсть белого медведя кажется темной?', question_tree=Node<?, <ROOT>>, answer='При ультрафиолетовой', answer_tree=Node<?, <ROOT>>),
#  Instance(question='С какого года проводилось богослужение на литовском языке', question_tree=Node<?, <ROOT>>, answer='c 1901 года', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что изучает зоология?', question_tree=Node<?, <ROOT>>, answer='животных', answer_tree=Node<?, <ROOT>>),
#  Instance(question='С какими организациями сотрудничают Сады Кью?', question_tree=Node<?, <ROOT>>, answer='с вузами, ботаническими садами, природоохранными, промышленными и правительственными', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В какое время в массовом машиностроении применялся метод калькулирования?', question_tree=Node<?, <ROOT>>, answer='с конца 1920-х гг. по 1938 г', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какое место оккупировал Акамару в рейтинге?', question_tree=Node<?, <ROOT>>, answer='Акамару занял третье место', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Чем богата мантия Нептуна?', question_tree=Node<?, <ROOT>>, answer='водой, аммиаком, метаном и прочими соединениями', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто приняли меры для предотвращения подобных эксцессов?', question_tree=Node<?, <ROOT>>, answer='Регуляторы', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда около десятка экономически развитых стран решили перейти на инфляционное таргетирование?', question_tree=Node<?, <ROOT>>, answer='С конца 1980-х гг', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто написал роман Чего же ты хочешь? ', question_tree=Node<?, <ROOT>>, answer='В. А. Кочетов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Где появились сорокопятки?', question_tree=Node<?, <ROOT>>, answer='В США', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как можно охарактеризовать мелодии соул-джаза?', question_tree=Node<?, <ROOT>>, answer='Стремительно закрученные', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда состоялась сделка по продаже Аляски?', question_tree=Node<?, <ROOT>>, answer='18 октября 1867 года', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кем было принято решение об организации конкурса по созданию герба и флага города Северодвинска в 2014 году?', question_tree=Node<?, <ROOT>>, answer='депутатами', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Для чего используется отреставрированный интерьер?', question_tree=Node<?, <ROOT>>, answer='для культурных мероприятий', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какими еще нормативными актоми регулируются права акционеров?', question_tree=Node<?, <ROOT>>, answer='Уставом непубличного общества.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Чему должна учиться интеллигенция у деревни ?', question_tree=Node<?, <ROOT>>, answer='нравственности', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Из каких провинций состояла Новгородская губерния, выделенная из Петербургской губернии в 1727 году?', question_tree=Node<?, <ROOT>>, answer='Новгородской, Псковской, Великолуцкой, Тверской, Белозерской', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто в основном выполняет междугородные автобусные перевозки в Шеффилде?', question_tree=Node<?, <ROOT>>, answer='National Express', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как назвал матч Фишер?', question_tree=Node<?, <ROOT>>, answer=' матчем на первенство мира ', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В какой зоне находится большая часть территории Голландии, Бельгии, Франции и Англии?', question_tree=Node<?, <ROOT>>, answer='в зоне 8.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В виде чего могут использоваться такие графики?', question_tree=Node<?, <ROOT>>, answer='Как самостоятельные модели технического анализа.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В отличии от чего в болгарском и македонском языках, при наличии определяемых слов перед существительным, определённый артикль ставится только в конце первого слова?', question_tree=Node<?, <ROOT>>, answer='падежных форм русского языка', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Где Роберт Фишер появился на свет?', question_tree=Node<?, <ROOT>>, answer='в Чикаго', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какое созвездие используется, в частности, в конфигурации колец Омрона?', question_tree=Node<?, <ROOT>>, answer='Евриона', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что показал отчёт за 2008 год?', question_tree=Node<?, <ROOT>>, answer='климат в Шеффилде теплеет быстрее, чем в любой другой год', answer_tree=Node<?, <ROOT>>),
#  Instance(question='субмарины какого типа стали первыми серийными лодками с двигателями Стирлинга?', question_tree=Node<?, <ROOT>>, answer='Субмарины типа Готланд ', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что может служить примером постмодернистского видения мира?', question_tree=Node<?, <ROOT>>, answer='концепция диалога Левинаса', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что подразумевается под словосочетанием полуторная конструкция?', question_tree=Node<?, <ROOT>>, answer='расстояние между осями рулонов меньше, чем их максимальный диаметр', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как расположены островные платформы на станциях с остановкой экспресса?', question_tree=Node<?, <ROOT>>, answer='между путями одного направления', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В какой промежуток времени Гиппократ выдвигал подобную гипотезу?', question_tree=Node<?, <ROOT>>, answer='V—IV в. до н. э', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда Билл Уинтерс основал хедж-фонд Renshaw Bay?', question_tree=Node<?, <ROOT>>, answer='в феврале 2011 года', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что было записано на обороте первой авторской рукописи Сергея Прокофьева?', question_tree=Node<?, <ROOT>>, answer='положение незаконченной шахматной партии', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какая лихорадка передается через укус комара?', question_tree=Node<?, <ROOT>>, answer='жёлтая', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какой количество от общего числа населения африканской языковой группы составляют канури?', question_tree=Node<?, <ROOT>>, answer='3,89 млн чел. (13,3 %)', answer_tree=Node<?, <ROOT>>),
#  Instance(question='О ком Альфред Шнитке высказывался как об одном из величайших композиторов в русской музыкальной истории?', question_tree=Node<?, <ROOT>>, answer='О Прокофьеве.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='где находятся жидкие среды', question_tree=Node<?, <ROOT>>, answer='в живых организмах.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='К чему приходит Уатт в результате своих исследований?', question_tree=Node<?, <ROOT>>, answer='к пониманию важности скрытой теплоты', answer_tree=Node<?, <ROOT>>),
#  Instance(question='На каком берегу охотники выискивали дичь', question_tree=Node<?, <ROOT>>, answer='на берегу внутренней Мэотиды', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как изменяется объем клетки при линейном увеличении ее радиуса?', question_tree=Node<?, <ROOT>>, answer='пропорционально кубу', answer_tree=Node<?, <ROOT>>),
#  Instance(question='На чём построено различие гласных звуков по долготе?', question_tree=Node<?, <ROOT>>, answer='на упорядочении слогов по признаку долготы/краткости', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Каким свойством обладают все соединения урана и в наибольшей степени сам уран?', question_tree=Node<?, <ROOT>>, answer='свойством естественной радиоактивности', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие производства спадают в экономике Тренто?', question_tree=Node<?, <ROOT>>, answer='обрабатывающие', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Сколько детских дошкольных учреждений включала система образования?', question_tree=Node<?, <ROOT>>, answer='102', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как называется химическая реакция, происходящая при участии катализаторов?', question_tree=Node<?, <ROOT>>, answer='катализ', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Откуда наёмники получали оплату за работу?', question_tree=Node<?, <ROOT>>, answer='из государственной казны', answer_tree=Node<?, <ROOT>>),
# ...
#  Instance(question='Как Бунин относился к рецензиям Адамовича?', question_tree=Node<?, <ROOT>>, answer='не всегда одобрительно', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Каким аллюзиям по мнению литературного критика Аркадия Горнфельда подвержены произведения Александра Грина?', question_tree=Node<?, <ROOT>>, answer='аллюзиям Эдгара По', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какая буква кириллицы имела трёхногое m-образное начертание помимо обычного?', question_tree=Node<?, <ROOT>>, answer='буква Т', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Где варьирует артикуляция r?', question_tree=Node<?, <ROOT>>, answer='в различных районах от r апикального до (преимущественно) r увулярного', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто ввел термин идеализм в философию?', question_tree=Node<?, <ROOT>>, answer='Лейбниц', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что устанавливает Воздушный кодекс Российской Федерации?', question_tree=Node<?, <ROOT>>, answer='какое ведомство несет ответственность за летную годность всех летательных аппаратов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Куда будет направлено в процессе подачи напряжения плюсом на p-полупроводник и минусом на n-полупроводник внешнее электрическое поле?', question_tree=Node<?, <ROOT>>, answer='против внутреннего электрического поля', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какую войну Константин I Великий провел незадолго до смерти?', question_tree=Node<?, <ROOT>>, answer='против готов и сарматов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто применил первую элективную среду?', question_tree=Node<?, <ROOT>>, answer='С. Н. Виноградский', answer_tree=Node<?, <ROOT>>),
#  Instance(question='На ком в основном лежит забота о подрастающем потомстве млекопитающих?', question_tree=Node<?, <ROOT>>, answer='на самках', answer_tree=Node<?, <ROOT>>),
#  Instance(question='С какими болезнями боролись при строительстве Панамского канала?', question_tree=Node<?, <ROOT>>, answer='малярией и жёлтой лихорадкой', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как называется оболочка, которая не допускает обмен ни веществом, ни энергией между системой и окружающей средой?', question_tree=Node<?, <ROOT>>, answer='такая оболочка называется адиабатической', answer_tree=Node<?, <ROOT>>),
#  Instance(question='кто такие позвоночные?', question_tree=Node<?, <ROOT>>, answer='высший подтип хордовых животных', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Сколько лет жизни в бедности можно расценивать как хроническую бедность?', question_tree=Node<?, <ROOT>>, answer='Более трёх лет.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком направлении движется кровь при сокращении сердца у рыб?', question_tree=Node<?, <ROOT>>, answer='от венозного синуса к артериальному конусу', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Где был заложен китайский город Чунцин?', question_tree=Node<?, <ROOT>>, answer='где река Цзялинцзян впадает в полноводную Янцзы', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что отражает в себе космограмма?', question_tree=Node<?, <ROOT>>, answer='относительное расположение тел Солнечной системы', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какой по счету студийный альбом выпустила в 2014 году группа Linkin Park?', question_tree=Node<?, <ROOT>>, answer='шестой', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком жанре распространено использование щипка медиатором', question_tree=Node<?, <ROOT>>, answer='Применим при исполнении рок-музыки и её производных', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что резко меняется в трудовой деятельности при карьерном росте?', question_tree=Node<?, <ROOT>>, answer='характер работы', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как называются подземные участки S-Bahn?', question_tree=Node<?, <ROOT>>, answer='U-Bahn', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто принимал участие в исследовании об общественной ценности немецких школ за рубежом?', question_tree=Node<?, <ROOT>>, answer='политики, чиновники, представители профсоюзов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кому было поручено управлять Сибирью после ее завоевания?', question_tree=Node<?, <ROOT>>, answer='Посольскому приказу', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком году был зарегистрирован в качестве акционерного общества закрытого типа?', question_tree=Node<?, <ROOT>>, answer='в декабре 1994 года', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Отец кого отказывался видеть Бунина своим будущим зятем?', question_tree=Node<?, <ROOT>>, answer='Варвары', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда образуются облака верхнего яруса?', question_tree=Node<?, <ROOT>>, answer='Когда обширные пласты воздуха поднимаются вверх.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какова доля ветроэнергетики в Дании?', question_tree=Node<?, <ROOT>>, answer='20 %', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком году была основана кейнсианская экономическая школа?', question_tree=Node<?, <ROOT>>, answer='в 1936', answer_tree=Node<?, <ROOT>>),
#  Instance(question='С помощью какого кода, благодаря коррекции ошибок, лёгкие радиальные царапины не влияют на читаемость диска?', question_tree=Node<?, <ROOT>>, answer='с помощью кода Рида — Соломона', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Почему тропические леса важны?', question_tree=Node<?, <ROOT>>, answer='они являются местообитанием почти половины всех населяющих её биологических видов', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какими двигателями были первые запатентованные паровые машины Джеймса Уатта?', question_tree=Node<?, <ROOT>>, answer='тяжёлыми двигателями с низким давлением', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Куда уехал ван Гог осенью 1885 года?', question_tree=Node<?, <ROOT>>, answer='в Антверпен', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как может быть описана веддоидная группа?', question_tree=Node<?, <ROOT>>, answer='как грацильный вариант австралоидной расы', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как образуется новая океаническая кора?', question_tree=Node<?, <ROOT>>, answer='в результате спрединга', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком году вышел сборник Как прошли выборы во 2-ю Государственную думу ?', question_tree=Node<?, <ROOT>>, answer='в 1907', answer_tree=Node<?, <ROOT>>),
#  Instance(question='С помощью чего применяют навесной монтаж?', question_tree=Node<?, <ROOT>>, answer='С помощью крана', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как называется воздушное судно, которое пилотирует пилот, не находящийся на борту?', question_tree=Node<?, <ROOT>>, answer='Дистанционно пилотируемое', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Каким тембром обладает инструмент?', question_tree=Node<?, <ROOT>>, answer='певучим', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Против какой корпорации ФАС России рассмотрела дело в апреле 2012 г.?', question_tree=Node<?, <ROOT>>, answer='RENAULT TRUCKS', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие бактерии имеют травоядные животные в пищеварительном тракте?', question_tree=Node<?, <ROOT>>, answer='бактерии-симбионты', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какими приемами обогащается авангардная драма в XX веке?', question_tree=Node<?, <ROOT>>, answer='приёмами литературы абсурда', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Автор чего Грибоедов?', question_tree=Node<?, <ROOT>>, answer='Он — автор нескольких фортепианных пьес', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как называется работа Карла Линнея, появившяся 1 мая 1753 года', question_tree=Node<?, <ROOT>>, answer='Species plantarum', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что входит во время оборота?', question_tree=Node<?, <ROOT>>, answer='Включается время (несколько минут) для отдыха водителя.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как называют пещеры, образованные волнами морей и океанов в прибрежных скалах?', question_tree=Node<?, <ROOT>>, answer='абразионными', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Где именно группа Машина времени по предложению Ованеса Мелик-Пашаева должна была выступить осенью 1978 года?', question_tree=Node<?, <ROOT>>, answer='в стройотряде в г. Печоре', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Для какой цели предоставляются торговый скидки?', question_tree=Node<?, <ROOT>>, answer='чтобы позволить продавцу увеличить объём продаж', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Чем исторически был Тебриз?', question_tree=Node<?, <ROOT>>, answer='крупным торговым центром', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какая песня Боуи прозвучала в картине Шоугёлз ?', question_tree=Node<?, <ROOT>>, answer=' I’m Afraid of Americans ', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что Леонардо да Винчи признавал единственным критерием истины?', question_tree=Node<?, <ROOT>>, answer='опыт', answer_tree=Node<?, <ROOT>>),
#  Instance(question='С точки зрения чего совместим между собой подвижной состав двух дивизионов?', question_tree=Node<?, <ROOT>>, answer='ширины колеи', answer_tree=Node<?, <ROOT>>),
#  Instance(question='сколько иностранных банков было в Сингапуре на ноябрь 2010 года??', question_tree=Node<?, <ROOT>>, answer='25', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что получено по ленд-лизу?', question_tree=Node<?, <ROOT>>, answer='Высокие доли продукции машиностроения.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что поддерживает подпоясанную куколку помимо кремастера?', question_tree=Node<?, <ROOT>>, answer='специальный паутинистый поясок', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком веке Британская Ост-Индская компания стала проявлять интерес к Оману?', question_tree=Node<?, <ROOT>>, answer='С конца XVIII века', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Сколько человек проживало в Днепропетровске в 1992 году?', question_tree=Node<?, <ROOT>>, answer='1 189 900 человек', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие применяются управленческие технологии в правлении эффективностью деятельности компанией?', question_tree=Node<?, <ROOT>>, answer='моделирование стратегии, карты сбалансированных показателей, процессно-ориентированное планирование', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Когда появился проект корабля 7К-ВИ ( Союз-ВИ ) во исполнение Постановления ЦК КПСС и Совета Министров?', question_tree=Node<?, <ROOT>>, answer='24 августа 1965 года', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Каким музыкальным направдением была увлечена 20-летняя Мадонна?', question_tree=Node<?, <ROOT>>, answer='панк-роком', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какой фанфик стоит особняком?', question_tree=Node<?, <ROOT>>, answer=' Звёздный путь людей и богов ', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Под владычество какой страны отошли города Лараш и Азилах', question_tree=Node<?, <ROOT>>, answer='Испании', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как еще использовали пиво?', question_tree=Node<?, <ROOT>>, answer='для расчётов с работниками', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Сколько отделов включает в себя тело ракообразных?', question_tree=Node<?, <ROOT>>, answer='3 отдела', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Почему в настоящее время вопрос об устойчивости интродуцентов крайне актуален и широко обсуждается?', question_tree=Node<?, <ROOT>>, answer='В связи с интенсивной интродукцией новых для России видов и форм декоративных садовых растений', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как сократили название архебактерий?', question_tree=Node<?, <ROOT>>, answer='переименованы в архей', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как работала фуникулёрная рельсовая дорога в Хоэнзальцбург?', question_tree=Node<?, <ROOT>>, answer='за счёт усилий людей и животных', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Этапы чего показывал Гончаров в своих романах?', question_tree=Node<?, <ROOT>>, answer='определённый этап исторического развития России', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что применяется в металлургии для раскисления?', question_tree=Node<?, <ROOT>>, answer='Кальций', answer_tree=Node<?, <ROOT>>),
#  Instance(question='С чем была связанна большая часть решений?', question_tree=Node<?, <ROOT>>, answer='С децентрализацией', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каких городах передаются два мультиплекса?', question_tree=Node<?, <ROOT>>, answer='В Астане, Алма-Ате', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Чем является ISBN. для каждого издания книги в любой стране, при условии принятия издателем этого стандарта?', question_tree=Node<?, <ROOT>>, answer='Уникальным идентификатором.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какое название носит телесериал, снятый по мотивам фильма о Шерлоке Холмсе?', question_tree=Node<?, <ROOT>>, answer=' Воспоминания о Шерлоке Холмсе ', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком году остров Аруба вышел из федерации Антильских островов и получил статус территории Королевства Нидерландов', question_tree=Node<?, <ROOT>>, answer='в 1986 году', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что описывали учёные латинизированный армянский период?', question_tree=Node<?, <ROOT>>, answer='Почти весь строй армянского языка', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Пол влиянием чего находилась эволюция взглядов?', question_tree=Node<?, <ROOT>>, answer='потребностей центрального банка', answer_tree=Node<?, <ROOT>>),
#  Instance(question='За что Хендрикс был приговорен к 2 годам заключения', question_tree=Node<?, <ROOT>>, answer='за угон машины', answer_tree=Node<?, <ROOT>>),
#  Instance(question='под чьим контролем была Вальтеллину в 1512-1797 годах?', question_tree=Node<?, <ROOT>>, answer='под контролем Граубюндена', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Кто по обычаю занимает пост президента?', question_tree=Node<?, <ROOT>>, answer='поочередно все члены Совета', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каком году вышла Фехтовальная книга Ганса Талхоффера, в которой были разделы о борьбе?', question_tree=Node<?, <ROOT>>, answer='в 1443 году', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Над каким произведением Лев Толстой работал за месяц до своей смерти ?', question_tree=Node<?, <ROOT>>, answer='над третьим вариантом повести Нет в мире виноватых ', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как расшифровыется аббревиатура ЗУП?', question_tree=Node<?, <ROOT>>, answer='Запасы, управляемые поставщиком', answer_tree=Node<?, <ROOT>>),
#  Instance(question='В каких средах происходит естественное перемешивание слоев?', question_tree=Node<?, <ROOT>>, answer='В газах и жидкостях.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Какие способности есть у людей?', question_tree=Node<?, <ROOT>>, answer='Воспринимать отношение с самим собой и с окружающей средой', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как назывался блог Колби Баззела?', question_tree=Node<?, <ROOT>>, answer=' Колби Баззел посылает войну на… ', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Где появились кафедры и даже факультеты политических наук?', question_tree=Node<?, <ROOT>>, answer='В европейских и северо-американских университетах.', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Что по мнению Камю борьба с насилием и несправедливостью их же методами могут породить?', question_tree=Node<?, <ROOT>>, answer='ещё большие насилие и несправедливость', answer_tree=Node<?, <ROOT>>),
#  Instance(question='Как иначе называется нижний ярус подземных вод прибалтийского артезианского бассейна?', question_tree=Node<?, <ROOT>>, answer='кембрийско-вендский', answer_tree=Node<?, <ROOT>>),
#  ...]

# %%
def find_sub(question_tree, find_list):
    for dec in question_tree.descendants(add_self=True):
        if dec.form.lower() in find_list:
            return True
    return False

def who_what_nom(question_tree):
    root = question_tree.children[0]
    if root.form.lower() in ['кто', 'что']:
        return True
    return False

def who_what(question_tree):
    root = question_tree.children[0]
    if len(root.children) > 0:
        clause = root.children[0]
        for word in clause.descendants(add_self=True):
            if word.lemma in ['кто', 'что', 'чем']:
                return True
    return False

def which_what(question_tree):
    root = question_tree.children[0]
    if len(root.children) > 0:
        clause = root.children[0]
        for word in clause.descendants(add_self=True):
            if word.lemma in ['какой', 'какая', 'какое', 'какие', 'чей']:
                return True
    return False

def kakovo(question_tree):
    root = question_tree.children[0]
    if root.lemma in ['каков']:
        return True
    return False

def time(question_tree):
    root = question_tree.children[0]
    if len(root.children) > 0:
        clause = root.children[0]
        for word in clause.descendants(add_self=True):
            if word.lemma in ['когда']:
                return True
    return False

def place(question_tree):
    root = question_tree.children[0]
    if len(root.children) > 0:
        clause = root.children[0]
        for word in clause.descendants(add_self=True):
            if word.lemma in ['где', 'куда', 'откуда', 'докуда']:
                return True
    return False

def cause(question_tree):
    root = question_tree.children[0]
    if len(root.children) > 0:
        clause = root.children[0]
        for word in clause.descendants(add_self=True):
            if word.lemma in ['почему', 'зачем', 'отчего']:
                return True
    return False


def way(question_tree):
    root = question_tree.children[0]
    if len(root.children) > 0:
        clause = root.children[0]
        for word in clause.descendants(add_self=True):
            if word.lemma in ['как']:
                return True
    return False

def quantity(question_tree):
    root = question_tree.children[0]
    if len(root.children) > 0:
        clause = root.children[0]
        for word in clause.descendants(add_self=True):
            if word.lemma in ['сколько', 'сколька', 'насколько']:
                return True
    return False

def whether(question_tree):
    for word in question_tree.descendants(add_self=True):
        if word.lemma in ['ли']:
            return True
    return False

# %%
a1 = []
a2 = []
a3 = []
a4 = []
a5 = []
a6 = []
a7 = []
a8 = []
a9 = []
a10 = []
a0 = []

for inst in tqdm(instances):
    for a, func in zip([a1, a2, a3, a4, a5, a6, a7, a8, a9, a10],
                  [who_what_nom, who_what, which_what, kakovo, time, place, cause, way, quantity, whether]):
        if func(inst.question_tree):
            a.append(inst)
            break
    else:
        a0.append(inst)
# Out:
#   0%|          | 0/5036 [00:00<?, ?it/s]

# %%
len(a0)
# Out:
# 271

# %%
for i in a1:
    print(i.question, '\n', i.answer, '\n')
# Out:
# Что такое инкубационный период?
#  в течение которого не проявляется никаких симптомов инфекции
#
# Что такое параматма?
#  сверхдуша
#
# Кто автор статьи Творчество Прокофьева в советском теоретическом музыкознании ?
#  Ю. Н. Холопов
#
# Что такое кроссбраузерность ?
#  обеспечение совместимости со множеством браузеров
#
# Что такое орган конституционного надзора ?
#  Государственный суд правосудия
#
# Что такое антенна Элтанина по мнению большинства ученых?
#  хищная губка Chondrocladia concrescens
#
# Что такое статья?
#  Один из самых распространенных и сложных газетных жанров.
#
# Что такое Табулатуры ?
#  Свод обязательных для выполнения правил музыкально-поэтического искусства мейстерзингеров
#
# Что такое результат, не требующий расчётов располагаемого и дискреционарного доходов.?
#  Потребление
#
# Кто такой фасилитатор?
#  человек, обеспечивающий успешную групповую коммуникацию
#
# Что такое доменное имя?
#  обозначение символами
#
# Что такое последний момент затмения?
#  Последнее касание
#
# Кто такие Polyergus?
#  Муравьи-амазонки
#
# кто такие позвоночные?
#  высший подтип хордовых животных
#
# Что такое сажень?
#  старорусская единица измерения расстояния
#
# Что такое межвидовое скрещивание?
#  скрещивание особей различных видов
#
# Что такое рестлинг в первую очередь?
#  это развлечение
#
# Что такое натурные наблюдения?
#  мониторинг плотины с помощью контрольно-измерительной аппаратуры
#
# Что такое углеводы?
#  Углево́ды — весьма обширный класс органических соединений
#
# Кто такие чешуекрылые?
#  Гусеницы, ведущие скрытый образ жизни
#
# Что такое оценка кредитоспособности ?
#  Кредитный скоринг
#
# Что такое геммулогенез?
#  Наиболее сложный тип бесполого размножения губок
#
# Кто был генеральный директор кондитерской фабрики Конфи до 1995 года?
#  В. И. Порядин.
#
# Что такое надвиг?
#  Вид разлома со смещением по падению
#
# Что такое ω?
#  ω — угловая скорость вращения Земли
#
# Что такое типологическая особенность языков банту?
#  система согласовательных именных классов с префиксальными показателями
#
# Что есть единственная функция состояния тел, определяющая направление самопроизвольного теплообмена между этими телами?
#  Температура.
#
# Что такое способность почвы служить культурным растениям средой обитания, источником и посредником в обеспечении земными факторами жизни и выполнять экологическую функцию?
#  Качество почвы
#
# Кто такой Фёдор Ива́нович Шаля́пин?
#  русский оперный и камерный певец
#
# Кто интеллектуальной собственности?
#  США
#
# Что такое тренд в экономике?
#  направление преимущественного движения показателей
#
# Что такое эмпатии ?
#  перевоплощения
#
# Что такое Prepaid card?
#  предварительно оплачиваемая карточка
#
# Что такое литературное произведение, обладающее особой ритмической структурой?
#  стихотворение
#
# Что такое время произвольного доступа (англ. random access time)?
#  среднее время, за которое винчестер выполняет операцию позиционирования головки чтения/записи на произвольный участок магнитного диска.
#
# Что такое ФОТАБ?
#  ФОТАБ
#
# Кто такие головохордовые?
#  Небольшие морские рыбообразные животные.
#
# Кто автор книги The Competitive Advantage of Nations?
#  М. Портер
#
# Что такое приспособленность?
#  способность организма к выживанию и размножению
#
# Что такое специальные прозрачные чешуйки , которые покрывают глаза змеи?
#  неподвижные веки
#
# Что такое полиандрия?
#  многомужество
#
# Что за вид наземного транспорта, перевозка грузов и пассажиров на котором осуществляется колёсными транспортными средствами по рельсовым путям?
#  Железнодоро́жный тра́нспорт
#
# Что такое безусловный контрольный пакет акций
#  50 % + 1 акция.
#
# Что такое саксофон?
#  музыкальный инструмент
#
# Что такое метод критической цепи?
#  метод планирования и управления проектами
#
# Что такое эндокардит?
#  воспаление внутренней оболочки сердца — эндокарда
#
# Что такое верхний слой земной коры, обладающий плодородием?
#  Почва
#
# Что такое относительная приспособленность?
#  число потомков с данным генотипом
#
# Кто такой Федоров?
#  лидер Национально-освободительного движения
#
# Что такое гусеничный дерматит? энтомоз, обусловленный раздражением кожи волосками гусениц некоторых видов.
#  Энтомоз, обусловленный раздражением кожи волосками гусениц некоторых видов.
#
# Что такое сердце?
#  фиброзно-мышечный полый орган
#
# Кто такой принц Флоризель?
#  один из героев Зимней сказки Шекспира
#
# Что такое ФАС?
#  Федеральная антимонопольная служба
#
# Что такое метатексты?
#  Тексты о языке.
#
# Кто такие сипаи
#   воины
#
# Что такое переднемоторность
#  редставляет собой объединение и содружественность в работе передних и задних крыльев
#
# Что такое эволюционная история видов, описывающая их изменения и генеалогические отношения между собой?
#  филогенез
#
# Что такое высшее проффесиональное образование?
#  Уровень профессионального образования, следующий после среднего общего или профессионального образования.
#
# Кто единственный в России расчётный депозитарий, обслуживающий все виды российских эмиссионных ценных бумаг?
#  Национальный депозитарный центр
#
# Кто такой Ф. С. Прядунов?
#  рудознатец
#
# Что такое кровный монтаж?
#  механическое разрезание и склейка ленты
#
# Кто такой Н. Н. Страхов?
#  Критик и философ
#
# Кто автор термина проблемные пьесы ?
#  Фредерик Боас.
#
# Что такое таксон для сравнительно-исторического языкознания?
#  Совокупность идиолектов
#
# Что такое IRES?
#  структура на 5 конце информационной РНК
#
# Что такое закалка?
#  быстрое охлаждение, аморфного материала
#
# Что такое прямые (директивные) методы?
#  административные меры в форме различных требований и норм
#
# Что такое рабочая сила в статистике?
#  Количество людей, готовых работать по найму.
#
# Кто такой характерный актер?
#  это артист, который специализируется на второстепенных ролях
#
# Что такое платформа?
#  Те продукты и услуги, которые позволяют объединить две группы пользователей.
#
# Что такое истинное опасение?
#  это подарок, это сигнал выживания
#
# Что такое процесс ассимиляции ?
#  операция отделения признака от корня сегмента и его ассоциации с соседним сегментом.
#
# Что такое кладистика?
#  направление филогенетической систематики
#
# Кто такой философ и теолог Альберт Великий?
#  Один из величайших мыслителей Средневековья, причисленный после смерти к лику святых.
#
# Что такое полития?
#   Средняя форма государства.
#
# Что такое реализм?
#  Верное воспроизведение действительности
#
# что такое сильня сферическя аберрация?
#  оптический дефект
#
# Кредитное товарищество что это?
#  вид кооперативного учреждения мелкого кредита, существовавший в Российской империи
#
# кто был отец Карла Линнея?
#  сельский лютеранский пастор
#
# Что такое же́нщина?
#  Же́нщина — человек женского пола или гендера.
#
# Кто был Лафайет по политическим убеждениям
#  Либерал
#
# Что такое сыта?
#  разведённый в воде мёд

# %%
for i in a2:
    print(i.question, '\n', i.answer, '\n')
# Out:
# Чем заболел Байрон в Миссолонги?
#  лихорадкой
#
# Что нарушают хромосомные аберрации?
#  Структуру хромосом.
#
# Кто считал что русская публицистическая литература восходит к „Слову о Законе и Благодати“ Илариона?
#  Игорь Дедков.
#
# О чем написано в песне Чайльд-Гарольда ?
#  Поездку на поля Ватерлоо
#
# Что изначально использовалось в качестве баттуты?
#  трубка из кожи, набитая шерстью, или рулон нот.
#
# Что может произойти со стоимостью нематериальных активов при разделении компании на части?
#  Может значительно снизиться
#
# что в режиме гибернации отключается?
#  питание ОЗУ
#
# Что содержат белки-каналы?
#  Внутренние заполненные водой поры
#
# Для чего используется добавка фторидов в соль?
#  для профилактики зубных заболеваний
#
# Кто разработал утилиту patch ( заплатка )?
#  Ларри Уолл
#
# Кто увидел вражеский аэроплан во время розведки?
#  лётчики
#
# На что укладывается верхнее строение пути?
#  земляное полотно
#
# Чем, помимо всего прочего, является Кёльн?
#  Крупнейшим музейно-выставочным центром.
#
# О чем говорилось в шестой части книги?
#  о причинах изменения широт планет
#
# Что обосновывается тем фактом, что Попов 25 марта 1896 г. провёл опыты с радиотелеграфией, послав на расстояние 250 м радиограмму?
#  Приоритет Попова
#
# Что сообщал Моцарт о Констанции в письме 15 декабря 1781 года ее отцу?
#  Что собирается жениться на ней.
#
# Что признали религиозные конфессии
#  возможность сочетания религиозных верований
#
# На чем основывались первые представления о строении атомов и природе химической валентности?
#  на закономерностях свойств элементов
#
# Что используют в качестве генератора импульсные РЛС метрового диапазона?
#  триодную лампу
#
# С чем связывается образ крысы?
#  с порчей, разрушением, смертью
#
# Что является главными преимуществами асинхронного ТЭД?
#  простота конструкции и малые габариты
#
# Что перенес Шостакович через несколько месяцев после смерти отца?
#  Тяжёлую операцию
#
# К чему в последующие этапы своего развития неоднократно возвращалась философия?
#  к релятивизму
#
# Что было принципиальным недостатком 4- и 8-дорожечных картриджей?
#  способ переключения дорожек
#
# Что позволяет шея жирафу?
#  срывать листья и молодые побеги с крон деревьев
#
# Что в вызывает мёд, собранный с рододендрона, в организме человека?
#  головную боль, рвоту, потемнение в глазах, а иногда и обморочное состояние
#
# Что произошло после после пика популярности?
#  интерес инвесторов к чистым технологиям снизился
#
# Кому передали Озерки родители Бунина?
#  сыну Евгению
#
# Что вызвало всплеск общественного интереса к этому направлению?
#  Публикация ряда результатов в открытой печати
#
# К чему привели ошибочные данные разветки Британии?
#  британская авиация нанесла бомбовые удары
#
# Кого несомненно возбудит занятие Порт-Артура или Да-лянь-вана?
#  Китай
#
# У кого ареалы часто сопряжены с распространением кормовых растений гусениц?
#  У монофагов и узких олигофагов
#
# Кому предаются полномочия в отсутствии управляющего в случае, когда число заместителей более одного?
#  Самому старшему по возрасту заместителю
#
# Формирование чего не происходит у губок в ходе эмбриогенеза?
#  зародышевых листков
#
# Что стало новым?
#  пчёлы полностью специализировались на опылении
#
# Что будет за изучение или попытки исправления ошибок программ путём дизассемблирования ?
#  могут преследоваться уголовным правом.
#
# Кто описал понятия рас, как исторически слагающиеся категории ?
#  Г. И. Петров
#
# Что утверждают некоторые критики относительно использования таксонов высшего по виду ранга в систематике?
#  эти таксоны не должны использоваться в систематике вообще
#
# Что должен делать Банк Канады?
#  способствовать экономическому благосостоянию канадских граждан
#
# Что было запатентовано и поступило в свободную продажу в 1907 году?
#  Фотопластинки Автохром братьев Люмьер
#
# На что расчленено тело у большинства млекопитающих?
#  на голову, шею, туловище, две пары конечностей и хвост
#
# Относительно чего законодательство Российской Федерации предъявляет меньшие процедурные требования к деятельности общества с ограниченной ответственностью?
#  чем к деятельности акционерного общества
#
# С чем была связана первоначальная неприятность дисков DVD-RW?
#  с несовместимостью старых приводов с этими новыми дисками
#
# Что отметили литературоведы глядя на произведения, созданных в эмигрантский период?
#  напрочь ушёл присущий Бунину прежде социальный посыл
#
# Кем публикуется Красный список угрожаемых видов
#  Международным союзом охраны природы и природных ресурсов
#
# что завоевали хозяева турнира
#  остались без наград.
#
# За что тренера раскритиковали ?
#  за неудачные перестановки
#
# В чём выражается это влияние?
#  в принятии физическими лицами, предприятиями и органами государственной власти экономических решений
#
# Кто построил первый каменный мост через Дунай?
#  Римский император Траян.
#
# Чем представлена у рыб система кровообращения?
#  только одним замкнутым контуром
#
# К чему привела тяжёлая жизнь при полуголодном существовании?
#  К сильному истощению
#
# Кому помог завоевать Англию в 1688 году другой шторм Протестантский ветер ?
#  Вильгельму Оранскому
#
# С помощью чего можно восстановить данные при подмене одного из секторов жесткого диска резервным?
#  При помощи ECC.
#
# Что вызывает изменения частот аллелей генов?
#  мутации, поток генов, естественный отбор и дрейф генов
#
# Кем писаны многие произведения средневековых поэтов?
#  Писаны под их диктовку женщинами.
#
# Что описывает Манну в романе
#  Манн описывает историю упадка и вырождения купеческой династии из Любека
#
# Что является один из этих негативных факторов,облегчающих распространение эпидемий?
#  Скученность городского населения
#
# Что используется в аксиоме Архимеда вместо тройки вещественных чисел?
#  тройка комплексных чисел
#
# Чем являются водородные соединения других элементов?
#  газами
#
# Кто вывел сорт розы Champneys Pink Cluster ?
#  Джон Чемпнис Чарльстон
#
# Кто развил философию в направлении абсолютного идеализма?
#  Фихте, Шеллинг и Гегель
#
# Что закрывается при сокращении камер сердца?
#  Клапаны остий.
#
# Кто отклонил проект идеального города Леонардо да Винчи?
#  Миланский герцог Лодовико Сфорца.
#
# Что изучает зоология?
#  животных
#
# Чем богата мантия Нептуна?
#  водой, аммиаком, метаном и прочими соединениями
#
# Кто приняли меры для предотвращения подобных эксцессов?
#  Регуляторы
#
# Кто написал роман Чего же ты хочешь?
#  В. А. Кочетов
#
# Кем было принято решение об организации конкурса по созданию герба и флага города Северодвинска в 2014 году?
#  депутатами
#
# Для чего используется отреставрированный интерьер?
#  для культурных мероприятий
#
# Чему должна учиться интеллигенция у деревни ?
#  нравственности
#
# Кто в основном выполняет междугородные автобусные перевозки в Шеффилде?
#  National Express
#
# В виде чего могут использоваться такие графики?
#  Как самостоятельные модели технического анализа.
#
# В отличии от чего в болгарском и македонском языках, при наличии определяемых слов перед существительным, определённый артикль ставится только в конце первого слова?
#  падежных форм русского языка
#
# Что показал отчёт за 2008 год?
#  климат в Шеффилде теплеет быстрее, чем в любой другой год
#
# Что может служить примером постмодернистского видения мира?
#  концепция диалога Левинаса
#
# Что подразумевается под словосочетанием полуторная конструкция?
#  расстояние между осями рулонов меньше, чем их максимальный диаметр
#
# Что было записано на обороте первой авторской рукописи Сергея Прокофьева?
#  положение незаконченной шахматной партии
#
# О ком Альфред Шнитке высказывался как об одном из величайших композиторов в русской музыкальной истории?
#  О Прокофьеве.
#
# К чему приходит Уатт в результате своих исследований?
#  к пониманию важности скрытой теплоты
#
# На чём построено различие гласных звуков по долготе?
#  на упорядочении слогов по признаку долготы/краткости
#
# что характеризует функция
#  изменение параметров сигнала
#
# Кому уступили место дагеротипия и калотипия?
#  мокрому коллодионному процессу
#
# Что было создано в Москве в 1922 году?
#  Персимфанс.
#
# Из чего состоит операционная система, которую разрабатывает Фонд свободного программного обеспечения ?
#  из открыто разрабатываемого программного обеспечения
#
# Обобщением чего являются постулаты термодинамики?
#  опытных фактов
#
# С кем в паре поюедила Морозова на Уимблдоне?
#  паре с Эверт
#
# Кем был получен первый патент на фотоаппарат, пригодный для моментальной фотографии?
#  Самуэлем Шлафроком
#
# Что требуется поездам из-за большой массы?
#  очень длинный тормозной путь
#
# Что наблюдается в современном обществе
#  Явный переход среди пользователей компьютерной техники
#
# С кем объединился Banco Central в 1991 году?
#  с Banco Hispano Americano
#
# Что является фундаментом этических норм?
#  законы функционирования рыночных структур
#
# На что направлена ценовая политика?
#  На достижение долго- и краткосрочных целей предприятия.
#
# Что не учитывается при расчете убыточности страховой компании?
#  Расходы на ведение дела
#
# Чем он украшен?
#  дорическими колоннами и настенной живописью
#
# Что прозрачно для радиоволн УКВ диапазона?
#  ионосфера
#
# Что позволяет уточнить или расширить список искомых ключевых слов?
#  использование в запросах булевых операторов
#
# Кто метит капельками мочи, экскрементами или выделениями пахучих желёз занимаемые ими участки обитания?
#  Многие млекопитающие
#
# Чем занимался петербургский Северный союз учащихся средних школ ?
#  просветительством
#
# Под руководством кого симфония стала наиболее продолжительной?
#  Вильгельма Фуртвенглера
#
# Кем управлялись средства до создания Администрации церковного имущества Святого Престола?
#  Специальной Администрацией Святого Престола
#
# Чем компенсировалось наличие безоружных устаревших самолетов у России?
#  примитивным вооружением германских самолётов
#
# За кого можно принять различающихся по окраске особей бабочки медведицы-кайя (Arctia caja)?
#  за представителей различных видов
#
# Над кем в полуфинале немцы взяли верх со счетом 2:1?
#  Над сборной СССР
#
# В чем состоит отличие между теневыми банками и обычными банками?
#  парабанки не принимают индивидуальные вклады от населения
#
# Кто занимает третье место по числу сбитых реактивных самолетов?
#  полковник ВВС Израиля Гиора Эпштейн
#
# Что отсутствует в какой-либо определённой среде ?
#  Выраженные приспособления к жизни
#
# Что является основным фильтром крови?
#  Селезёнка (красная пульпа)
#
# Что получил Шеффилд в 1893 году?
#  статус сити
#
# От чего зависит эффективность пастеризации молочного сырья?
#  от температуры и времени проведения процесса
#
# За что выступают шотландо-ирландцы?
#  Они преданы идее сохранения конституционных связей с британской короной
#
# За счет чего внешнее финансирование оказывается дороже внутреннего?
#  За счет привлечения кредитов или выпуска облигация
#
# Кто усматривает первооснову устойчивости и единства общества в признаках наличия коллективного сознания, общей воли, препятствующей губительной силе человеческого эгоизма?
#  Эмиль Дюркгейм.
#
# Кому подражает парусник Papilio agestor?
#  несъедобной данаиде сита
#
# Что относится к непроизводственным основным средствам?
#  жилые здания, детские сады, клубы, стадионы, больницы
#
# Что требуют граждане в стандартной ситуации
#  эффективного и ответственного управления
#
# Что постепенно уточнялось среди зоофитов ?
#  Систематическое положение
#
# Что подвергали анализу?
#  отношения согласования, управления и примыкания
#
# Кто добывал и использовал платину с незапамятных времён?
#  Цивилизации Анд (инки и чибча).
#
# От чего должны быть защищены провода троллейбуса?
#  От сближения
#
# К чему приурочены съёмки?
#  к 40-летнему юбилею оригинального сериала
#
# Что доминирует в промышленности Швейцарии?
#  Крупные объединения транснационального характера.
#
# Кто занимается распространением произведений?
#  издательство
#
# Из чего состоит вода?
#  из двух атомов водорода и одного — кислорода
#
# Над чем работал Лейбниц как инженер?
#  над вычислительными машинами, часами
#
# Чем отличается метромост от обычного моста?
#  повышенной прочностью
#
# Кто так отзывался о И.А.Бунине: Иван Алексеевич оказался в стороне от общего движения в области русского стиха .
#  Максимилиан Волошин
#
# Что представляют собой теплоэлектростанции, кинопромышленность (киноиндустрия)?
#  предприятия по ремонту промышленных изделий
#
# В процессе чего углерод в виде СО2 поглощается из тропосферы растениями?
#  В процессе фотосинтеза.
#
# Чем подстилается внутренняя поверхность ядерной оболочки?
#  ядерной ламиной
#
# Кем управлялся Мемель до этого?
#  назначенной Советом послов Директорией
#
# На чем сформировано мелкотоварное производство?
#  на частной собственности на производственные ресурсы и личном труде их владельца
#
# Что Покупатель передаст Продавцу в случае дефолта?
#  Обязательства Базового заемщика
#
# Кто занимается пресечением антиконкурентного поведения отдельных хозяйствующих субъектов на товарных и финансовых рынках
#  ФАС России
#
# Что предоставил эдикт Константина Великого в сам год его смерти?
#  право свободного перехода в христианство всякому желающему
#
# Для чего нужна третья космическая скорость?
#  чтобы покинуть звёздную систему
#
# Чему равна цена одного деления в шкале Цельсия?
#  цене деления шкалы Кельвина
#
# Кто рекомендует разработчикам и авторам документации не читать патентов во избежание преследования за сознательное нарушение патента или перестраховки из‐за неправильного прочтения?
#  Software Freedom Law Center
#
# Что при повышении давления частично превращается в жидкость?
#  насыщенный пар
#
# После чего город стал перестраиваться?
#  После того, как город получил статус административного центра губернии
#
# Что запретил Национальный банк Австрии, усмотрев угрозу своей монополии, когда более 300 общин в Австрии заинтересовались свободными местными деньгами?
#  печатание свободных местных денег
#
# Что особого было в этих городах
#  уникальные для Руси примеры государственного устройства
#
# С кем совместно Шаляпин разработал план будущего дома?
#  с архитектором Кузнецовым
#
# что помимо вещного права также присутствует?
#  доля неимущественного права
#
# Что дают компаниям различные методологии для внедрения управления эффективностью деятельности?
#  структуру
#
# Что критикует Мьевиль во Властелине колец ?
#  Идеи утешения и побега .
#
# Чем в понимании Чернышевского являлась община?
#  патриархальный институт русской жизни
#
# Что может делать имплантат?
#  измерять кровяное давление
#
# Кому принадлежали согласно буллы все земли к западу и к югу от линии, соединяющей полюса Земли и проходящей в ста лигах западнее и южнее любого из островов Азорских островов или островов Кабо-Верде ?
#  принадлежали Испании
#
# Кто обучал Шостаковича гармонии и оркестровке в Петроградской консерватории?
#  М. О. Штейнберг
#
# Из за чего Сирокко несёт пыль из Северной Африки в Южную Европу через Средиземное море?
#  в результате движения внетропических циклонов
#
# Что притягивается и отталкивается в соответствии с законом обратных квадратов?
#  магнитные полюса
#
# Кем было осуществлено строительство здания Пентагона?
#  Строительной компанией Джона МакШейна из Филадельфии
#
# Обо что происходит трение космического аппарата ?
#  об остатки атмосферы планеты
#
# Чем славилась монахиня Гросвита?
#  Славилась своей учёностью
#
# К чему обратился Кант в Критике чистого разума ?
#  к проблеме рационализма и эмпиризма
#
# От кого происходит класс Eumetazoa?
#  от одноклеточных предков
#
# С чем совпадает второе имя Байрона?
#  с девичьей фамилией матери
#
# Чем сопровождался набег тюрингов?
#  страшными жестокостями
#
# Кем финансируется шведский языковой совет?
#  шведским правительством
#
# Для чего была предназначена незаконченная гипертекстовая система Нельсона - Xanadu?
#  Для хранения и поиска текста, в который введены взаимосвязи и окна .
#
# С чем могут связываться молекулы конечного продукта метаболического пути?
#  С продуцировавшим их ферментом
#
# Кто в 1395 году принял титул герцога Миланского?
#  Джангалеаццо Висконти
#
# Кто был основателем эмпириокритицизма?
#  Рихард Авенариус
#
# Кем должно быть подписано распоряжение, на основании которого работник бухгалтерии совершает проводки, связанные с кредитной задолженностью?
#  уполномоченным должностным лицом банка
#
# Что дает основу для получения соответствующих оценок?
#  закон больших чисел в форме Чебышёва
#
# Что характеризует разрешение в оптическом микроскопе?
#  Чёткость изображения
#
# Что является важным элементом при создании портрета?
#  взгляд
#
# Что обеспечивает порядок и рамки, в которых протекает деятельность?
#  Социальный контроль
#
# С чем столкнулась Африка, окончательно закрыв древний океан Тетис?
#  Африка столкнулась с Евразией
# Чего не обнаруживают верхнепалеолитические черепа из Китая, Юго-Восточной Азии и Индонезии?
#  монголоидности
#
# Для чего необходимо синусоидальное напряжение ультразвуковой частоты?
#  Для подмагничивания при записи и для стирания записи
#
# Кто первым занялся изучением компьютерных игр?
#  сотрудники Копенгагенского университета информационных технологий
#
# Эксперименты по слиянию чего послужили толчком к началу расшифровки регуляторов митотического деления?
#  клеток, находящихся на разных этапах клеточного цикла
#
# За что отвечает Министерство охраны окружающей среды Манитобы?
#  экологическое состояние провинции
#
# Кто в 1865 году открыл законы наследственности
#  Грегор Мендель
#
# Чем по мнению некоторых авторов может быть автофагия при определённых условиях?
#  отдельным типом клеточной смерти.
#
# Кого из писателей указывает в своей монографии критик Ирина Васюченко в качестве предшественника и наследника Александра Грина?
#  Владимира Набокова
#
# Кто из игроков после игры подтвердили, что им делали уколы?
#  Отто Вальтер, Ханс Шефер и Хорст Эккель
#
# Что значит гомономно сегментированные грудные и брюшные отделы у некоторых примитивных видов ракообразных?
#  состоят из практически одинаковых сегментов
#
# Кто полагал, что движущими силами эволюции являются: определённая изменчивость, неопределённая изменчивость, борьба за существование и естественный отбор
#  Дарвин
#
# Кто выписывает сквозной коносамент?
#  Грузоотправитель
#
# Кто преподавал уроки Льюису Клайв Стейплзу?
#  Киркпатрик
#
# Кто способен к образованию эндоспор?
#  некоторые виды прокариот
#
# Чем при сооружении подводных лодок в СССР был вытеснен титан?
#  Высокопрочной сталью.
#
# Во что перерастал промысел после появления сложных и энергоёмких машин и механизмов?
#  в промышленность
#
# Что вызывает наличие в клеточной стенке фибриллярных нитей?
#   бегущую волну по поверхности клетки
#
# Кто описывал содержание реформы?
#  А. А. Корнилов
#
# Кого обыграла италия?
#  обыграли Норвегию
#
# Кто заметил: Именно в этой перспективе раскрывается Бунин-новатор, желающий быть продолжателем великой классической традиции в эпоху модернизма, но с тем, чтобы переписать всю эту традицию заново ?
#  литературовед Юрий Лотман
#
# На чем основывается традиционная систематика лишайников?
#  На микобионте.
#
# Что первоначально делает портретист после того, как заказчик присылает свое фото?
#  запускает компьютерную программу
#
# От чего не отличается принцип устройства клеточных мембран?
#  от эукариот
#
# Чем UBS объяснил свое решение отказаться от австралийского бизнеса?
#  повышением нормативных и клиентских требований
#
# Где, несколько позднее, чем в Великобритании, стала развиваться лёгкая атлетика?
#  в США
#
# Кто владел в 1896—1899 годах оперным театром в Москве?
#  меценат С. И. Мамонтов
#
# Что можно разместить в месте, где в SRAM размещается один триггер, хранящий 1 бит?
#  Несколько конденсаторов и транзисторов для хранения нескольких бит.
#
# Что обычно геометрия держит в руках?
#  глобус и циркуль
#
# Что отражают эмоции?
#  различные аспекты значения вызвавших их ситуаций
#
# Продуктами чего являются строительные материалы?
#  деревообработки и целлюлозно-бумажной промышленности
#
# Что приводит к нарушению изотопного состояния?
#  Физические процессы в природе.
#
# У кого на данный момент выявлены бактериоциты?
#  только у некоторых видов обыкновенных губок
#
# Кто предпринял масштабную и плодотворную попытку синтеза античных, схоластических и картезианских идей на основе метода всеохватности и строгости рассуждений?
#  Лейбниц.
#
# Кого называют предками птиц?
#  динозавров
#
# Чем дышит большая часть ракообразных?
#  кожными жабрами
#
# Что применяют в некоторых системах широкоформатного кино наряду с широкой киноплёнкой?
#  анаморфирование изображения
#
# На чем основаны полуколичественные подходы?
#  на квантовомеханической интуиции
#
# На ком был женат Л.Толстой?
#  На С. А. Берс
#
# Что написано на знаке, кроме NSF, даты и широты установки?
#   Geographic south pole
#
# Что обеспечивает уничтожение в молоке бактерий?
#  УВТ-обработка
#
# С помощью чего пытался контролировать экономику Роберт Мугабе?
#  с помощью военной силы
#
# Кто писал, что папа Корнелий был выбран в согласии с желанием Бога и Его Церкви, свидетельствами почти всего клира, собором старших по возрасту епископов (sacerdotum) и добрыми людьми ?
#  Святой Киприан Карфагенский
#
# Через что проходит кровь в правый желудочек?
#  Через трикуспидальный клапан (он состоит из трёх лепестков)
#
# Что может образовываться при нагревании кремния с металлами?
#  Силициды
#
# Что обладает самым большим и оптимальным временем?
#  диски для портативных устройств
#
# Кем в будущем были отредактированы стихи Микеланджело?
#  его внучатым племянником
#
# Кем был ослеплен князь Василий Тёмный?
#  своим двоюродным братом Дмитрием Шемякой
#
# К кому обращаются будущие владельцы сайтов для разработки?
#  Фрилансерам, студиям, бюро, конторам.
#
# Кем сделано открытие, что установления культуры существенно отличаются от законов природы
#  Софистами
#
# Что разрешает к применению внесистемной единицы рентген в Российской Федерации?
#  Положение о единицах величин
#
# Что ведёт ведёт к переходу от диплоидной фазы к гаплоидной в жизненном цикле ?
#  Уменьшение числа хромосом в результате мейоза
#
# Кто является самым маленьким из фигурантов антимонопольных дел в США?
#  компания Transitional Optical
#
# Кем и для чего был использован термин кибернетика?
#  Н. Винером для обозначения общей науки об управлении
#
# На что похож мембранный компартмент, окружающий цитоплазму при макроаутофагии?
#  На цистерну эндоплазматического ретикулума.
#
# Что открыла Япония когда пересмотрела свою прежнюю политику самоизоляции от внешнего мира ?
#  Некоторые порты для товарообмена с западными странами.
#
# Что рассматривают в технологиях управления риском?
#  обобщенные понятия случайного события
#
# Чем характеризуется бегство вкладчиков ?
#  наплыв в банк требований о возвращении вкладов
#
# На основании чего можно было проследить локальные различия в разговорной речи?
#  На основании диалектных форм, изредка попадавших в памятники
#
# От кого происходит Савойская династия согласно научным исследованиям?
#  от Беренгара II
#
# Что расположенное за рубежом, строится на земле, взятой в долгосрочную аренду у местных органов власти?
#  Объекты
#
# Что обеспечивают прочность, жесткость и устойчивость здания в целом и его отдельных частей под действием нагрузок от веса людей, мебели, оборудования, ветровых, сейсмических, снеговых и других временных нагрузок?
#  Несущие конструкции
#
# Кто формулирует идею эксперимента как источника знания?
#  Фрэнсис Бэкон
#
# Что делает пар, поступающий в цилиндр паровой машины
#  расширяется и перемещает поршень
#
# За кого призвала голосовать Мадонна в своём Instagram-аккаунте 1 сентября 2016 года?
#  за Хиллари Клинтон
#
# Чем питаются личинки речного окуня?
#  в основном зоопланктоном
#
# От чего отказалось постмодернистское искусство?
#  от попыток создания универсального канона
#
# Над чем значительно преобладают в российской философии этика, политическая философия, философия истории, философия религии?
#  Над исследованиями в области метафизики, эпистемологии и др.
#
# Что традиционно для средневекового хозяйственного режима?
#  соединение крестьянских домашних промыслов с патриархальным (натуральным) земледелием
#
# Что делает гильза раздуваемая пороховыми газами при традиционном заряжании
#  успешно изолирует патронник от остальных частей конструкции.
#
# Кто стал новым главным тренером Мейпл Лифс 20 мая 2015 года?
#  Майк Бэбкок
#
# С чем тесно связана философская система йоги?
#  со школой санкхьи
#
# К кому обращался Руссо задавая вопрос, хуже ли жилось бы человечеству без познания тайны мировых законов?
#  к просветлённым умам
#
# Что отсутствует в мембранах прокариот?
#  Молекулы холестерина и некоторых липидов
#
# Что существует на границах зон и поясов ?
#  Сильная турбулентность
#
# Кто внес в русский витраж значительный вклад в 19-ом веке?
#  Джон Ла Фарж и Луис Тиффани
#
# Что находится внутри селезенки?
#  трабекулы (балки)
#
# Кто стал главным тренером сборной Германии?
#  Эрих Риббек
#
# Что вызывают бактерии проникающее внутрь молодых корней ?
#  Образование клубеньков
#
# На что распространяется десятина dîmes insolites?
#  на картофель, сеяную траву и т. п.
# Что изменило саму структуру стекольной промышленности?
#  иностранный капитал
#
# Кто определяет в качестве отличительных признаков общества как объединения людей наличие географических границ, общую законодательную систему и определённую национальную?
#  Нейл Смелзер.
#
# Что нужно сделать после доставки на квартиру потребителя нового или подержанного инструмента?
#  проверить, при необходимости отрегулировать его механизм и настроить
#
# Что дает использование плавающих процентных ставок?
#  Серии процентных платежей
#
# Кто был обладателем неофициального статуса лидера экономического империализма?
#  Гэри Беккер
#
# Что происходило с душами согласно доктрине Оригена?
#  они продвигались по пути к совершенству
#
# Что делает избыточным вертикальную интеграцию в развитых рынках?
#  механизмы контроля над смежниками
#
# Что широко и неравномерно распространена в природе?
#  Полиплоидия
#
# Чему учили представители патристики, такие как Климент Александрийский, Василий Великий, Григорий Нисский и другие?
#  образ Божий заключается в разумности человека
#
# Что позволяет вынос электрооборудования троллейбуса на крышу?
#  понизить уровень пола
#
# Что предполагает иерархическая конструкция, предложенная Фелибьеном?
#  Иерархическая конструкция, предложенная Фелибьеном, предполагает, что индивидуализация может касаться исключительно человеческого существа.
#
# В чем находится фермент жизненной силы процесса брожения?
#  В дрожжевых клетках
#
# Кому в 2006 году Роспотребнадзор по результатам проверки жалобы заёмщика предъявил претензию о взимании комиссии за открытие ссудного счёта по договору потребительского кредита?
#  Банку Хоум Кредит
#
# Кому прусское правительство поручило представить своё юридическое заключение о правах на наследство в Шлезвиг-Гольштейне принца Августенбургского?
#  Особой прусской комиссии (Kronsyndicat).
#
# Что вмещает в себя Оранжерея?
#  растения десяти климатических зон
#
# Что происходит с территориальными обозначениями после реформ?
#  не обновляются
#
# Что представлял собой капсюль?
#  медный колпачок с легковоспламеняющейся инициирующей смесью внутри
#
# Что выполняет процедуру регенерации?
#  процессор или контроллер памяти
#
# Из чего состоит брюшко у перепончатокрылых?
#  состоит из 6—8 члеников, не считая членика, плотно соединённого с заднегрудью, и видоизмененных члеников.
#
# Кем был предложен способ описания структурного состояния стеклообразного вещества посредством характеристики так называемой структурной температуры Tf?
#  предложенный А. Тулом
#
# Кто является природными врагами чешуекрылых и преимагинальных стадий их развития?
#  В первую очередь являются насекомоядные позвоночные животные: птицы, ящерицы, жабы, грызуны, насекомоядные млекопитающие
#
# Кто остановил самозванца на пути к Киликии?
#  был разбит Костандином, братом царя Хетума I
#
# Чем характеризуется переход от инфляции к гиперинфляции?
#  началом неконтролируемого, галопирующего роста цен
#
# Что включает в себя создание комфортных внешних условий труда?
#  оформление рабочего места, мест отдыха
#
# Кто был назначен новым наставником сборной Италии по футболу?
#  Дино Дзофф
#
# Кто являлся бедным по Росстату
#  семейный человек с детьми
#
# Кем было сделано первое греческое издание?
#  Альдом Мануцием
#
# Чем ограничивалось время хода подводных лодок на электромоторе?
#  необходимостью частого всплытия для подзаряда аккумуляторных батарей
#
# Что нужно знать для совершения платежа по банковской карте ?
#  данные банковской карты
#
# Чем занимается?
#  денежно-кредитной политикой
#
# В качестве чего их применяют в различных устройствах и системах?
#  Исполнительных механизмов
#
# Чем Пристли и другие сторонники теории флогистона считали азот и кислород?
#  различными видоизменениями обыкновенного воздуха
#
# Кем назначаются главы государства?
#  Большим Генеральным советом
#
# С чем связаны логистические операции?
#  с преобразованием товарно-материальных ценностей и услугами в сфере коммерческого посредничества
#
# Чем сопровождаются эмоции?
#  специфической физиологической реакцией
#
# Кто разрабатывает и реализуюет во взаимодействии с Правительством Российской Федерации единую государственную денежно-кредитную политику и наделённый особыми полномочиями, в частности, правом эмиссии денежных знаков и регулирования деятельности банков?
#  Центральный банк Российской Федерации (Банк России)
#
# Что относится к драгоценным (благородным) металлам?
#  Золото, серебро и платина.
#
# На что жаловалась Вера в своих воспоминаниях?
#  на непредсказуемость и неуправляемость Грина
#
# Кто в мае 1667 года выдал Разину кузнечные мехи и другое снаряжение и пропустил воровскую флотилию без артиллерийского обстрела вниз по Волге?
#  Царицынский воевода Андрей Ункновский.
#
# Кто был родной тёткой А. С. Грина?
#  Изабелла Гриневская
#
# Что сохраняется в потомстве благодаря наследственности?
#  характерные черты вида
#
# Что начали изучать многие молодые люди?
#  способы развития тела
#
# Кому принадлежала идея создания электронной таблица VisiCalc?
#  Дэниелу Бриклину
#
# Что является дополнительным морфологическим признаком некоторых хромосом?
#  вторичная перетяжка
#
# Что происходит, когда денежное обращение часто уступает место натуральному обмену?
#  долларизация экономики
#
# Кто считал, что наземные животные произошли от земноводных, а те в свою очередь самозародились в илу?
#  Демокрит
#
# Кто являлся в то время послом США в Зимбабве?
#  Кристофер Делл
#
# Что приводит в движение пар, в двигателе внешнего сгорания?
#  паровые машины
#
# От чего образовано большинство приставок?
#  От слов древнегреческого языка
#
# Чем явилось учение Декарта для философии рационализма?
#  первым кирпичом в фундаменте
#
# Что выяснилось в ходе экспериментов по пересадке фрагментов тела одной губки к другой губке?
#  что колленциты участвуют в защитных реакциях
#
# Чем ограничился мэр, когда ему выпала честь управлять составом в ходе церемонии?
#  тем, что предстал перед фотокамерой в кабине машиниста
#
# Кто последовал за ними в Пизу, где и жил по-прежнему под одной крышей с графиней?
#  Байрон
#
# Кем был оккупирован в 1190 году город Конья?
#  участниками Третьего Крестового похода
#
# Кем предложили стать Д.Н. Толстому по возвращении?
#  Мировым посредником по 4-му участку Крапивенского уезда Тульской губернии
#
# Кто образует правление Банка Канады?
#  Управляющий и первый заместитель управляющего
#
# Для чего ещё создаётся особый вид войск?
#  Для обеспечения наведения переправ или временных мостов
#
# Что показывает Мадара во время битвы?
#  риннэган
#
# Кто ввел термин идеализм в философию?
#  Лейбниц
#
# Что устанавливает Воздушный кодекс Российской Федерации?
#  какое ведомство несет ответственность за летную годность всех летательных аппаратов
#
# Кто применил первую элективную среду?
#  С. Н. Виноградский
#
# На ком в основном лежит забота о подрастающем потомстве млекопитающих?
#  на самках
#
# Что отражает в себе космограмма?
#  относительное расположение тел Солнечной системы
#
# Что резко меняется в трудовой деятельности при карьерном росте?
#  характер работы
#
# Кто принимал участие в исследовании об общественной ценности немецких школ за рубежом?
#  политики, чиновники, представители профсоюзов
#
# Кому было поручено управлять Сибирью после ее завоевания?
#  Посольскому приказу
#
# Отец кого отказывался видеть Бунина своим будущим зятем?
#  Варвары
#
# С помощью чего применяют навесной монтаж?
#  С помощью крана
#
# Автор чего Грибоедов?
#  Он — автор нескольких фортепианных пьес
#
# Что входит во время оборота?
#  Включается время (несколько минут) для отдыха водителя.
#
# Что Леонардо да Винчи признавал единственным критерием истины?
#  опыт
#
# С точки зрения чего совместим между собой подвижной состав двух дивизионов?
#  ширины колеи
#
# Что получено по ленд-лизу?
#  Высокие доли продукции машиностроения.
#
# Что поддерживает подпоясанную куколку помимо кремастера?
#  специальный паутинистый поясок
#
# Этапы чего показывал Гончаров в своих романах?
#  определённый этап исторического развития России
#
# Что применяется в металлургии для раскисления?
#  Кальций
#
# С чем была связанна большая часть решений?
#  С децентрализацией
#
# Чем является ISBN. для каждого издания книги в любой стране, при условии принятия издателем этого стандарта?
#  Уникальным идентификатором.
#
# Что описывали учёные латинизированный армянский период?
#  Почти весь строй армянского языка
#
# Пол влиянием чего находилась эволюция взглядов?
#  потребностей центрального банка
#
# За что Хендрикс был приговорен к 2 годам заключения
#  за угон машины
#
# Кто по обычаю занимает пост президента?
#  поочередно все члены Совета
#
# После чего австралийский мир сумчатых претерпел существенные изменения?
#  после появления человека
#
# На что обменивалась местная валюта Северной России времен Гражданской войны в Государственных эмиссионных кассах?
#  на фунты стерлингов и наоборот
#
# Что выражают имиджевые слоганы?
#  смысл философии компании, бренда, товара или услуги
#
# Что стоит на первом месте в творчестве Мадонны?
#  внешнее выражение
#
# Тенденцию к чему имеют политеистические религиозные традиции?
#  к меньшему абсолютизму
#
# Что простирается на восток-юго-восток от плато Амстердам?
#  Австрало-Антарктическое поднятие
#
# Кем, по мнению Джона Рея, изначально были сотворены обобщенные им виды животных и растений?
#  Богом
#
# Кто направлял Герцену подробные обзорные письма?
#  Тургенев
#
# Что не исчезло вместе со снижением интереса к западному средневековью?
#  Витражи
#
# С кем состоит в отношениях дочь Кинга Наоми?
#  с женщиной по имени Тандека
#
# Что чаще всего берется для процесса насильственного окончания жизни?
#  материалы, которые оказались под рукой
#
# Что может привести к задержке финансирования бюджетных учреждений, срыву сроков выполнения государственных и муниципальных заказов, возникновению проблемы неплатежей в народном хозяйстве?
#  Небольшая часть бюджетов дефицитна
#
# Чем является новый район в западной части Васильевского острова?
#  фасадом Санкт-Петербурга
#
# От чего следует отличать правильное и эффективное управление?
#  от так называемого камлания и воздействия
#
# Что предполагалось построить?
#  Посёлок-сад
#
# Чем отличался европейский вариант от американского?
#  перфорацией
#
# Что позволяло выдуманным документам казаться настоящими?
#  Сочетание выдуманных документов с реальными
#
# К чему может привести сокращение совокупного предложения?
#  к таким последствиям, как стагфляция и инфляция издержек
#
# Что заняло главное место в творчестве Ван Гога?
#  прихотливо искривлённый контур
#
# От чего зависит платная ли продукция у издательства или нет?
#  От целей существования издательства и от его бизнес-модели.
#
# Что используется в современных патронах заводского изготовления?
#  полиэтиленовые пыж-контейнеры
#
# Во что переходят бронхи в процессе многократного разветвления?
#  Переходят в терминальные бронхиолы
#
# Что Лавуазье определял совместно с Жан-Шарлем Борда?
#  расширение меди и платины
#
# На чём играют шашками?
#  на расчерченной доске
#
# Что сделал Шекспир после лирического Ричарда II ?
#  Шекспир ввёл прозаическую комедию в свои хроники Генрих IV, части 1
#
# Кто требуется банку и клиенту, чтобы правильно структурировать сделку?
#  посредник-переводчик
#
# Для понимания природы чего многое сделали Людвиг фон Мизес, Фридрих Август фон Хайек ?
#  природы предпринимательства
#
# Что происходит с организмом-хозяином в результате деятельность паразитоидов?
#  либо гибнет, либо теряет способность к продолжению рода
#
# Чем Западная Сибирь сменяется на юго-востоке?
#  предгорьями Алтая, Салаира, Кузнецкого Алатау и Горной Шории
#
# Что высмеивал Тиль везде?
#  человеческие слабости и пороки
#
# О чем говорилось в пятой части книги?
#  о планетах вообще
#
# Что стало итогом межплеменных столкновений?
#  вокруг поселений появляются укрепления
#
# В кого преобразуется мизидная личинка?
#  во взрослое животное
#
# Из-за чего в СССР тоннелестроение получило значительное развитие?
#  в связи с интенсивным железнодорожным строительством, созданием сети ГЭС, сооружением метрополитенов и объектов городского подземного хозяйства
#
# На чем основана традиционная экономика?
#  на традициях, передающихся из поколения в поколение
#
# Что называют разновидностью наземного строительного сооружения с помещениями?
#  Зда́ние
#
# Что называется нуклеокапсидом?
#  комплекс белков вирусного капсида с вирусной нуклеиновой кислотой
#
# Кем рассматриваются дела возбужденные ФАС России?
#  создаваемой для этих целей комиссией
#
# О чем обманчивы обыденные представления, как об устаревшем в современном обществе явлении?
#  о ремесле
#
# Кто преподавал в Лейденском университете в период опубликования сочинения Линнея?
#  профессор Германа Бургаве
#
# Что служит примером универсальной модификации белка?
#  Убиквитинирование
#
# Что является важным источником азота в питании организма?
#  Аминокислоты
#
# Что сделала инфляция после распада СССР?
#   съела копейку
#
# Что происходит если очередная цена продолжает двигаться в направлении прежней вертикальной Каги-линии?
#  линия будет продлена
#
# кто закончил работу Брюллова
#  П. В. Басину
#
# Кто в Белоруссии занимается отладкой систем передачи цифрового телевидения?
#  МТИС
#
# Чем стал для техники бескомпрессорный двигатель внутреннего сгорания высокого сжатия с самовоспламенением?
#  наиболее экономичным стационарным тепловым двигателем
#
# Кто выражал сомнения в реальности социального прогресса?
#  Теодор Адорно
#
# Чем в живых организмах определяется аминокислотный состав белков?
#  Состав белков определяется генетическим кодом.
#
# Из чего сделана древняя дорога Свит-Трек, обнаруженная на острове Великобритания?
#  перекладин из молодых ясеня, дуба и липы и дубового настила
#
# Кем была создана комиссия, принимающая идеи, для создания флага и герба города Северодвинска в 2014 году?
#  управлением культуры и общественных связей
#
# Что поддерживают конвенции?
#  воспроизводство социального поведения
#
# Что относится к международным видам борьбы?
#  греко-римская борьба, вольная борьба и дзюдо
#
# Что увеличивают головки на основе туннельного магниторезистивного эффекта?
#  вероятность достоверности считывания информации
#
# Что является главной особенностью общей циркуляции атмосферы Марса?
#  фазовые переходы углекислого газа в полярных шапках
#
# По мере чего осуществляется транспорт белков в ЭПР?
#  По мере их синтеза
#
# Поддержание чего являлось главной целью китайских философов?
#  гармонии и порядка в государстве и обществе
#
# У кого в частном секторе возникли затруднения в убеждении капиталистов в большой коммерческой ценности изобретения?
#  у владельцев патентов
#
# На что ссылался Луи Фейн обосновывая такое название школы?
#  на Management science
#
# К чему относится провинциальный в Австралии?
#  к частям штата за пределами столицы
#
# Кто пролетел мимо Юпитера?
#   Кассини .
#
# Что в строении черепа кита способствует особому способу дыхания?
#  ноздри смещены на темя
#
# Кто не мог мириться с таким порядком вещей ?
#  Аскетическая мысль православного Востока
#
# Что излучается при распаде изомерных состояний ядер?
#  один или несколько гамма-квантов
#
# Что дало возможность выйти на экран второму и третьему сезону Энтерпрайза ?
#  массовая поддержка фанатов Звёздного пути
#
# Благодаря чему стало возможным эффективное образование и накопление знаний?
#  развитию двух отделов нервной системы
#
# Кто открыл вирус гепатита B?
#  Барух Бламберг.
#
# В чем заключается практическое значение насекомых для человека?
#  главным образом, вред
#
# Для чего была доработана авиационная пушка Нудельмана-Рихтера НР-23 — модификация хвостового орудия реактивного бомбардировщика Ту-22 ?
#  для стрельбы в вакууме
#
# Кому Франция предоставила возможность обучаться на своем языке после завоевания Алжира, Марокко и Туниса?
#  берберам
#
# Для чего гончары Южной Америки добавляли порошок из сушенных бадяг в гончарную глину?
#  для повышения прочности изделий из неё
#
# Кто стал первым из образцов Байрона?
#  Роберт Раштон
#
# Что было сформировано, после официального обозначения города, как административного центра?
#  городническое и уездное правления
#
# Что происходит с суммой обеспечением заявки после проведения аукциона?
#  сумма возвращается
#
# Чем представлено русское зодчество в Иркутске?
#  Старейшим каменным зданием, сохранившимся от острога — Спасской церковью.
#
# В чем арабы видят залог приспособления арабского литературного языка к современному состоянию общества?
#  В богатстве и чёткости словообразовательных парадигм.
#
# Во время правления кого проводились работы Пьером Леско?
#  Генриха II и Карла IX
#
# Кто является крупнейшим специалистом по истории российской и советской науки?
#  Лорен Грэхэм
# Что давала ювелирам выдача резервных монет в виде кредитов под проценты?
#  генерировала доход для ювелиров
#
# К чему привела нехватка драгоценных металлов?
#  монеты почти не выпускались
#
# Во сколько раз больше было самолетов в России, чем в Англии перед Первой Мировой войной?
#  в 4 раза
#
# Что играет важную роль в линьке у ракообразных?
#  нейросекреторные клетки, связанные с упоминавшейся выше синусовой железой, и небольшой эндокринной головной железой.
#
# Кто привел сборную Германии к худшим результатам?
#  Эрих Риббек
#
# Для чего использовалась немецкая резьба из дерева?
#  для алтарных и других церковных украшений.
#
# Что характеризует величину притока денег, если оно больше нуля, или оттока денег, если оно меньше нуля?
#  численное значение денежного потока
#
# Чем отличаются чешуекрылые от ручейников
#  особенностями жилкования крыльев; формой волосков, модифицированных в чешуйки
#
# К чему можно отнести значительную часть сочинений Линнея?
#  к описательной естественной истории
#
# Что осуществляют предприятия ПАО Калмэнергосбыт , ПАО Южная межрегиональная энергетическая компания , ПАО Калмэнергоком , ПАО Калмэнерго в Элисте?
#  Производство и распределение электроэнергии
#
# Что позволяет людям инвестировать свои деньги без потери возможности использования их по требованию?
#  Частичное банковское резервирование
#
# В рамках чего для культуристов актуальна потеря лишнего жира?
#  в рамках подготовки к различным соревнованиям
#
# Что было у него в квартире — роскошь для Вены того времени?
#  собственный бильярдный стол
#
# Схватку с кем Холмс описывает Ватсону в рассказе Пустой дом ?
#  профессором Мориарти
#
# Что часто демонстрирует в социальных науках общество в целом?
#  стратификацию
#
# Для чего система директ-костинга имеет большое значение?
#  для глубокого анализа работы предприятия
#
# Что не происходит при рекомбинации?
#  изменения частоты аллелей
#
# Для сопряжения с чем предназначена ЦВМ-101?
#  с бортовой системой управления МКС
#
# В чем состоит, в целом, роль ритма в стихотворении?
#  в придании тексту своеобразной музыкальности
#
# Кем был создан первый варп-звездолет землян?
#  доктором Кохрейном и его помощницей Лили Слоун
#
# На 40 % от чего формировались доходы журнала Вокруг света в 2010-х годах?
#  от продаж
#
# Для чего создан музей?
#  Музей призван показать зависимость человека от растений.
#
# Чему придавалось особое значение?
#  запискам, воспоминаниям, дневникам, автобиографиям и т. п.
#
# Что, как правило, не ограничено в тех видах борьбы, где возможна только чистая победа, а нет победы по очкам?
#  время встречи
#
# Из чего состоит трисахарид рафинозы?
#  из молекул глюкозы, фруктозы и галактозы
#
# На чем базируется фундаментальный анализ?
#  на сравнении финансовых мультипликаторов эмитентов
#
# Кем занимались все государственные должности?
#  выходцами из протестантского меньшинства
#
# Что насыпалось в гильзу для патрона Боксера?
#  порох
#
# За счет чего повысилась общая производительность?
#  добавления недорогих и легко заменяемых компьютеров
#
# Кто является соседом Португалии на Иберийском полуострове?
#  Кастилия
#
# Что способна к изменению своего состояния, и все естественные изменения монады исходят из её внутреннего принципа?
#  Монада
#
# Кто был спутником Йохансена по походу на Северный полюс?
#  Нансен
#
# У кого был постоянный приток иностранных исполнителей?
#  Новый латинский джазовый Ренессанс
#
# К чему мог привести сам факт публикации статьи Рагу из синей птицы в центральной газете?
#  к серьёзным последствиям для группы
#
# Что было после смерти папы Климент IV?
#  двадцать кардиналов никак не могли избрать папу
#
# Что играет важную роль для нормального функционирования белков?
#  Поддержание правильной пространственной структуры
#
# Что располагается внутри личинки?
#  склероциты, археоциты, секреторные клетки, колленциты, а также личиночный скеле
#
# Что отличает взрыв от горения?
#  Различие механизмов передачи энергии
#
# С кем местные носители сохраняли некоторые торговые контакты?
#  с Италией и Иллирией
#
# Чем питаются хищьные рыбы?
#  Хищные рыбы используют в качестве пищевого ресурса широчайший спектр объектов.
#
# Между кем банк перед IPO распределил 3 % акций?
#  среди семи ключевых сотрудников
#
# Из чего состоит государственная школьная система в кантоне Женева?
#  Из начальных школ (фр. écoles primaires) (4-12 лет) и периода специализации (фр. cycles d orientation) (12-15 лет).
#
# Что полагал Янсзон, высадившись на австралийский континент?
#  что это южное продолжение Новой Гвинеи
#
# Что фиксирует датчик?
#  Данные
#
# Что было открыто во дворце после восстановления?
#  Национальная галерея
#
# Что отыскала божественная мудрость?
#  одну потерянную драхму
#
# Что думал Ломоносов про финский, мексиканский (ацтекский), готтентотский, китайский языки?
#  учёный отрицал какое-либо родство упомянутых языков
#
# Что произойдет в результате развития зародыша из потомков данного ядра, описанного в примере?
#  Развитие клеток женской половины тела
#
# Что является основным ограничением создания троллейбусных линий, работающих на большей установившейся скорости?
#  контактная сеть и токосъёмники
#
# По чему диссертант отвечает на вопросы диссертационного совета?
#  По своему докладу, диссертации и автореферату.
#
# Что Байрон чувствовал острее многих?
#  Безнадёжное несоответствие романтических идеалов и действительности.
#
# Что сыграло важную роль в установлении дальности радиосвязи 150 км?
#  новая конструкция передатчика
#
# К чему чаще всего прикреплена куколка?
#  к субстрату
#
# Что опубликовал через год журнал Современные записки (1925, № 23-24) ?
#  новую повесть Бунина Митина любовь
#
# От недостатка чего может погибнуть человек, дыша воздухом с высокой концентрацией метана?
#  кислорода
#
# Кто писал о естественных модификациях, происходящих во время воспроизводства, накапливающихся в течение многих поколений и приводящих к формированию новых видов?
#  Мопертюи
#
# Что обнаружил в почве дрейфующих льдов восточного побережья Гренландии Нансен Фритьоф?
#  диатомеи
#
# Что является главной задачей классификации?
#  Описание разнообразия вирусов и группировка их на основании общих свойств
#
# С помощью чего регистрируются оптические излучения в фотоаппарате?
#  Фотоматериала или светочувствительной матрицы.
#
# Что продукт все же вызывает горение водорода?
#  чистая вода
#
# Чем может быть предусмотрено преимущественное право приобретения акций самим обществом?
#  Устав
#
# Что образуется между предсердием и желудочком?
#  Митральный (двухстворчатый) и трехстворчатый (трикуспидальный) клапаны
#
# Кто был поставлен во главе правления?
#  Тюрго и Мальзерб
#
# Что перед смертью попросил Ариперт у дворян?
#  Избрать на престол совместно двух его сыновей.
#
# Кто по политическим взглядам был, скорее, умеренным традиционалистом, склонявшимся больше к дистрибутизму и либертарианству с монархическим уклоном в пользу укоренившихся договоров, правил и ортодоксальности, чем инноваций и модернизации?
#  Толкин
#
# Что создает опорную реакцию для рамы?
#  поток касательных усилий
#
# Кто приказал остановить ввоз платины и утопить остатки в море?
#  испанский король
#
# ...
#
# Что из действующего на куколку отражается в признаках самой бабочки?
#  Различия внешних условий
#
# Под начало кого поступил Нансен в возрасте 21 года?
#  Даниэля Корнелиуса Даниэльсена.
#
# Что представляют собой кредитные потолки для частных клиентов?
#  лимит суммы или количества кредитов
#
# Кто в Житии Ансгара зафиксировал конкуренцию?
#  Римберт
#
# Кто считал, что юмор – это средство решения психической проблемы простейшими способами, успешно опробованными индивидами в самом начале жизни ?
#  З. Фрейд
#
# Что любил Льюис?
#  любил прогулки, но не путешествия
#
# От чего зависит тип дробления?
#  От количества желтка и его расположения в яйце.
#
# К чему следует избегать стремления ?
#  к низкому уровню инфляции
#
# Что дополнительно включает поле исследований теоретической информатики?
#  широкий спектр тем, связанных с более абстрактными логическими и математическими аспектами вычислений.
#
# Из чего состоят аналитические глагольные формы?
#  Из вспомогательных глаголов и неличных форм (будущее, перфект).
#
# Кто спроектировал кампанилу Флорентийского собора?
#  Джотто
#
# Для чего разрабатывался ракетно-космический комплекс Союз ?
#  для пилотируемого облёта Луны
#
# Кто является полноправной правопреемницей сборных Веймарской республики, Третьего рейха и ФРГ?
#  Нынешняя сборная Германии.
#
# Что утратили вирусы?
#  гены
#
# Что было выделено из общего товарного ряда на роль особого товара ?
#  золота
#
# кто в 2011 году добился от компании Facebook предоставления его конфиденциальных данных на оптическом носителе?
#  студент юридического факультета Венского университета Макс Шремс
#
# Что может передаваться в дар какому-либо учреждению, ведомству, то есть сохранять или менять свою принадлежность?
#  Частные музеи
#
# Что было основой хозяйства с конца 1-го тысячелетия в Прибалтике?
#  Пашенное земледелие
#
# Права на что продал Гослинг компании UniPress?
#  на распространение Emacs
#
# Что означает слово космонавтика , астронавтика ?
#  Искусство вождения космического (межзвёздного) корабля
#
# Кто в 1808 году основал Высшую школу?
#  Доситей Обрадович
#
# Кому писал Лейбниц о вендах в письме 23 ноября 1712 года?
#  генералу Брюсу
#
# чего считывающие головки в рабочем режиме не касаются?
#  поверхности пластин
#
# Из чего состоит вирион?
#  нуклеиновой кислоты, покрытой защитной белковой оболочкой
#
# Что позволяют сделать биометрические системы аутентификации?
#  сохранять информацию о платежных данных клиента в безопасности
#
# Чему в баррелях равна лошадиная сила?
#  1 баррель·миля/ч
#
# Что является источником заряженных частиц для создания магнитосферы у Юпитера?
#  солнечный ветер и его спутник Ио
#
# Кем является банк для страховых компаний ЗАО Русский Стандарт Страхование и ООО Компания Банковского Страхования ?
#  агентом
#
# Чем описывается отзыв твёрдого тела на прилагаемое усилие?
#  модулями упругости
#
# Что ускорило процес социальных перемен в Мавритании?
#  Засуха
#
# С чем связаны упреки некоторых ученых?
#  в одни группы объединены организмы с совершенно разными экологическими функциями
#
# С чем связан ряд морфологических и физиологических изменений, из-за которых можно с уверенностью делать вывод, что все крылатые насекомые являются потомками одного общего вида?
#  С развитием у насекомых крыльев
#
# Чем защищены глаза змей?
#  сросшимися прозрачными веками
#
# Что хранят кассовые резервы?
#  товары конечного объема или количества
#
# Что произошло при племянниках графа Пьера II?
#  Пьемонт и Савойя разделились
#
# Кем готовилось покушение на императора?
#  А. К. Соловьевым
#
# Кто еще имел те же права и обязаности что и Председатель СФРЮ?
#  Президиум СФРЮ
#
# Что представляют собой чешуйки на крыльях чешуекрылых?
#  видоизменённые щетинки
#
# С чем связано возникновение суховеев в степных районах края?
#  Усилением ветра
#
# Кто жил в пещерах в Сакромонте?
#  цыгане
#
# Кто по наследству получил Уайт-хаус?
#  принцесса Августа Саксен-Готская
#
# Что удалось сохранить народу баски?
#  Свои архаичные социально-экономические структуры
#
# Кто в настоящее время, в рамках Федеральной резервной системы, способствует ценовой стабильности и устойчивого экономического роста в Новой Англии и нации?
#  Федеральный резервный банк Бостона
#
# Кто внедрял пакеляжное покрытие дорог во Франции?
#  П. Трезаге
#
# Кто исполнял роль современной мэрии?
#  Приказная изба
#
# Кого прогоняли антилопы канны в сомкнутом строю ?
#  гепардов
#
# Что случилось с Юрием Игоревичем?
#  остался защищать Рязань, но на шестой день осады был убит
#
# Чем обладал Фишер?
#  повышенной восприимчивостью к освещению и шумам
#
# С чем сравнивают Илиаду и Одиссею ?
#  Сравниваются с киклическими поэмами.
#
# Кто согнали всех жителей гетто и заперли в тесной синагоге без возможности еды и питья, отправления естественных надобностей?
#  Власти
#
# Что сделали в конце концов индейцы, истомленные голодом, которые не могли жить в прериях без бизонов?
#  покорились и переселились в резервации
#
# На кого в этом повлиял Лейбниц?
#  На Иммануила Канта
#
# С помощью чего обширные пласты воздуха поднимаются вверх?
#  За счёт многоуровневой конвергенции.
#
# Что представляет весьма различное строение?
#  Личинки
#
# С помощью чего можно вычислить углы?
#  различных измерительных приборов и приспособлений
#
# Что обеспечивает связь AF с мембранным клеточным рецептором агрегации (AR)?
#  Галектин
#
# Кто в конце XIX столетия попытался выплавить медь из норильской руды?
#  купец К. М. Сотников
#
# Кто использует органическую рациональность в эволюционном подходе?
#  Ричард Нельсон, Сидней Уинтер, Армен Алчиан
#
# К чему не ведут аскетические усилия сами по себе?
#  к совершенству
#
# Что произошло в битве с Сасори ?
#  Все три марионетки были разрушены
#
# От чего зависит дифференцированный подход в разработке стратегии?
#  от сущности и характера их деятельности
#
# Достоверность чего именно не может гарантироваться точностью чисел?
#  учётной информации
#
# Что важно сделать для установления функций отдельных компонентов клетки
#  выделить их в чистом виде
#
# Кто объявил о разработке механической системы рекуперации?
#  Williams
#
# Чем возможно объясняется появление в Македонии XIV в. палатальных звуков К и Г ?
#  влиянием сербского языка
#
# Что изменила денежная реформа 1994—1996 г.г. на Украине?
#  всю систему денежного обращения Украины
#
# Для чего применяли высокое начертание буквы Т помимо экономии места?
#  для красоты
#
# кем была рассказана история хлодвига
#  Григорием Турским
#
# ЧТо сочинил в пять с половиной лет Прокофьеву С.С.?
#  пьесу для фортепиано Индийский галоп
#
# Что глубоко поразила Гайдна?
#  Смерть Моцарта
#
# что писали в царствование Иоанна Васильевича и Феодора Иоанновича в грамотах?
#   на Дон Донским атаманам и казакам
#
# Кто изучал разницу между либералами и консерваторами в связи с тем, что есть связь между моралью и политикой?
#  Джонатан Хайдт и Джесс Грэм
#
# Чем было мотивировано решение о крупных инвестициях в рынок недвижимости Австралии?
#  стратегической важностью Азиатско-Тихоокеанского региона
#
# В чем возникла необходимость после прибытия Колумба из Вест-Индии ?
#  необходимость в разделении сфер влияния между Испанией и Португалией
#
# Кто писал: Представим долготу времени, которого сии языки разделились! Подумай же, когда курляндский! Подумай же, когда латинский, греческий, немецкий, российский! О глубокая древность ?
#  Ломоносов
#
# Чем является диоксид кремния в нормальных условиях?
#  Твёрдым биоинертным, неразлагаемым веществом.
#
# Что происходит при длительном хранении быстро замороженного молока?
#  Перекристализация.
#
# В чем может выражаться идеология национализма кроме политических манифестов?
#  в литературных произведениях, научных трудах и так далее
#
# Что делает положение миног неоднозначным?
#  У них в наличии недоразвитый череп и рудиментарные позвонки
#
# Что расположено внутри хоботка чешуекрылых?
#  мелкие чувствительные волоски
#
# Чем можно легировать кремний ?
#  Фосфором.
#
# Чем являлись натуральные макеты охотничьей добычи и цветные отпечатки рук?
#  Источниками изобразительных форм
#
# Что отражает трактовка термина финансы без уточняющих прилагательных только по отношению к общественному сектору экономики?
#  начальную стадию развития западной финансовой науки
#
# В чем искал утешение Жан-Жак Руссо?
#  в природе
#
# Что обычно делал Байрон на вспышки гнева свой матери?
#  Отвечал насмешками.
# Кто впервые объеденил языковые группы в один уральский язык?
#  Родство финно-угорских и самодийских языков доказал Э. Н. Сетял
#
# Что сыграло большую роль в становлении современных концернов?
#  динамика финансовых рынков 1960-х
#
# Чем определяется температура варки стекол?
#  компонентами этих стеклообразующих расплавов
#
# На что делятся породы по содержанию щелочей?
#  На серии.
#
# Что объединяют горизонтальные концерны?
#  похожие фирмы с различной клиентурой
#
# С чем связаны истоки джаза?
#  С блюзом
#
# Что Леонардо да Винчи направил по адресу знаменитого проповедника Джироламо Савонаролы?
#  пророчества
#
# Чем созывались сессии Народной скупщины, провозглашались законы, даровались помилование, награждались наградами?
#  Указами
#
# Что происходит в многоклеточном организме при гибели большинства клеток?
#  Начинает страдать организм в целом
#
# Что включает репликация вируса?
#  синтез мРНК ранних генов вируса
#
# Что представляет собой решение уравнения Декартом через построение отрезка с длиной, равной корню уравнения?
#  Анахронизм
#
# От чего не зависит вероятность получения прибыли от арбитража букмекерских ставок?
#  от исхода состязания
#
# Что происходит с детьми, оставленные своими родителями и воспитанные чужими?
#  не могут узнать своих отцов
#
# Кто сообщил Левенгуку о семенных зверьках ?
#  Его друг, студент-медик Иоганн Гам (Johan Ham)
#
# Что обусловлено малым энергетическим барьером для движения дислокаций и сдвига кристаллографических плоскостей?
#  Пластичность
#
# Что, по мнению Олега Михалова, сближает творчество Чехова и Бунина?
#   направление общих поисков
#
# Кто заключил с Австрией мир в Фюссене, 22 апр. 1745 г.?
#  Максимилиан Иосиф
#
# Кто разработал теорию технологического разрыва?
#  Майкл Познер
#
# В качестве чего в настоящее время используется сорт гибрида розы рубигиноза?
#  в качестве подвоя для садовых роз
#
# Что включает в себя первый год трехлетнего цикла обновления стандарта?
#  внедрение стандарта в индустрии
#
# Что в прошлом происходило на Марсе, как и на Земле?
#  Движение литосферных плит
#
#  Альфой и омегой чего считали первичную материю металлов ?
#  всего сущего
#
# Что включает в себя программа создания федерального туристического кластера Рязанский
#  масштабную реконструкцию территории Рязанского кремля
#
# Кто выполнял функции банков до их появления во всех азиатских сделках примерно до 1770 г.?
#  менялы и хавалдары
#
# Кем впервые была обоснована животная природа губок?
#  Джоном Эллисом
#
# На что обречены страны, где общественные институты носят закрытый характер?
#  на отставание и упадок
#
# Из-за чего значительное количество удерживаемой влаги конденсируется на больших высотах и выпадает в виде дождя?
#  из-за его адиабатического охлаждения
#
# Кто являеться предком пчёл?
#  Хищные осы
#
# Что позволяет разместить ведущий мост троллейбуса ниже или выше оси колёс?
#  Колёсные редукторы
#
# На чем была основана идея Поппера об открытом обществе?
#  на демократии и критическом мышлении индивидов.
#
# На чём в основном основана экономика Копенгагена?
#  На сфере услуг и торговле
#
# Чего не имеют голоцентрические хромосомы?
#  Первичной перетяжки.
#
# От чего питаются все системы троллейбуса?
#  От контактной сети
#
# Во главе с кем русская армия захватывала город?
#  с воеводой Юрием Захарьичем Кошкиным
#
# Чем формируется углубление для имплантации чипового модуля?
#  пресс-формой
#
# Акт покупки чего предваряет строительство объектов?
#  земельного участка
#
# Кто покровительствовал в Индии персидскому языку?
#  Мусульманские султаны
#
# Кто является автором Армянской грамматики ?
#  Габриэл Аветикян.
#
# Кто уверял, что сцена с порошком была для него самой неприятной?
#  Дэвид
#
# Кому передаются многие диспозитивные функции от управленца (менеджера)?
#  к среднему уровню менеджмента
#
# Что входит в состав белка с четвертичной структурой?
#  Белковые молекулы.
#
# Кто высказался о количестве менеджмента оказывающих влияние на организацию?
#  По мнению Питера Друкера.
#
# Чего сверхкороткие импульсы используются в лазерной химии для запуска и анализа химических реакций?
#  лазерного излучения
#
# Представителями кого были Хосе Леандро Андраде и Хосе Педро Сеа?
#   Насьоналя
#
# О чем ведётся спор между литературоведами много десятков лет?
#  О точных границах между прозой и поэзией
#
# На произведениях кого основан фильм 1961 года Властелин мира (англ.)русск. ?
#  Жюля Верна
#
# Из чего состоит железнодорожный путь?
#  из двух параллельных рельсов
#
# Кто является преемником Канта в Германии?
#  Фихте, Шеллинг и Гегель
#
# Кто стал новым министром финансов после отставки Симхи Эрлиха?
#  Игаль Горовиц
#
# Чем регулируется процесс линьки?
#  гормональной системой
#
# Чем могут обмениваться некоторые животные?
#  умениями
#
# Кто стал наставником Скуадры Адзурры ?
#  Джованни Трапаттони
#
# Чего не имеют холостые патроны
#  Холостые патроны не имеют поражающего элемента
#
# Кто проиграл сражение под Вероной в 403 году?
#  Аларих
#
# От чего зависит мощность облучения?
#  от региона
#
# За что получила выговор Сюзанн Ленглен от организаторов?
#  за оскорбление величества
#
# Что хотели устроить большевистские лидеры до 1921 года?
#   мировую революцию
#
# На что влияют электрофизические свойства кремния?
#  на свойства созданного электронного прибора
#
# Кому было запрещено оставлять свою провинцию вместе с подчинёнными им войсками?
#  наместникам провинций
#
# Кем был изобретен первый почти пригодный двухкатный газовый ДВС?
#  французским механиком Этьеном Ленуаром
#
# Из чего изготовляют аноды химических источников тока?
#  лития
#
# Что дают высокие результаты показанные на турнирах Арнольд Классик или Ночь Чемпионов ?
#  возможность участвовать в конкурсе Мистер Олимпия
#
# Что образуют вместе город Байконур и космодром Байконур?
#  комплекс Байконур
#
# Что подразумевают под культурой из Швейцарии ?
#  все имеющиеся жанры, в которых работают люди со швейцарским паспортом
#
# Чем занимается технология Samsung Knox?
#  поиск уязвимостей
#
# С течением чего эти клетки предположительно утратили гены, которые были лишними при паразитическом образе жизни?.
#  Времени.
#
# Что влияет на клиентский кредитный портфель?
#  принятая банком система управления
#
# Что соединилось, образовав материк Ангарида?
#  Сибирская платформа и ряд горных систем
#
# Что создает линия раздела
#  монофилетическое выделение над парафилетическим
#
# Что помогло человеку подняться над животным миром?
#  способность анализировать и делать выводы
#
# Что является основными задачами Управления контроля?
#  осуществление контроля и надзора соблюдения антимонопольного законодательства
#
# В результате деятельности кого произошло накопление в атмосфере кислорода согласно гипотезе?
#  фотосинтезирующих организмов
#
# Кого называли величайшими реалистами?
#  Толстого и Тургенева
#
# Кто открыл стиль джаз?
#  Жоао Жилберто и Антонио Карлосом Жобином
#
# Что стало причиной развития кино в его современном виде?
#  съёмкой и публичной демонстрацией первых короткометражных фильмов
#
# Что не было разработано в феодальном и римском правах на собственность?
#  четкого различия между правом собственности и другими правами на вещи
#
# Что характерно для эволюции бактерий?
#  характерен ярко выраженный физиолого-биохимический уклон
#
# Чем не является язык?
#  универсальным дифференцирующим признаком нации
#
# Что сумел выхлопотать Шостаковичу Глазунов
#  дополнительный паёк и персональную стипендию..
#
# Что включает в себя техника борьбы в стойке?
#  только броски
#
# Что ожидается в итоге формирования межгосударственных экономических блоков?
#  ффект перелива, заключающийся в росте дохода от международной торговли
#
# Что является основными техническими показателями ЛПМ?
#  Детонации и долговременная стабильность скорости движения ленты
#
# С чем граничит Иркутск на северо-западе?
#  С Ангарским муниципальным районом
#
# Из-за чего у многих видов бабочек на стадии куколки появляются изменения в окраске и рисунке крыльев, а иногда даже и в форме крыльев?
#  Под влиянием температурного воздействия

# %%
len(a1), len(a9)
# Out:
# (82, 211)

# %%
for i in a10:
    print(i.question, '\n', i.answer, '\n')
# Out:
# Находит ли отражение в алфавите фонетическая связь слогов?
#  не находит
#
# Совместимы ли операционные системы POSIX?
#  Считаются POSIX-совместимыми по существу
#
# Многие ли вещества входящие в растворители токсичны?
#  Многие синтетические проявляющие вещества.
#
# Зависит ли форма генома от типа нуклеиновой кислоты?
#  не зависит
#
# Был ли в атмосфере свободный кислород до появления первых фотосинтезирующих архей?
#  В атмосфере его практически не было.
#
# Многие ли верят в одновременное существование материального тела и нематериального сознания?
#  Большинство людей на Земле
#
# Было ли отсутствие войн показателем цивилизованности?
#  Это не был показатель цивилизованности.
#
# Можно ли принять бабочек одного вида за представителей разного вида?
#  Можно.
#
# Способен ли холерный вибрион заразить человека при контакте через кожу?
#  не способен
#
# Велик ли был бассейн?
#  (37 на 4 м) с глубиной от 1 м на западе до 3 на востоке
#
# Велик ли артериальный конус у костистых рыб?
#  Очень мал.
#
# Оставил ли сочинения после себя Сократ ?
#  Никаких сочинений после себя не оставил.
#
# Разнообразны ли млекопитающие?
#  По размерам и внешнему облику млекопитающие очень разнообразны.
#
# Был ли Сан - Марино окупирован немцами?
#  был ненадолго оккупирован
#
# Присуща ли распределительная функция только социалистической экономике?
#  общая для государственных финансов любых формаций
#
# Одинаково ли ориентированы макромолекулы в микрофибрилле?
#  одинаково
#
# Может ли быть количество участников ООО очень большим?
#  не может быть слишком велико
#
# Разная ли величина приемлемого риска для различных обществ?
#  различная
#
# Всегда ли ракообразные однополые?
#  известны случаи гермафродитизма
#
# Были ли колодцы в Помпеях?
#  хоть и существовали, но были немногочисленными
#
# Возможно ли искусственно повысить коэффициент монетизации?
#  Невозможно
#
# Может ли существовать социальное пространство в сети Интернет?
#  может
#
# Гигроскопичен ли германат висмута?
#  абсолютно негигроскопичен
#
# Есть ли трансляции на башкирском языке?
#  осуществляется телевизионное и радиовещание
#
# Образуются ли гаметы у бактерий при половом процессе?
#  не образуются
#
# Долго ли живут лишайники?
#  лишайники долго живут
#
# Имеет ли банк лицензии на осуществление банковских операций со средствами в рублях и иностранной валюте?
#  имеет лицензии
#
# Посещал ли Вольфганг школу в Зальцбурге?
#  Доподлинно неизвестно.
#
# Может ли метро находится над землей?
#  Линии метрополитена могут прокладываться под землёй в тоннелях, по поверхности и на эстакадах
#
# Часто ли люди с суицидальными наклонностями получают помощь в Интернете?
#  редко
#
# Меняется ли порядок струн для гитаристов-левшей?
#  меняться на обратный
#
# всегда ли аллель влияет на приспособление тела?
#  влияние определённых аллелей на приспособленность организма не является постоянным
#
# Нашли ли виновных в краже рисунка Дали?
#  По этому делу предъявили обвинения четырём сотрудникам
#
# Находится ли спирт в безалкогольном пиве?
#  содержит 0,2—1,0 % спирта
#
# Имеют ли прокариотические клетки внутренние мембраны?
#  Не имеют
#
# Отталкиваются ли противоположные полюса магнитов?
#  противоположные притягиваются
#
# Считают ли демонстративное дирижирование наизусть дурным тоном?
#  считали и считают
#
# Можно ли считать правильным, то с чем ассоциируется в настоящее время фаянс ?
#  нельзя считать правильным
#
# Выше ли яркостная температура чем равносильная Юпитера?
#  яркостная температура несколько выше равновесной
#
# Много ли людей использует иранский язык?
#  меньшинство
#
# Может ли правообладатель отозвать решения?
#  Выданные пользователям разрешения правообладатель отозвать не может.
#
# Влечет ли что нибудь за собой, если договор подпишет только один прокурист?
#  Не влечет возникновения каких-либо обязанностей у компании
#
# Регламентируются ли потребительские качества?
#  не регламентируются
#
# Написал ли Стивен Кинг связанную с сериалом Lost книгу Зловещий близнец ?
#  не подтвердились
#
# Способны ли межвидовые гибриды к размножению?
#  не способны
#
# Могут ли банки в рыночной экономике напрямую достигать цели денежно-кредитной политики
#  не могут
#
# Развивались ли газеты в 20 веке
#  В XX веке газеты продолжали успешно развиваться
#
# Был ли на самом деле присвоен Хлодвигу титул консула?
#  не был

# %%
write_tree(*parser(['Кем писаны многие произведения средневековых поэтов?']))
# Out:
# # sent_id = ?
# # text = Кем писаны многие произведения средневековых поэтов ?
# ─┮
#  │ ╭─╼ 1 Кем кто PRON obl <?#2, писаны> Case=Ins
#  ╰─┾ 2 писаны писать VERB root <?, <ROOT>> Aspect=Perf|Number=Plur|Tense=Past|Variant=Short|VerbForm=Part|Voice=Pass
#    │ ╭─╼ 3 многие многие NUM amod <?#4, произведения> _
#    ┡─┾ 4 произведения произведение NOUN nsubj:pass <?#2, писаны> Animacy=Inan|Case=Nom|Gender=Neut|Number=Plur
#    │ │ ╭─╼ 5 средневековых средневековый ADJ amod <?#6, поэтов> Case=Gen|Degree=Pos|Number=Plur
#    │ ╰─┶ 6 поэтов поэт NOUN nmod <?#4, произведения> Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur
#    ╰─╼ 7 ? ? PUNCT punct <?#2, писаны> _

# %%
write_tree(*parser(['писаны под их диктовку женщинами.']))
# Out:
# # sent_id = ?
# # text = писаны под их диктовку женщинами .
# ─┮
#  ╰─┮ 1 писаны писать VERB root <?, <ROOT>> Aspect=Perf|Number=Plur|Tense=Past|Variant=Short|VerbForm=Part|Voice=Pass
#    │ ╭─╼ 2 под под ADP case <?#4, диктовку> _
#    │ ┢─╼ 3 их их DET det <?#4, диктовку> _
#    ┡─┶ 4 диктовку диктовка NOUN obl <?#1, писаны> Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing
#    ┡─╼ 5 женщинами женщина NOUN obl <?#1, писаны> Animacy=Anim|Case=Ins|Gender=Fem|Number=Plur
#    ╰─╼ 6 . . PUNCT punct <?#1, писаны> _

# %% [markdown]
# ## Тесты

# %%
import importlib
import src.generate
import tests.tester
importlib.reload(src.generate)
importlib.reload(tests.tester)

from src.generate import LongAnswerGenerator
from tests.tester import Tester

gen = LongAnswerGenerator(parser=parser)
tester = Tester(gen)

# %%
tester.test_case('case2')
# Out:
# CASE: case2
# DESC: Кто, что, and their other forms
# TEST: Чем заболел Байрон в Миссолонги? лихорадкой
# ok
# TEST: Кто считал что русская публицистическая литература восходит к „Слову о Законе и Благодати“ Илариона?  Игорь Дедков.
# ok
# TEST: Кто увидел вражеский аэроплан во время розведки? лётчики
# Parse(word='увидели', tag=OpencorporaTag('VERB,perf,tran plur,past,indc'), normal_form='увидеть', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'увидели', 861, 4),))
# ok
# TEST: На что укладывается верхнее строение пути? земляное полотно
# ok
# TEST: Что сообщал Моцарт о Констанции в письме 15 декабря 1781 года ее отцу? Что собирается жениться на ней.
# ok
# TEST: С чем связывается образ крысы?  с порчей, разрушением, смертью
# ok
# TEST: Кому передали Озерки родители Бунина?  сыну Евгению
# ok
# TEST: К чему привели ошибочные данные разветки Британии? британская авиация нанесла бомбовые удары
# ok
# TEST: Что описывает Манну в романе Манн описывает историю упадка и вырождения купеческой династии из Любека
# ok
# TEST: Кем писаны многие произведения средневековых поэтов? Писаны под их диктовку женщинами.
# ok
# TEST: К чему в последующие этапы своего развития неоднократно возвращалась философия? к релятивизму
# ok
# TEST: Кто развил философию в направлении абсолютного идеализма? Фихте, Шеллинг и Гегель
# Parse(word='развили', tag=OpencorporaTag('VERB,perf,tran plur,past,indc'), normal_form='развить', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'развили', 631, 4),))
# ok
# TEST: В виде чего могут использоваться такие графики?  Как самостоятельные модели технического анализа.
# ok
# TEST: В отличии от чего в болгарском и македонском языках, при наличии определяемых слов перед существительным, определённый артикль ставится только в конце первого слова? падежных форм русского языка
# ok
# TEST: Чем характеризуется бегство вкладчиков ? наплыв в банк требований о возвращении вкладов
# ok
# TEST: Что означает выражение: страна может осуществлять производство определенного товара с меньшими издержками? используя меньшее количество ресурсов
# GENERATED Используя меньшее количество ресурсов означает выражение: страна может осуществлять производство определенного товара с меньшими издержками. != TRUE Выражение: страна может осуществлять производство определенного товара с меньшими издержками означает используя меньшее количество ресурсов.
# TEST: Что вызвало всплеск общественного интереса к этому направлению?  Публикация ряда результатов в открытой печати
# ok
# TEST: Кого несомненно возбудит занятие Порт-Артура или Да-лянь-вана?   Китай
# ok
# TEST: Что требуют граждане в стандартной ситуации  эффективного и ответственного управления
# ok
# TEST: Из за чего Сирокко несёт пыль из Северной Африки в Южную Европу через Средиземное море?  в результате движения внетропических циклонов
# ok
# TEST: Что рассматривают в технологиях управления риском?  обобщенные понятия случайного события
# ok
# TEST: Что было открыто во дворце после восстановления? Национальная галерея
# ok
# TEST: Что для идентификации сайтов в адресе после указания хоста стоит? тильда и имя сайта
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_14298/3501604926.py in <module>
# ----> 1 tester.test_case('case2')
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/tests/tester.py in test_case(self, case_name)
#      17
#      18         for question, answer, long_answer in cases[case_name]['qal_triples']:
# ---> 19             self.test_one(question, answer, long_answer)
#      20
#      21         print()
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/tests/tester.py in test_one(self, question, answer, long_answer)
#      23     def test_one(self, question, answer, long_answer):
#      24         print(colored("TEST:", 'red'), question, answer)
# ---> 25         gen = self.long_answer_generator.generate_one(question, answer)
#      26         if gen == long_answer:
#      27             print('ok')
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/src/generate.py in generate_one(self, question, answer)
#      86         answer, answer_tree = self.preprocess_with_tree(answer, answer_tree)
#      87         question, question_tree = self.preprocess_with_tree(question, question_tree)
# ---> 88         long_answer = self.generate_long_answer(question, question_tree, answer, answer_tree)
#      89         long_answer = self.postprocess(long_answer)
#      90         return long_answer
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/src/generate.py in generate_long_answer(self, question, question_tree, answer, answer_tree)
#      68
#      69     def generate_long_answer(self, question, question_tree, answer, answer_tree):
# ---> 70         return CommonGenerator().generate(question, question_tree, answer, answer_tree)
#      71
#      72     def postprocess(self, answer):
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/src/generate.py in generate(self, question, question_tree, answer, answer_tree)
#     102     def generate(self, question, question_tree, answer, answer_tree):
#     103         for handler in case_handlers:
# --> 104             result, long_answer = handler.generate(question, question_tree, answer, answer_tree)
#     105             if result:
#     106                 return long_answer
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/src/generate.py in generate(self, question, question_tree, answer, answer_tree)
#     401         if not self.trim(question_tree, answer_tree):
#     402             qword_node = self.find_qword(question_tree)
# --> 403             self.harmonize(qword_node, question_tree, answer_tree)
#     404
#     405         qword_node = self.find_qword(question_tree)
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/src/generate.py in harmonize(self, qword_node, question_tree, answer_tree)
#     375
#     376     def harmonize(self, qword_node, question_tree, answer_tree):
# --> 377         self.harmonize_verb(qword_node, question_tree, answer_tree)
#     378         self.harmonize_noun(qword_node, question_tree, answer_tree)
#     379
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/src/generate.py in harmonize_verb(self, qword_node, question_tree, answer_tree)
#     269         if root.upos not in ['VERB', 'AUX'] or qword_node.feats['Case'] != 'Nom':
#     270             return
# --> 271         self.harmonize_verb_one(qword_node, question_tree, answer_tree, root)
#     272         auxes = get_children(root, 'aux')
#     273         for aux in auxes:
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/src/generate.py in harmonize_verb_one(self, qword_node, question_tree, answer_tree, root)
#     295                 ))
#     296                 print(parsers[0].inflect(params))
# --> 297                 new_word = parsers[0].inflect(params).word
#     298                 root.form = new_word
#     299
#
# AttributeError: 'NoneType' object has no attribute 'word'

# %%
for i in a2:
    print(i.question, i.answer)
    print(gen.generate_one(i.question, i.answer))
    print()
# Out:
# Чем заболел Байрон в Миссолонги? лихорадкой
# Байрон заболел лихорадкой в Миссолонги.
#
# Что нарушают хромосомные аберрации? Структуру хромосом.
# Хромосомные аберрации нарушают структуру хромосом.
#
# Кто считал что русская публицистическая литература восходит к „Слову о Законе и Благодати“ Илариона? Игорь Дедков.
# Игорь Дедков считал что русская публицистическая литература восходит к „Слову о Законе и Благодати“ Илариона.
#
# О чем написано в песне Чайльд-Гарольда ? Поездку на поля Ватерлоо
# Написано о поездке на поля Ватерлоо в песне Чайльд-Гарольда.
#
# Что изначально использовалось в качестве баттуты? трубка из кожи, набитая шерстью, или рулон нот.
# Трубка из кожи, набитая шерстью, или рулон нот изначально использовались в качестве баттуты.
#
# Что может произойти со стоимостью нематериальных активов при разделении компании на части? Может значительно снизиться
# Значительно снизиться может произойти со стоимостью нематериальных активов при разделении компании на части.
#
# что в режиме гибернации отключается? питание ОЗУ
# Питание ОЗУ отключается в режиме гибернации.
#
# Что содержат белки-каналы? Внутренние заполненные водой поры
# Белки-каналы содержат внутренние заполненные водой поры.
#
# Для чего используется добавка фторидов в соль? для профилактики зубных заболеваний
# Добавка фторидов в соль используется для профилактики зубных заболеваний.
#
# Кто разработал утилиту patch ( заплатка )? Ларри Уолл
# Ларри Уолл разработал утилиту patch (заплатка).
#
# Кто увидел вражеский аэроплан во время розведки? лётчики
# Лётчики увидели вражеский аэроплан во время розведки.
#
# На что укладывается верхнее строение пути? земляное полотно
# Верхнее строение пути укладывается на земляное полотно.
#
# Чем, помимо всего прочего, является Кёльн? Крупнейшим музейно-выставочным центром.
# Кёльн помимо прочего, является крупнейшим музейно-выставочным центром всего.
#
# О чем говорилось в шестой части книги? о причинах изменения широт планет
# Говорилось о причинах изменения широт планет в шестой части книги.
#
# Что обосновывается тем фактом, что Попов 25 марта 1896 г. провёл опыты с радиотелеграфией, послав на расстояние 250 м радиограмму? Приоритет Попова
# Приоритет Попова обосновывается тем фактом, что Попов 25 марта 1896 г. провёл опыты с радиотелеграфией, послав на расстояние 250 м радиограмму.
#
# Что сообщал Моцарт о Констанции в письме 15 декабря 1781 года ее отцу? Что собирается жениться на ней.
# Что собирается жениться на ней.
#
# Что признали религиозные конфессии возможность сочетания религиозных верований
# Религиозные конфессии признали возможность сочетания религиозных верований.
#
# На чем основывались первые представления о строении атомов и природе химической валентности? на закономерностях свойств элементов
# Первые представления о строении атомов и природе химической валентности основывались на закономерностях свойств элементов.
#
# Что используют в качестве генератора импульсные РЛС метрового диапазона? триодную лампу
# Импульсные РЛС метрового диапазона используют триодную лампу в качестве генератора.
#
# С чем связывается образ крысы? с порчей, разрушением, смертью
# Образ крысы связывается с порчей, разрушением, смертью.
#
# Что является главными преимуществами асинхронного ТЭД? простота конструкции и малые габариты
# Простота конструкции и малые габариты являются главными преимуществами асинхронного ТЭД.
#
# Что перенес Шостакович через несколько месяцев после смерти отца? Тяжёлую операцию
# Шостакович перенес тяжёлую операцию через несколько месяцев после смерти отца.
#
# К чему в последующие этапы своего развития неоднократно возвращалась философия? к релятивизму
# Философия неоднократно возвращалась к релятивизму в последующие этапы своего развития.
#
# Что было принципиальным недостатком 4- и 8-дорожечных картриджей? способ переключения дорожек
# Способ переключения дорожек было принципиальным недостатком 4- и 8-дорожечных картриджей.
#
# Что позволяет шея жирафу? срывать листья и молодые побеги с крон деревьев
# Срывать листья и молодые побеги с крон деревьев.
#
# Что в вызывает мёд, собранный с рододендрона, в организме человека? головную боль, рвоту, потемнение в глазах, а иногда и обморочное состояние
# Мёд, собранный с рододендрона, в вызывает головную боль, рвоту, потемнение в глазах, а иногда и обморочное состояние в организме человека.
#
# Что произошло после после пика популярности? интерес инвесторов к чистым технологиям снизился
# Интерес инвесторов к чистым технологиям снизился.
#
# Кому передали Озерки родители Бунина? сыну Евгению
# Родители Бунина передали Озерки сыну Евгению.
#
# Что вызвало всплеск общественного интереса к этому направлению? Публикация ряда результатов в открытой печати
# Публикация ряда результатов в открытой печати вызвала всплеск общественного интереса к этому направлению.
#
# К чему привели ошибочные данные разветки Британии? британская авиация нанесла бомбовые удары
# Британская авиация нанесла бомбовые удары.
#
# Кого несомненно возбудит занятие Порт-Артура или Да-лянь-вана? Китай
# Занятие Порт-Артура или Да-лянь-вана несомненно возбудит Китай.
#
# У кого ареалы часто сопряжены с распространением кормовых растений гусениц? У монофагов и узких олигофагов
# Ареалы часто сопряжены у монофагов и узких олигофагов с распространением кормовых растений гусениц.
#
# Кому предаются полномочия в отсутствии управляющего в случае, когда число заместителей более одного? Самому старшему по возрасту заместителю
# Полномочия предаются самому старшему по возрасту заместителю в отсутствии управляющего в случае, когда число заместителей более одного.
#
# Формирование чего не происходит у губок в ходе эмбриогенеза? зародышевых листков
# Формирование зародышевых листков не происходит у губок в ходе эмбриогенеза.
#
# Что стало новым? пчёлы полностью специализировались на опылении
# Пчёлы полностью специализировались на опылении.
#
# Что будет за изучение или попытки исправления ошибок программ путём дизассемблирования ? могут преследоваться уголовным правом.
# Могут преследоваться уголовным правом будет за изучение или попытки исправления ошибок программ путём дизассемблирования.
#
# Кто описал понятия рас, как исторически слагающиеся категории ? Г. И. Петров
# Г. И. Петров описал понятия рас, как исторически слагающиеся категории.
#
# Что утверждают некоторые критики относительно использования таксонов высшего по виду ранга в систематике? эти таксоны не должны использоваться в систематике вообще
# Некоторые критики относительно использования таксонов высшего по виду ранга в систематике утверждают эти таксоны не должны использоваться в систематике вообще.
#
# Что должен делать Банк Канады? способствовать экономическому благосостоянию канадских граждан
# Способствовать экономическому благосостоянию канадских граждан.
#
# Что было запатентовано и поступило в свободную продажу в 1907 году? Фотопластинки Автохром братьев Люмьер
# Фотопластинки Автохром братьев Люмьер были запатентованы и поступило в свободную продажу в 1907 году.
#
# На что расчленено тело у большинства млекопитающих? на голову, шею, туловище, две пары конечностей и хвост
# Тело расчленено на голову, шею, туловище, две пары конечностей и хвост у большинства млекопитающих.
#
# Относительно чего законодательство Российской Федерации предъявляет меньшие процедурные требования к деятельности общества с ограниченной ответственностью? чем к деятельности акционерного общества
# Законодательство Российской Федерации предъявляет меньшие процедурные требования к деятельности общества с ограниченной ответственностью чем к деятельности акционерного общества.
#
# С чем была связана первоначальная неприятность дисков DVD-RW? с несовместимостью старых приводов с этими новыми дисками
# Первоначальная неприятность дисков DVD-RW была связана с несовместимостью старых приводов с этими новыми дисками.
#
# Что отметили литературоведы глядя на произведения, созданных в эмигрантский период? напрочь ушёл присущий Бунину прежде социальный посыл
# Напрочь ушёл присущий Бунину прежде социальный посыл.
#
# Кем публикуется Красный список угрожаемых видов Международным союзом охраны природы и природных ресурсов
# Красный список угрожаемых видов публикуется международным союзом охраны природы и природных ресурсов.
#
# что завоевали хозяева турнира остались без наград.
# Хозяева турнира завоевали остались без наград.
#
# За что тренера раскритиковали ? за неудачные перестановки
# Раскритиковали тренера за неудачные перестановки.
#
# В чём выражается это влияние? в принятии физическими лицами, предприятиями и органами государственной власти экономических решений
# Это влияние выражается в принятии физическими лицами, предприятиями и органами государственной власти экономических решений.
#
# Кто построил первый каменный мост через Дунай? Римский император Траян.
# Римский император Траян построил первый каменный мост через Дунай.
#
# Чем представлена у рыб система кровообращения? только одним замкнутым контуром
# Система кровообращения представлена только одним замкнутым контуром у рыб.
#
# К чему привела тяжёлая жизнь при полуголодном существовании? К сильному истощению
# Тяжёлая жизнь при полуголодном существовании привела к сильному истощению.
#
# Кому помог завоевать Англию в 1688 году другой шторм Протестантский ветер ? Вильгельму Оранскому
# Другой шторм Протестантский ветер помог завоевать Англию в 1688 году Вильгельму Оранскому.
#
# С помощью чего можно восстановить данные при подмене одного из секторов жесткого диска резервным? При помощи ECC.
# Можно при помощи ECC восстановить данные при подмене одного из секторов жесткого диска резервным.
#
# Что вызывает изменения частот аллелей генов? мутации, поток генов, естественный отбор и дрейф генов
# Мутации, поток генов, естественный отбор и дрейф генов вызывают изменения частот аллелей генов.
#
# Кем писаны многие произведения средневековых поэтов? Писаны под их диктовку женщинами.
# Писаны под их диктовку женщинами.
#
# Что описывает Манну в романе Манн описывает историю упадка и вырождения купеческой династии из Любека
# Манн описывает историю упадка и вырождения купеческой династии из Любека.
#
# Что является один из этих негативных факторов,облегчающих распространение эпидемий? Скученность городского населения
# Один из этих негативных факторов, облегчающих распространение эпидемий является скученность городского населения.
#
# Что используется в аксиоме Архимеда вместо тройки вещественных чисел? тройка комплексных чисел
# Тройка комплексных чисел используется в аксиоме Архимеда вместо тройки вещественных чисел.
#
# Чем являются водородные соединения других элементов? газами
# Водородные соединения других элементов являются газами.
#
# Кто вывел сорт розы Champneys Pink Cluster ? Джон Чемпнис Чарльстон
# Джон Чемпнис Чарльстон вывел сорт розы Champneys Pink Cluster.
#
# Кто развил философию в направлении абсолютного идеализма? Фихте, Шеллинг и Гегель
# Фихте, Шеллинг и Гегель развили философию в направлении абсолютного идеализма.
#
# Что закрывается при сокращении камер сердца? Клапаны остий.
# Клапаны остий закрываются при сокращении камер сердца.
#
# Кто отклонил проект идеального города Леонардо да Винчи? Миланский герцог Лодовико Сфорца.
# Миланский герцог Лодовико Сфорца отклонил проект идеального города Леонардо да Винчи.
#
# Что изучает зоология? животных
# Зоология изучает животных.
#
# Чем богата мантия Нептуна? водой, аммиаком, метаном и прочими соединениями
# Мантия Нептуна богата водой, аммиаком, метаном и прочими соединениями.
#
# Кто приняли меры для предотвращения подобных эксцессов? Регуляторы
# Регуляторы приняли меры для предотвращения подобных эксцессов.
#
# Кто написал роман Чего же ты хочешь?  В. А. Кочетов
# В. А. Кочетов написал роман Чего же ты хочешь.
#
# Кем было принято решение об организации конкурса по созданию герба и флага города Северодвинска в 2014 году? депутатами
# Решение об организации конкурса по созданию герба и флага города Северодвинска в 2014 году было принято депутатами.
#
# Для чего используется отреставрированный интерьер? для культурных мероприятий
# Отреставрированный интерьер используется для культурных мероприятий.
#
# Чему должна учиться интеллигенция у деревни ? нравственности
# Интеллигенция должна учиться нравственности у деревни.
#
# Кто в основном выполняет междугородные автобусные перевозки в Шеффилде? National Express
# National Express выполняет междугородные автобусные перевозки в основном в Шеффилде.
#
# В виде чего могут использоваться такие графики? Как самостоятельные модели технического анализа.
# Такие графики могут использоваться как самостоятельные модели технического анализа.
#
# В отличии от чего в болгарском и македонском языках, при наличии определяемых слов перед существительным, определённый артикль ставится только в конце первого слова? падежных форм русского языка
# В отличии от падежных форм русского языка в болгарском и македонском языках, при наличии определяемых слов перед существительным, определённый артикль ставится только в конце первого слова.
#
# Что показал отчёт за 2008 год? климат в Шеффилде теплеет быстрее, чем в любой другой год
# Климат в Шеффилде теплеет быстрее, чем в любой другой год.
#
# Что может служить примером постмодернистского видения мира? концепция диалога Левинаса
# Концепция диалога Левинаса может служить примером постмодернистского видения мира.
#
# Что подразумевается под словосочетанием полуторная конструкция? расстояние между осями рулонов меньше, чем их максимальный диаметр
# Расстояние между осями рулонов меньше, чем их максимальный диаметр подразумевается под словосочетанием полуторная конструкция.
#
# Что было записано на обороте первой авторской рукописи Сергея Прокофьева? положение незаконченной шахматной партии
# Положение незаконченной шахматной партии было записано на обороте первой авторской рукописи Сергея Прокофьева.
#
# О ком Альфред Шнитке высказывался как об одном из величайших композиторов в русской музыкальной истории? О Прокофьеве.
# Альфред Шнитке высказывался о Прокофьеве как об одном из величайших композиторов в русской музыкальной истории.
#
# К чему приходит Уатт в результате своих исследований? к пониманию важности скрытой теплоты
# Уатт приходит к пониманию важности скрытой теплоты в результате своих исследований.
#
# На чём построено различие гласных звуков по долготе? на упорядочении слогов по признаку долготы/краткости
# Различие гласных звуков по долготе построено на упорядочении слогов по признаку долготы/краткости.
#
# что характеризует функция изменение параметров сигнала
# Функция характеризует изменение параметров сигнала.
#
# Кому уступили место дагеротипия и калотипия? мокрому коллодионному процессу
# Дагеротипия и калотипия уступили место мокрому коллодионному процессу.
#
# Что было создано в Москве в 1922 году? Персимфанс.
# Персимфанс был создан в Москве в 1922 году.
#
# Из чего состоит операционная система, которую разрабатывает Фонд свободного программного обеспечения ? из открыто разрабатываемого программного обеспечения
# Операционная система, которую разрабатывает Фонд свободного программного обеспечения состоит из открыто разрабатываемого программного обеспечения.
#
# Обобщением чего являются постулаты термодинамики? опытных фактов
# Постулаты термодинамики являются обобщением опытных фактов.
#
# С кем в паре поюедила Морозова на Уимблдоне? паре с Эверт
# Морозова поюедила с парой с Эверт в паре на Уимблдоне.
#
# Кем был получен первый патент на фотоаппарат, пригодный для моментальной фотографии? Самуэлем Шлафроком
# Первый патент на фотоаппарат, пригодный для моментальной фотографии был получен Самуэлем Шлафроком.
#
# Что требуется поездам из-за большой массы? очень длинный тормозной путь
# Очень длинный тормозной путь требуется поездам из-за большой массы.
#
# Что наблюдается в современном обществе Явный переход среди пользователей компьютерной техники
# Явный переход среди пользователей компьютерной техники наблюдается в современном обществе.
#
# С кем объединился Banco Central в 1991 году? с Banco Hispano Americano
# Banco Central объединился с Banco Hispano Americano в 1991 году.
#
# Что является фундаментом этических норм? законы функционирования рыночных структур
# Законы функционирования рыночных структур являются фундаментом этических норм.
#
# На что направлена ценовая политика? На достижение долго- и краткосрочных целей предприятия.
# Ценовая политика направлена на достижение долго- и краткосрочных целей предприятия.
#
# Что не учитывается при расчете убыточности страховой компании? Расходы на ведение дела
# Расходы на ведение дела не учитываются при расчете убыточности страховой компании.
#
# Чем он украшен? дорическими колоннами и настенной живописью
# Он украшен дорическими колоннами и настенной живописью.
#
# Что прозрачно для радиоволн УКВ диапазона? ионосфера
# Ионосфера прозрачно для радиоволн УКВ диапазона.
#
# Что позволяет уточнить или расширить список искомых ключевых слов? использование в запросах булевых операторов
# Использование в запросах булевых операторов позволяет уточнить или расширить список искомых ключевых слов.
#
# Кто метит капельками мочи, экскрементами или выделениями пахучих желёз занимаемые ими участки обитания? Многие млекопитающие
# Многие млекопитающие метят занимаемые ими участки обитания капельками мочи, экскрементами или выделениями пахучих желёз.
#
# Чем занимался петербургский Северный союз учащихся средних школ ? просветительством
# Петербургский Северный союз учащихся средних школ занимался просветительством.
#
# Под руководством кого симфония стала наиболее продолжительной? Вильгельма Фуртвенглера
# Симфония стала под руководством Вильгельма Фуртвенглера наиболее продолжительной.
#
# Кем управлялись средства до создания Администрации церковного имущества Святого Престола? Специальной Администрацией Святого Престола
# Средства управлялись специальной Администрацией Святого Престола до создания Администрации церковного имущества Святого Престола.
#
# Чем компенсировалось наличие безоружных устаревших самолетов у России? примитивным вооружением германских самолётов
# Наличие безоружных устаревших самолетов у России компенсировалось примитивным вооружением германских самолётов.
#
# За кого можно принять различающихся по окраске особей бабочки медведицы-кайя (Arctia caja)? за представителей различных видов
# За представителей различных видов можно принять различающихся по окраске особей бабочки медведицы-кайя (Arctia caja).
#
# Над кем в полуфинале немцы взяли верх со счетом 2:1? Над сборной СССР
# Немцы взяли верх над сборной СССР в полуфинале со счетом 2:1.
#
# В чем состоит отличие между теневыми банками и обычными банками? парабанки не принимают индивидуальные вклады от населения
# Парабанки не принимают индивидуальные вклады от населения.
#
# Кто занимает третье место по числу сбитых реактивных самолетов? полковник ВВС Израиля Гиора Эпштейн
# Полковник ВВС Израиля Гиора Эпштейн занимает третье место по числу сбитых реактивных самолетов.
#
# Что отсутствует в какой-либо определённой среде ? Выраженные приспособления к жизни
# Выраженные приспособления к жизни отсутствуют в какой-либо определённой среде.
#
# Что является основным фильтром крови? Селезёнка (красная пульпа)
# Селезёнка (красная пульпа) является основным фильтром крови.
#
# Что получил Шеффилд в 1893 году? статус сити
# Шеффилд получил статус сити в 1893 году.
#
# От чего зависит эффективность пастеризации молочного сырья? от температуры и времени проведения процесса
# Эффективность пастеризации молочного сырья зависит от температуры и времени проведения процесса.
#
# За что выступают шотландо-ирландцы? Они преданы идее сохранения конституционных связей с британской короной
# Они преданы идее сохранения конституционных связей с британской короной.
#
# За счет чего внешнее финансирование оказывается дороже внутреннего? За счет привлечения кредитов или выпуска облигация
# Внешнее финансирование оказывается за счет привлечения кредитов или выпуска облигация дороже внутреннего.
#
# Кто усматривает первооснову устойчивости и единства общества в признаках наличия коллективного сознания, общей воли, препятствующей губительной силе человеческого эгоизма? Эмиль Дюркгейм.
# Эмиль Дюркгейм усматривает первооснову устойчивости и единства общества в признаках наличия коллективного сознания, общей воли, препятствующей губительной силе человеческого эгоизма.
#
# Кому подражает парусник Papilio agestor? несъедобной данаиде сита
# Парусник Papilio agestor подражает несъедобной данаиде ситу.
#
# Что относится к непроизводственным основным средствам? жилые здания, детские сады, клубы, стадионы, больницы
# Жилые здания, детские сады, клубы, стадионы, больницы относятся к непроизводственным основным средствам.
#
# Что требуют граждане в стандартной ситуации эффективного и ответственного управления
# Граждане требуют эффективного и ответственного управления в стандартной ситуации.
#
# Что постепенно уточнялось среди зоофитов ? Систематическое положение
# Систематическое положение постепенно уточнялось среди зоофитов.
#
# Что подвергали анализу? отношения согласования, управления и примыкания
# Подвергали отношения согласования, управления и примыкания анализу.
#
# Кто добывал и использовал платину с незапамятных времён? Цивилизации Анд (инки и чибча).
# Цивилизации Анд (инки и чибча) добывали и использовал платину с незапамятных времён.
#
# От чего должны быть защищены провода троллейбуса? От сближения
# Провода троллейбуса должны быть защищены от сближения.
#
# К чему приурочены съёмки? к 40-летнему юбилею оригинального сериала
# Съёмки приурочены к 40-летнему юбилею оригинального сериала.
#
# Что доминирует в промышленности Швейцарии? Крупные объединения транснационального характера.
# Крупные объединения транснационального характера доминируют в промышленности Швейцарии.
#
# Кто занимается распространением произведений? издательство
# Издательство занимается распространением произведений.
#
# Из чего состоит вода? из двух атомов водорода и одного — кислорода
# Вода состоит из двух атомов водорода и одного — кислорода.
#
# Над чем работал Лейбниц как инженер? над вычислительными машинами, часами
# Лейбниц как инженер работал над вычислительными машинами, часами.
#
# Чем отличается метромост от обычного моста? повышенной прочностью
# Метромост отличается повышенной прочностью от обычного моста.
#
# Кто так отзывался о И.А.Бунине: Иван Алексеевич оказался в стороне от общего движения в области русского стиха . Максимилиан Волошин
# Максимилиан Волошин так отзывался о И.А.Бунине: Иван Алексеевич оказался в стороне от общего движения в области русского стиха.
#
# Что представляют собой теплоэлектростанции, кинопромышленность (киноиндустрия)? предприятия по ремонту промышленных изделий
# Теплоэлектростанции, кинопромышленность (киноиндустрия) представляют предприятия по ремонту промышленных изделий собой.
#
# В процессе чего углерод в виде СО2 поглощается из тропосферы растениями? В процессе фотосинтеза.
# Углерод в виде СО2 поглощается в процессе в процесса фотосинтеза из тропосферы растениями.
#
# Чем подстилается внутренняя поверхность ядерной оболочки? ядерной ламиной
# Внутренняя поверхность ядерной оболочки подстилается ядерной ламиной.
#
# Кем управлялся Мемель до этого? назначенной Советом послов Директорией
# Мемель управлялся назначенной Советом послов Директорией до этого.
#
# На чем сформировано мелкотоварное производство? на частной собственности на производственные ресурсы и личном труде их владельца
# Мелкотоварное производство сформировано на частной собственности на производственные ресурсы и личном труде их владельца.
#
# Что Покупатель передаст Продавцу в случае дефолта? Обязательства Базового заемщика
# Покупатель передаст обязательства Базового заемщика Продавцу в случае дефолта.
#
# Кто занимается пресечением антиконкурентного поведения отдельных хозяйствующих субъектов на товарных и финансовых рынках ФАС России
# ФАС России занимается пресечением антиконкурентного поведения отдельных хозяйствующих субъектов на товарных и финансовых рынках.
#
# Что предоставил эдикт Константина Великого в сам год его смерти? право свободного перехода в христианство всякому желающему
# Эдикт Константина Великого предоставил право свободного перехода в христианство всякому желающему в сам год его смерти.
#
# Для чего нужна третья космическая скорость? чтобы покинуть звёздную систему
# Третья космическая скорость нужна чтобы покинуть звёздную систему.
#
# Чему равна цена одного деления в шкале Цельсия? цене деления шкалы Кельвина
# Цена одного деления в шкале Цельсия равна цене деления шкалы Кельвина.
#
# Кто рекомендует разработчикам и авторам документации не читать патентов во избежание преследования за сознательное нарушение патента или перестраховки из‐за неправильного прочтения? Software Freedom Law Center
# Software Freedom Law Center рекомендует не читать патентов во избежание преследования за сознательное нарушение патента или перестраховки из‐за неправильного прочтения разработчикам и авторам документации.
#
# Что при повышении давления частично превращается в жидкость? насыщенный пар
# Насыщенный пар частично превращается при повышении давления в жидкость.
#
# После чего город стал перестраиваться? После того, как город получил статус административного центра губернии
# Город стал перестраиваться после того, как город получил статус административного центра губернии.
#
# Что запретил Национальный банк Австрии, усмотрев угрозу своей монополии, когда более 300 общин в Австрии заинтересовались свободными местными деньгами? печатание свободных местных денег
# Национальный банк Австрии запретил печатание свободных местных денег, усмотрев угрозу своей монополии, когда более 300 общин в Австрии заинтересовались свободными местными деньгами.
#
# Что особого было в этих городах уникальные для Руси примеры государственного устройства
# Уникальные для Руси примеры государственного устройства было в этих городах.
#
# С кем совместно Шаляпин разработал план будущего дома? с архитектором Кузнецовым
# Шаляпин совместно разработал план будущего дома с архитектором Кузнецовым.
#
# что помимо вещного права также присутствует? доля неимущественного права
# Также доля неимущественного права присутствует помимо вещного права.
#
# Что дают компаниям различные методологии для внедрения управления эффективностью деятельности? структуру
# Различные методологии для внедрения управления эффективностью деятельности дают структуру компаниям.
#
# Что критикует Мьевиль во Властелине колец ? Идеи утешения и побега .
# Мьевиль критикует идеи утешения и побега во Властелине колец.
#
# Чем в понимании Чернышевского являлась община? патриархальный институт русской жизни
# Община являлась патриархальным институтом русской жизни в понимании Чернышевского.
#
# Что может делать имплантат? измерять кровяное давление
# Имплантат может делать измерять кровяное давление.
#
# Кому принадлежали согласно буллы все земли к западу и к югу от линии, соединяющей полюса Земли и проходящей в ста лигах западнее и южнее любого из островов Азорских островов или островов Кабо-Верде ? принадлежали Испании
# Все земли к западу и к югу от линии, соединяющей полюса Земли и проходящей в ста лигах западнее и южнее любого из островов Азорских островов или островов Кабо-Верде принадлежали Испании согласно буллы.
#
# Кто обучал Шостаковича гармонии и оркестровке в Петроградской консерватории? М. О. Штейнберг
# М. О. Штейнберг обучала Шостаковича гармонии и оркестровке в Петроградской консерватории.
#
# Из за чего Сирокко несёт пыль из Северной Африки в Южную Европу через Средиземное море? в результате движения внетропических циклонов
# Сирокко несёт пыль в результате движения внетропических циклонов из Северной Африки в Южную Европу через Средиземное море.
#
# Что притягивается и отталкивается в соответствии с законом обратных квадратов? магнитные полюса
# Магнитные полюса притягиваются и отталкивается в соответствии с законом обратных квадратов.
#
# Кем было осуществлено строительство здания Пентагона? Строительной компанией Джона МакШейна из Филадельфии
# Строительство здания Пентагона было осуществлено строительной компанией Джона МакШейна из Филадельфии.
#
# Обо что происходит трение космического аппарата ? об остатки атмосферы планеты
# Трение космического аппарата происходит об остатки атмосферы планеты.
#
# Чем славилась монахиня Гросвита? Славилась своей учёностью
# Монахиня Гросвита славилась своей учёностью.
#
# К чему обратился Кант в Критике чистого разума ? к проблеме рационализма и эмпиризма
# Кант обратился к проблеме рационализма и эмпиризма в Критике чистого разума.
#
# От кого происходит класс Eumetazoa? от одноклеточных предков
# Класс Eumetazoa происходит от одноклеточных предков.
#
# С чем совпадает второе имя Байрона? с девичьей фамилией матери
# Второе имя Байрона совпадает с девичьей фамилией матери.
#
# Чем сопровождался набег тюрингов? страшными жестокостями
# Набег тюрингов сопровождался страшными жестокостями.
#
# Кем финансируется шведский языковой совет? шведским правительством
# Шведский языковой совет финансируется шведским правительством.
#
# Для чего была предназначена незаконченная гипертекстовая система Нельсона - Xanadu? Для хранения и поиска текста, в который введены взаимосвязи и окна .
# Незаконченная гипертекстовая система Нельсона - Xanadu была предназначена для хранения и поиска текста, в который введены взаимосвязи и окна.
#
# С чем могут связываться молекулы конечного продукта метаболического пути? С продуцировавшим их ферментом
# Молекулы конечного продукта метаболического пути могут связываться с продуцировавшим их ферментом.
#
# Кто в 1395 году принял титул герцога Миланского? Джангалеаццо Висконти
# Джангалеаццо Висконти принял титул герцога Миланского в 1395 году.
#
# Кто был основателем эмпириокритицизма? Рихард Авенариус
# Рихард Авенариус был основателем эмпириокритицизма.
#
# Кем должно быть подписано распоряжение, на основании которого работник бухгалтерии совершает проводки, связанные с кредитной задолженностью? уполномоченным должностным лицом банка
# Распоряжение, на основании которого работник бухгалтерии совершает проводки, связанные с кредитной задолженностью должно быть подписано уполномоченным должностным лицом банка.
#
# Что дает основу для получения соответствующих оценок? закон больших чисел в форме Чебышёва
# Закон больших чисел в форме Чебышёва дает основу для получения соответствующих оценок.
#
# Что характеризует разрешение в оптическом микроскопе? Чёткость изображения
# Чёткость изображения характеризует разрешение в оптическом микроскопе.
#
# Что является важным элементом при создании портрета? взгляд
# Взгляд является важным элементом при создании портрета.
#
# Что обеспечивает порядок и рамки, в которых протекает деятельность? Социальный контроль
# Социальный контроль обеспечивает порядок и рамки, в которых протекает деятельность.
#
# С чем столкнулась Африка, окончательно закрыв древний океан Тетис? Африка столкнулась с Евразией
# Африка столкнулась Африка с Евразией, окончательно закрыв древний океан Тетис.
#
# Чего не обнаруживают верхнепалеолитические черепа из Китая, Юго-Восточной Азии и Индонезии? монголоидности
# Верхнепалеолитические черепа из Китая, Юго-Восточной Азии и Индонезии не обнаруживают монголоидности.
#
# Для чего необходимо синусоидальное напряжение ультразвуковой частоты? Для подмагничивания при записи и для стирания записи
# Синусоидальное напряжение ультразвуковой частоты необходимо для подмагничивания при записи и для стирания записи.
#
# Кто первым занялся изучением компьютерных игр? сотрудники Копенгагенского университета информационных технологий
# Сотрудники Копенгагенского университета информационных технологий занялись первым изучением компьютерных игр.
#
# Эксперименты по слиянию чего послужили толчком к началу расшифровки регуляторов митотического деления? клеток, находящихся на разных этапах клеточного цикла
# Эксперименты по слиянию клеток, находящихся на разных этапах клеточного цикла послужили толчком к началу расшифровки регуляторов митотического деления.
#
# За что отвечает Министерство охраны окружающей среды Манитобы? экологическое состояние провинции
# Министерство охраны окружающей среды Манитобы отвечает за экологическое состояние провинции.
#
# Кто в 1865 году открыл законы наследственности Грегор Мендель
# Грегор Мендель открыл законы наследственности в 1865 году.
#
# Чем по мнению некоторых авторов может быть автофагия при определённых условиях? отдельным типом клеточной смерти.
# Автофагия может отдельным типом клеточной смерти по мнению некоторых авторов при определённых условиях.
#
# Кого из писателей указывает в своей монографии критик Ирина Васюченко в качестве предшественника и наследника Александра Грина? Владимира Набокова
# Критик Ирина Васюченко указывает Владимира Набокова в своей монографии в качестве предшественника и наследника Александра Грина.
#
# Кто из игроков после игры подтвердили, что им делали уколы? Отто Вальтер, Ханс Шефер и Хорст Эккель
# Отто Вальтер, Ханс Шефер и Хорст Эккель подтвердили после игры, что им делали уколы.
#
# Что значит гомономно сегментированные грудные и брюшные отделы у некоторых примитивных видов ракообразных? состоят из практически одинаковых сегментов
# Состоят из практически одинаковых сегментов.
#
# Кто полагал, что движущими силами эволюции являются: определённая изменчивость, неопределённая изменчивость, борьба за существование и естественный отбор Дарвин
# Дарвин полагал, что движущими силами эволюции являются: определённая изменчивость, неопределённая изменчивость, борьба за существование и естественный отбор.
#
# Кто выписывает сквозной коносамент? Грузоотправитель
# Грузоотправитель выписывает сквозной коносамент.
#
# Кто преподавал уроки Льюису Клайв Стейплзу? Киркпатрик
# Киркпатрик преподавал уроки Льюису Клайв Стейплзу.
#
# Кто способен к образованию эндоспор? некоторые виды прокариот
# Некоторые виды прокариот способен к образованию эндоспор.
#
# Чем при сооружении подводных лодок в СССР был вытеснен титан? Высокопрочной сталью.
# Титан был вытеснен высокопрочной сталью при сооружении подводных лодок в СССР.
#
# Во что перерастал промысел после появления сложных и энергоёмких машин и механизмов? в промышленность
# Промысел перерастал в промышленность после появления сложных и энергоёмких машин и механизмов.
#
# Что вызывает наличие в клеточной стенке фибриллярных нитей?  бегущую волну по поверхности клетки
# Наличие в клеточной стенке фибриллярных нитей вызывает бегущую волну по поверхности клетки.
#
# Кто описывал содержание реформы? А. А. Корнилов
# А. А. Корнилов описывал содержание реформы.
#
# Кого обыграла италия? обыграли Норвегию
# Италия обыграла обыграли Норвегию.
#
# Кто заметил: Именно в этой перспективе раскрывается Бунин-новатор, желающий быть продолжателем великой классической традиции в эпоху модернизма, но с тем, чтобы переписать всю эту традицию заново ? литературовед Юрий Лотман
# Литературовед Юрий Лотман заметил: Именно в этой перспективе раскрывается Бунин-новатор, желающий быть продолжателем великой классической традиции в эпоху модернизма, но с тем, чтобы переписать всю эту традицию заново.
#
# На чем основывается традиционная систематика лишайников? На микобионте.
# Традиционная систематика лишайников основывается на микобионте.
#
# Что первоначально делает портретист после того, как заказчик присылает свое фото? запускает компьютерную программу
# Портретист первоначально делает запускает компьютерную программу после того, как заказчик присылает свое фото.
#
# От чего не отличается принцип устройства клеточных мембран? от эукариот
# Принцип устройства клеточных мембран не отличается от эукариотов.
#
# Чем UBS объяснил свое решение отказаться от австралийского бизнеса? повышением нормативных и клиентских требований
# UBS объяснил свое решение отказаться от австралийского бизнеса повышением нормативных и клиентских требований.
#
# Где, несколько позднее, чем в Великобритании, стала развиваться лёгкая атлетика? в США
# Лёгкая атлетика где, несколько позднее, в США в Великобритании, стала развиваться.
#
# Кто владел в 1896—1899 годах оперным театром в Москве? меценат С. И. Мамонтов
# Меценат С. И. Мамонтов владел в 1896—1899 годах оперным театром в Москве.
#
# Что можно разместить в месте, где в SRAM размещается один триггер, хранящий 1 бит? Несколько конденсаторов и транзисторов для хранения нескольких бит.
# Несколько конденсаторы и транзисторов для хранения нескольких бит можно разместить в месте, где в SRAM размещается один триггер, хранящий 1 бит.
#
# Что обычно геометрия держит в руках? глобус и циркуль
# Геометрия обычно держит глобус и циркуль в руках.
#
# Что отражают эмоции? различные аспекты значения вызвавших их ситуаций
# Различные аспекты значения вызвавших их ситуаций отражают эмоции.
#
# Продуктами чего являются строительные материалы? деревообработки и целлюлозно-бумажной промышленности
# Строительные материалы являются продуктами деревообработки и целлюлозно-бумажной промышленности.
#
# Что приводит к нарушению изотопного состояния? Физические процессы в природе.
# Физические процессы в природе приводят к нарушению изотопного состояния.
#
# У кого на данный момент выявлены бактериоциты? только у некоторых видов обыкновенных губок
# Бактериоциты выявлены только у некоторых видов обыкновенных губок на данный момент.
#
# Кто предпринял масштабную и плодотворную попытку синтеза античных, схоластических и картезианских идей на основе метода всеохватности и строгости рассуждений? Лейбниц.
# Лейбниц предпринял масштабную и плодотворную попытку синтеза античных, схоластических и картезианских идей на основе метода всеохватности и строгости рассуждений.
#
# Кого называют предками птиц? динозавров
# Называют динозавров предками птиц.
#
# Чем дышит большая часть ракообразных? кожными жабрами
# Большая часть ракообразных дышит кожными жабрами.
#
# Что применяют в некоторых системах широкоформатного кино наряду с широкой киноплёнкой? анаморфирование изображения
# Наряду с широкой киноплёнкой применяют анаморфирование изображения в некоторых системах широкоформатного кино.
#
# На чем основаны полуколичественные подходы? на квантовомеханической интуиции
# Полуколичественные подходы основаны на квантовомеханической интуиции.
#
# На ком был женат Л.Толстой? На С. А. Берс
# Был женат на С. А. Берс Л.Толстой.
#
# Что написано на знаке, кроме NSF, даты и широты установки?  Geographic south pole
# Geographic south pole написано на знаке, кроме NSF, даты и широты установки.
#
# Что обеспечивает уничтожение в молоке бактерий? УВТ-обработка
# Увт-обработку обеспечивает уничтожение в молоке бактерий.
#
# С помощью чего пытался контролировать экономику Роберт Мугабе? с помощью военной силы
# Роберт Мугабе пытался контролировать экономику с помощью военной силы.
#
# Кто писал, что папа Корнелий был выбран в согласии с желанием Бога и Его Церкви, свидетельствами почти всего клира, собором старших по возрасту епископов (sacerdotum) и добрыми людьми ? Святой Киприан Карфагенский
# Святой Киприан Карфагенский писал, что папа Корнелий был выбран в согласии с желанием Бога и Его Церкви, свидетельствами почти всего клира, собором старших по возрасту епископов (sacerdotum) и добрыми людьми.
#
# Через что проходит кровь в правый желудочек? Через трикуспидальный клапан (он состоит из трёх лепестков)
# Кровь проходит через трикуспидальный клапан (он состоит из трёх лепестков) в правый желудочек.
#
# Что может образовываться при нагревании кремния с металлами? Силициды
# Силициды могут образовываться при нагревании кремния с металлами.
#
# Что обладает самым большим и оптимальным временем? диски для портативных устройств
# Диски для портативных устройств обладают самым большим и оптимальным временем.
#
# Кем в будущем были отредактированы стихи Микеланджело? его внучатым племянником
# Стихи Микеланджело были отредактированы его внучатым племянником в будущем.
#
# Кем был ослеплен князь Василий Тёмный? своим двоюродным братом Дмитрием Шемякой
# Князь Василий Тёмный был ослеплен своим двоюродным братом Дмитрием Шемякой.
#
# К кому обращаются будущие владельцы сайтов для разработки? Фрилансерам, студиям, бюро, конторам.
# Будущие владельцы сайтов для разработки обращаются к фрилансерам, студиям, бюро, конторам.
#
# Кем сделано открытие, что установления культуры существенно отличаются от законов природы Софистами
# Открытие, что установления культуры существенно отличаются от законов природы сделано софистами.
#
# Что разрешает к применению внесистемной единицы рентген в Российской Федерации? Положение о единицах величин
# Положение о единицах величин рентген разрешает к применению внесистемной единицы в Российской Федерации.
#
# Что ведёт ведёт к переходу от диплоидной фазы к гаплоидной в жизненном цикле ? Уменьшение числа хромосом в результате мейоза
# Уменьшение числа хромосом в результате мейоза ведёт ведёт к переходу от диплоидной фазы к гаплоидной в жизненном цикле.
#
# Кто является самым маленьким из фигурантов антимонопольных дел в США? компания Transitional Optical
# Компания Transitional Optical является самым маленьким из фигурантов антимонопольных дел в США.
#
# Кем и для чего был использован термин кибернетика? Н. Винером для обозначения общей науки об управлении
# Термин кибернетика был использован Н. Винером для обозначением общей науки об управлении.
#
# На что похож мембранный компартмент, окружающий цитоплазму при макроаутофагии? На цистерну эндоплазматического ретикулума.
# Мембранный компартмент, окружающий цитоплазму при макроаутофагии похож на цистерну эндоплазматического ретикулума.
#
# Что открыла Япония когда пересмотрела свою прежнюю политику самоизоляции от внешнего мира ? Некоторые порты для товарообмена с западными странами.
# Япония открыла некоторые порты для товарообмена с западными странами когда пересмотрела свою прежнюю политику самоизоляции от внешнего мира.
#
# Что рассматривают в технологиях управления риском? обобщенные понятия случайного события
# Рассматривают обобщенные понятия случайного события в технологиях управления риском.
#
# Чем характеризуется бегство вкладчиков ? наплыв в банк требований о возвращении вкладов
# Бегство вкладчиков характеризуется наплывом в банк требований о возвращении вкладов.
#
# На основании чего можно было проследить локальные различия в разговорной речи? На основании диалектных форм, изредка попадавших в памятники
# Можно на основании на основания диалектных форм, изредка попадавших в памятники было проследить локальные различия в разговорной речи.
#
# От кого происходит Савойская династия согласно научным исследованиям? от Беренгара II
# Савойская династия происходит от Беренгара II согласно научным исследованиям.
#
# Что расположенное за рубежом, строится на земле, взятой в долгосрочную аренду у местных органов власти? Объекты
# Объекты за рубежом строятся на земле, взятой в долгосрочную аренду у местных органов власти.
#
# Что обеспечивают прочность, жесткость и устойчивость здания в целом и его отдельных частей под действием нагрузок от веса людей, мебели, оборудования, ветровых, сейсмических, снеговых и других временных нагрузок? Несущие конструкции
# Несущие конструкции обеспечивают прочность, жесткость и устойчивость здания в целом и его отдельных частей под действием нагрузок от веса людей, мебели, оборудования, ветровых, сейсмических, снеговых и других временных нагрузок.
#
# Кто формулирует идею эксперимента как источника знания? Фрэнсис Бэкон
# Фрэнсис Бэкон формулирует идею эксперимента как источника знания.
#
# Что делает пар, поступающий в цилиндр паровой машины расширяется и перемещает поршень
# Пар, поступающий в цилиндр паровой машины делает расширяется и перемещает поршень.
#
# За кого призвала голосовать Мадонна в своём Instagram-аккаунте 1 сентября 2016 года? за Хиллари Клинтон
# Мадонна призвала голосовать за Хиллари Клинтон 1 сентября 2016 года в своём Instagram-аккаунте.
#
# Чем питаются личинки речного окуня? в основном зоопланктоном
# Личинки речного окуня питаются в основном зоопланктоном.
#
# От чего отказалось постмодернистское искусство? от попыток создания универсального канона
# Постмодернистское искусство отказалось от попыток создания универсального канона.
#
# Над чем значительно преобладают в российской философии этика, политическая философия, философия истории, философия религии? Над исследованиями в области метафизики, эпистемологии и др.
# Этика, политическая философия, философия истории, философия религии значительно преобладают над исследованиями в области метафизики, эпистемологии и др в российской философии.
#
# Что традиционно для средневекового хозяйственного режима? соединение крестьянских домашних промыслов с патриархальным (натуральным) земледелием
# Соединение крестьянских домашних промыслов с патриархальным (натуральным) земледелием традиционно для средневекового хозяйственного режима.
#
# Что делает гильза раздуваемая пороховыми газами при традиционном заряжании успешно изолирует патронник от остальных частей конструкции.
# Успешно изолирует патронник от остальных частей конструкции.
#
# Кто стал новым главным тренером Мейпл Лифс 20 мая 2015 года? Майк Бэбкок
# Майк Бэбкок стал новым главным тренером Мейпл Лифс 20 мая 2015 года.
#
# С чем тесно связана философская система йоги? со школой санкхьи
# Философская система йоги тесно связана со школой санкхьи.
#
# К кому обращался Руссо задавая вопрос, хуже ли жилось бы человечеству без познания тайны мировых законов? к просветлённым умам
# Руссо обращался к просветлённым умам задавая вопрос, хуже ли жилось бы человечеству без познания тайны мировых законов.
#
# Что отсутствует в мембранах прокариот? Молекулы холестерина и некоторых липидов
# Молекулы холестерина и некоторых липидов отсутствуют в мембранах прокариот.
#
# Что существует на границах зон и поясов ? Сильная турбулентность
# Сильная турбулентность существует на границах зон и поясов.
#
# Кто внес в русский витраж значительный вклад в 19-ом веке? Джон Ла Фарж и Луис Тиффани
# Джон Ла Фарж и Луис Тиффани внесли значительный вклад в 19-ом веке в русский витраж.
#
# Что находится внутри селезенки? трабекулы (балки)
# Трабекулы (балки) находятся внутри селезенки.
#
# Кто стал главным тренером сборной Германии? Эрих Риббек
# Эрих Риббек стал главным тренером сборной Германии.
#
# Что вызывают бактерии проникающее внутрь молодых корней ? Образование клубеньков
# Бактерии проникающее вызывают образование клубеньков внутрь молодых корней.
#
# На что распространяется десятина dîmes insolites? на картофель, сеяную траву и т. п.
# Десятина dîmes insolites распространяется на картофель, сеяную траву и т. п.
#
# Что изменило саму структуру стекольной промышленности? иностранный капитал
# Иностранный капитал изменил саму структуру стекольной промышленности.
#
# Кто определяет в качестве отличительных признаков общества как объединения людей наличие географических границ, общую законодательную систему и определённую национальную? Нейл Смелзер.
# Нейл Смелзер определяет наличие географических границ, общую законодательную систему и определённую национальную в качестве отличительных признаков общества как объединения людей.
#
# Что нужно сделать после доставки на квартиру потребителя нового или подержанного инструмента? проверить, при необходимости отрегулировать его механизм и настроить
# Проверить, при необходимости отрегулировать его механизм и настроить.
#
# Что дает использование плавающих процентных ставок? Серии процентных платежей
# Использование плавающих процентных ставок дает серии процентных платежей.
#
# Кто был обладателем неофициального статуса лидера экономического империализма? Гэри Беккер
# Гэри Беккер был обладателем неофициального статуса лидера экономического империализма.
#
# Что происходило с душами согласно доктрине Оригена? они продвигались по пути к совершенству
# Они продвигались по пути к совершенству.
#
# Что делает избыточным вертикальную интеграцию в развитых рынках? механизмы контроля над смежниками
# Механизмы контроля над смежниками делают вертикальную интеграцию в развитых рынках избыточным.
#
# Что широко и неравномерно распространена в природе? Полиплоидия
# Полиплоидия широко и неравномерно распространена в природе.
#
# Чему учили представители патристики, такие как Климент Александрийский, Василий Великий, Григорий Нисский и другие? образ Божий заключается в разумности человека
# Образ Божий заключается в разумности человека.
#
# Что позволяет вынос электрооборудования троллейбуса на крышу? понизить уровень пола
# Понизить уровень пола позволяет вынос электрооборудования троллейбуса на крышу.
#
# Что предполагает иерархическая конструкция, предложенная Фелибьеном? Иерархическая конструкция, предложенная Фелибьеном, предполагает, что индивидуализация может касаться исключительно человеческого существа.
# Иерархическая конструкция, предложенная Фелибьеном, предполагает, что индивидуализация может касаться исключительно человеческого существа.
#
# В чем находится фермент жизненной силы процесса брожения? В дрожжевых клетках
# Фермент жизненной силы процесса брожения находится в дрожжевых клетках.
#
# Кому в 2006 году Роспотребнадзор по результатам проверки жалобы заёмщика предъявил претензию о взимании комиссии за открытие ссудного счёта по договору потребительского кредита? Банку Хоум Кредит
# ...
# Была пробурена Саатлинская скважина была сделана в СССР для изучения вопроса о границе между верхней (гранитной) и нижней (базальтовой) континентальной корой.
#
# Кем был издан французский оригинал работы сочинения Лейбница Монадология ? Эрдманном вместе с Новыми опытами
# Французский оригинал работы сочинения Лейбница Монадология был издан Эрдманном вместе с Новыми опытами.
#
# Синтезом чего является синтетическая теория эволюции? синтезом классического дарвинизма и популяционной генетики
# Синтетическая теория эволюции является синтезом синтеза классического дарвинизма и популяционной генетики.
#
# Кем простые субстанции создаются одномоментно, и каждая из них может быть уничтожена только вся сразу, за один момент? Богом
# Простые субстанции одномоментно создаются Богом, и каждая из них может быть уничтожена только вся сразу, за один момент.
#
# Несмотря на что функция полезности является неотъемлемой частью большинства современных экономических моделей? на некоторую ограниченность подхода
# Функция полезности является на некоторую ограниченность подхода неотъемлемой частью большинства современных экономических моделей.
#
# С помощью чего некоторые исследователи предлагают отображать филогенетические связи  Сетки жизни
# Некоторые исследователи предлагают отображать филогенетические связи с сетки жизни.
#
# что в строгом письме регламентировалось разветвленными правилами? приготовление и разрешение диссонанса
# Приготовление и разрешение диссонанса регламентировались в строгом письме разветвленными правилами.
#
# Чем объяснялось медленное распространение формата DVD-RW? несовместимостью старых приводов с этими новыми дисками
# Медленное распространение формата DVD-RW объяснялось несовместимостью старых приводов с этими новыми дисками.
#
# Чем гордился отец Микеланджело? аристократическим происхождением
# Отец Микеланджело гордился аристократическим происхождением.
#
# Кому пишет письмо Толстой осенью 1857 года? И. С. Тургеневу
# Толстой пишет письмо И. С. Тургеневу осенью 1857 года.
#
# Что оставляет концентрированная серная кислота отщепляя воду от органических соединений? чёрный углерод (уголь)
# Концентрированная серная кислота оставляет чёрный углерод (уголь) отщепляя воду от органических соединений.
#
# Благодаря чему макромолекулярные данные накапливаются всё быстрыми темпами? успехам молекулярной биологии
# Макромолекулярные данные накапливаются благодаря успехам молекулярной биологии всё быстрыми темпами.
#
# Кто составлял достойную конкуренцию? европейские пары
# Европейские пары составляли достойную конкуренцию.
#
# Кто является представителем рода аполлонов обыкновенный аполлон
# Обыкновенный аполлон является представителем рода аполлонов.
#
# На основе чего формируются черты характера человека? Человек действует, приобретает опыт.
# Человек действует, приобретает опыт.
#
# Чем отличается короткометражное кино от полнометражного? Небольшой продолжительностью фильма
# Короткометражное кино отличается небольшой продолжительностью фильма от полнометражного.
#
# В кого бракониды откладывают яйца? В свободно передвигающихся гусениц
# Бракониды откладывают яйца в свободно передвигающихся гусениц.
#
# Чего не ожидала писательница от своих книг? получения садистского удовольствия от жестокости ради жестокости
# Писательница не ожидала получения садистского удовольствия от жестокости ради жестокости от своих книг.
#
# Что является главным направлением творчества группы Papa Roach в 2012 году? хард-рок
# Хард-рок является главным направлением творчества группы Papa Roach в 2012 году.
#
# Кто отвечает за точность проведения всех наличных операций? казначей
# Казначей отвечает за точность проведения всех наличных операций.
#
# За что распространитель СПО может взимать плату? за получение у него копий, за каналы доставки, носители
# Распространитель СПО может взимать плату за получение у него копий, за каналы доставки, носители.
#
# Кто создал глаголицу? глаголицу создал Константин (Кирилл) Философ
# Глаголицу создал Константин (Кирилл) Философ.
#
# С кем губки вступают в разнообразные взаимоотношения? с другими животными
# Губки вступают с другими животными в разнообразные взаимоотношения.
#
# Что прописал Агарков для банка за изменение или расторжение договора? штрафные санкции
# Агарков прописал штрафные санкции для банка за изменение или расторжение договора.
#
# Кто относится к инфузориям? практически все микроскопические беспозвоночные
# Практически все микроскопические беспозвоночные относятся к инфузориям.
#
# Что происходит со структурой бетона применение интегральных капиллярных материалов? уплотняется
# Уплотняется применение интегральных капиллярных материалов происходит со структурой бетона.
#
# Кто может использовать информацию о ценных бумагах в личных неблаговидных целях? руководство
# Руководство может использовать информацию о ценных бумагах в личных неблаговидных целях.
#
# Что выпускается без фиксированного дивиденда для обеспечения долгосрочных потребностей? облигации или акции
# Облигации или акции выпускаются без фиксированного дивиденда для обеспечения долгосрочных потребностей.
#
# В отличии чего заключалась проблема несовместимости старых приводов с новыми дисками DVD-RW? оптического слоя, ответственного за запоминание информации
# В отличии оптического слоя, ответственного за запоминание информации заключалась проблема несовместимости старых приводов с новыми дисками DVD-RW.
#
# Что включает в себя понятие конверсия на отдельных площадках? целый ряд действий, связанных с покупкой
# Включает целый ряд действий, связанных с покупкой понятие конверсия на отдельных площадках в себя.
#
# Для чего была предназначена бригада Ямады? для борьбы с большевиками
# Бригада Ямады была предназначена для борьбы с большевиками.
#
# Кто сменил продюсеров первых сезонов Энтерпрайза ? Мэнни Кото
# Мэнни Кото сменил продюсеров первых сезонов Энтерпрайза.
#
# Кем большинство современников считали Ливай Хилла? мошенником
# Большинство современников считали Ливай Хилла мошенником.
#
# На основании чего выводился средний балл? на основании величины
# Средний балл выводился на основании на основания величины.
#
# Кому уступают млекопитающие среди позвоночных по численности и биомассе в водоёмах? Лучепёрым рыбам
# Млекопитающие уступают лучепёрым рыбам среди позвоночных по численности и биомассе в водоёмах.
#
# Что построил Гийом Мале в Гравиле? замок
# Гийом Мале построил замок в Гравиле.
#
# Кому выдает кредит Покупатель ?  Базовому заемщику .
# Покупатель выдает кредит базовому заемщику.
#
# Для чего был установлен дизайн согласно современности и передовым технологиям? для других крупных ботанических оранжерей по всей Великобритании
# Дизайн был установлен для других крупных ботанических оранжерей по всей Великобритании согласно современности и передовым технологиям.
#
# Что обеспечивается посредством мотор-генератора, либо статического преобразователя? Получение низкого напряжения из напряжения контактной сети
# Получение низкого напряжения из напряжения контактной сети обеспечивается посредством мотор-генератора, либо статического преобразователя.
#
# В чём виделось превосходство Бунина над Тургеневым литературными критиками? В пейзажной прозе
# Превосходство Бунина над Тургеневым литературными критиками виделось в пейзажной прозе.
#
# Что происходит в сериалах Я женат на Джоане , Я люблю Люси , Дарма и Грег ? прямой, приземлённый, рациональный муж женится на ветреной, смешной, эмоциональной женщине
# Прямой, приземлённый, рациональный муж женится на ветреной, смешной, эмоциональной женщине.
#
# С чем шарнирно соединяется мост? С кузовом.
# Мост шарнирно соединяется с кузовом.
#
# Кто организовал общенациональную кампанию против французского католического меньшинства Манитобы? Орден оранжистов
# Орден оранжистов организовал общенациональную кампанию против французского католического меньшинства Манитобы.
#
# Чем вызывал негодование публики Рихард Вагнер? Дирижировал наизусть
# Рихард Вагнер вызывал негодование публики дирижировал наизусть.
#
# Что является отличительной чертой деления прокариотических клеток? Непосредственное участие реплицированной ДНК в процессе деления.
# Непосредственное участие реплицированной ДНК в процессе деления является отличительной чертой деления прокариотических клеток.
#
# Для кого был закрыт доступ к высшим судебным должностям? лиц третьего сословия
# Доступ к высшим судебным должностям был закрыт для лиц третьего сословия.
#
# Что предполагает отрасль хозяйства — пушное звероводство.? Разведение пушных зверей — соболя, норку, песца, лисицу, нутрию, шиншиллу — на зверофермах
# Отрасль хозяйства — пушное звероводство. предполагает разведение пушных зверей — соболя, норку, песца, лисицу, нутрию, шиншиллу — на зверофермах.
#
# Что вызывало зависть соперников Дюма? оглушительный успех его книг
# Оглушительный успех его книг вызывал зависть соперников Дюма.
#
# Из-за чего Амальтея в прошлом распалась на части? Из-за метеоритной бомбардировки.
# Амальтея распалась из-за метеоритной бомбардировки в прошлом на части.
#
# Что утрачивают морские костистые рыбы с низкой концентрацией ионов в организме? воду
# Морские костистые рыбы с низкой концентрацией ионов в организме утрачивают воду.
#
# Что эксплуатировали паровые машины тройного или даже четырёхкратного расширения? серии цилиндров двойного действия
# Паровые машины тройного или даже четырёхкратного расширения эксплуатировали серии цилиндров двойного действия.
#
# Что относится к числу неадаптивных причин эволюции? генетический дрейф, поток генов и мутации.
# Генетический дрейф, поток генов и мутации относятся к числу неадаптивных причин эволюции.
#
# в чем были заинтересованы страны, упомянутые в работе Адама Смита Исследование о природе и причинах богатства народов ? в свободном развитии международной торговли
# Страны, упомянутые в работе Адама Смита Исследование о природе и причинах богатства народов были заинтересованы в свободном развитии международной торговли.
#
# Что впрыскивается с хвоста капсида в клетку-хозяина? генетический материал вируса
# Генетический материал вируса впрыскивается с хвоста капсида в клетку-хозяина.
#
# Что является ключевыми моментами метода Шерлока Холмса? наблюдательность и экспертные знания
# Наблюдательность и экспертные знания являются ключевыми моментами метода Шерлока Холмса.
#
# для чего используется делегирование полномочий ? для улучшения и оптимизации рабочей силы руководителя
# Делегирование полномочий используется для улучшения и оптимизации рабочей силы руководителя.
#
# Что происходило с фотографическими пластинками, если поместить их рядом с солями урана? пластинки оказывались засвеченными
# Пластинки оказывались засвеченными происходили с фотографическими пластинками, если поместить их рядом с солями урана.
#
# Кому досталась победа в женском теннисе в 1959 году? бразильянке Марии Буэно
# Победа в женском теннисе в 1959 году досталась бразильянке Марии Буэно.
#
# Что также получают реакцией гидратации в промышленности? этиленгликоль
# Также получают этиленгликоль реакцией гидратации в промышленности.
#
# Кем была основана первая компания по разработке ПО? Роем Наттом и Флетчером Джоунсом
# Первая компания по разработке ПО была основана Роем Наттом и Флетчером Джоунсом.
#
# Что получилось сделать у Корнеля Оживить французскую драму
# Оживить французскую драму получилось сделать у Корнеля.
#
# Кто написал сценарий к одиннадцатому полнометражному фильму Звёздный путь ? Роберто Орси и Алекс Курцман
# Роберто Орси и Алекс Курцман написали сценарий к одиннадцатому полнометражному фильму Звёздный путь.
#
# Что чётко разделено при двуполом размножении? оба пола
# Оба пола чётко разделён при двуполом размножении.
#
# Вокруг чего стягивается плазматическая мембрана? остаточного тельца Флемминга
# Плазматическая мембрана стягивается вокруг остаточного тельца Флемминга.
#
# Что учитывается при монтаже телефильмов? рекламные блоки в эфирной сетке телеканалов
# Рекламные блоки в эфирной сетке телеканалов учитываются при монтаже телефильмов.
#
# Кем был одобрен перечень банков, участвующих в программе? Советом директоров АСВ
# Перечень банков, участвующих в программе был одобрен советом директоров АСВ.
#
# Кто писал, что пролетариат окажется вынужденным вносить классовую борьбу в деревню и, таким образом, нарушать ту общность интересов, которая несомненно имеется у всего крестьянства, но в сравнительно узких пределах ? Троцкий
# Троцкий писал, что пролетариат окажется вынужденным вносить классовую борьбу в деревню и, таким образом, нарушать ту общность интересов, которая несомненно имеется у всего крестьянства, но в сравнительно узких пределах.
#
# Кем определяется размер дивидендов. Советом директоров предприятия.
# Размер дивидендов. определяется советом директоров предприятия.
#
# Что для идентификации сайтов в адресе после указания хоста стоит? тильда и имя сайта
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_14298/318518786.py in <module>
#       1 for i in a2:
#       2     print(i.question, i.answer)
# ----> 3     print(gen.generate_one(i.question, i.answer))
#       4     print()
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/src/generate.py in generate_one(self, question, answer)
#      86         answer, answer_tree = self.preprocess_with_tree(answer, answer_tree)
#      87         question, question_tree = self.preprocess_with_tree(question, question_tree)
# ---> 88         long_answer = self.generate_long_answer(question, question_tree, answer, answer_tree)
#      89         long_answer = self.postprocess(long_answer)
#      90         return long_answer
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/src/generate.py in generate_long_answer(self, question, question_tree, answer, answer_tree)
#      68
#      69     def generate_long_answer(self, question, question_tree, answer, answer_tree):
# ---> 70         return CommonGenerator().generate(question, question_tree, answer, answer_tree)
#      71
#      72     def postprocess(self, answer):
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/src/generate.py in generate(self, question, question_tree, answer, answer_tree)
#     102     def generate(self, question, question_tree, answer, answer_tree):
#     103         for handler in case_handlers:
# --> 104             result, long_answer = handler.generate(question, question_tree, answer, answer_tree)
#     105             if result:
#     106                 return long_answer
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/src/generate.py in generate(self, question, question_tree, answer, answer_tree)
#     402         if not self.trim(question_tree, answer_tree):
#     403             qword_node = self.find_qword(question_tree)
# --> 404             self.harmonize(qword_node, question_tree, answer_tree)
#     405
#     406         qword_node = self.find_qword(question_tree)
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/src/generate.py in harmonize(self, qword_node, question_tree, answer_tree)
#     376
#     377     def harmonize(self, qword_node, question_tree, answer_tree):
# --> 378         self.harmonize_verb(qword_node, question_tree, answer_tree)
#     379         self.harmonize_noun(qword_node, question_tree, answer_tree)
#     380
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/src/generate.py in harmonize_verb(self, qword_node, question_tree, answer_tree)
#     269         if root.upos not in ['VERB', 'AUX'] or qword_node.feats['Case'] != 'Nom':
#     270             return
# --> 271         self.harmonize_verb_one(qword_node, question_tree, answer_tree, root)
#     272         auxes = get_children(root, 'aux')
#     273         for aux in auxes:
#
# /data/home/admin/bachelor/extended_generative_qa_ru/preprocessing/src/generate.py in harmonize_verb_one(self, qword_node, question_tree, answer_tree, root)
#     296                     morph_parse(root.form, ["PRTS"])
#     297                 ))
# --> 298                 new_word = parsers[0].inflect(params).word
#     299                 root.form = new_word
#     300
#
# AttributeError: 'NoneType' object has no attribute 'word'

# %%
gen.generate_one('Кто автор книги The Competitive Advantage of Nations?', 'В. О. Сурков')
# Out:
# 'В. О. Сурков - это автор книги The Competitive Advantage of Nations.'

# %%
write_tree(*parser(['Что для идентификации сайтов в адресе после указания хоста стоит?']))
# Out:
# # sent_id = ?
# # text = Что для идентификации сайтов в адресе после указания хоста стоит ?
# ─┮
#  │ ╭─╼ 1 Что что PRON nsubj <?#10, стоит> Case=Nom
#  │ │ ╭─╼ 2 для для ADP case <?#3, идентификации> _
#  │ ┢─┾ 3 идентификации идентификация NOUN obl <?#10, стоит> Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
#  │ │ ┡─╼ 4 сайтов сайт NOUN nmod <?#3, идентификации> Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
#  │ │ │ ╭─╼ 5 в в ADP case <?#6, адресе> _
#  │ │ ╰─┶ 6 адресе адрес NOUN nmod <?#3, идентификации> Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
#  │ │ ╭─╼ 7 после после ADP case <?#8, указания> _
#  │ ┢─┾ 8 указания указание NOUN obl <?#10, стоит> Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
#  │ │ ╰─╼ 9 хоста хост NOUN nmod <?#8, указания> Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#  ╰─┾ 10 стоит стоять VERB root <?, <ROOT>> Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
#    ╰─╼ 11 ? ? PUNCT punct <?#10, стоит> _

# %%
tree = get_tree(*parser(['писали под из диктовку']))
tree.children[0].remove(children='rehang')
tree.children
# Out:
# [Node<?#2, работы>]

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
print(morph.parse('стоит')[0], '\n',
      morph.parse('стоит')[1], '\n',
      morph.parse('стоит')[2], '\n',
      )
butyavka = morph.parse('стоит')[0]
butyavka.inflect({'plur'})
# Out:
# Parse(word='стоит', tag=OpencorporaTag('VERB,impf,intr,Impe sing,pres,indc'), normal_form='стоить', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'стоит', 1304, 2),))
#  Parse(word='стоит', tag=OpencorporaTag('VERB,impf,intr sing,3per,pres,indc'), normal_form='стоять', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'стоит', 2176, 5),))
#  Parse(word='стоит', tag=OpencorporaTag('VERB,impf,tran sing,3per,pres,indc'), normal_form='стоить', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'стоит', 2829, 5),))

# %%
butyavka = morph.parse('наплыв')

# %%
butyavka[1].tag.POS
# Out:
# 'NOUN'
